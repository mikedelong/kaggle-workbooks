# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/100-million-random-values/100 Million Random Values.csv')
df.head()
# Out:
#        col1      col2      col3      col4      col5      col6      col7  \
# 0  0.351826  0.552540  0.883962  0.896084  0.258852  0.146816  0.427795
# 1  0.023325  0.857925  0.610042  0.862262  0.096637  0.793002  0.324918
# 2  0.754705  0.407673  0.458940  0.788811  0.380545  0.356489  0.266228
# 3  0.780540  0.674675  0.439044  0.258040  0.508532  0.653579  0.010269
# 4  0.414569  0.769114  0.943292  0.518043  0.472415  0.027251  0.923420
#
#        col8      col9     col10  ...   col9991   col9992   col9993   col9994  \
# 0  0.985237  0.119935  0.927899  ...  0.983813  0.229019  0.963223  0.544037
# 1  0.025194  0.032260  0.329649  ...  0.865163  0.191472  0.154791  0.382200
# 2  0.115581  0.322107  0.120237  ...  0.386104  0.146092  0.931389  0.540215
# 3  0.287572  0.424164  0.770689  ...  0.807429  0.336267  0.130776  0.540568
# 4  0.162933  0.283660  0.197664  ...  0.770699  0.689006  0.824875  0.290480
#
#     col9995   col9996   col9997   col9998   col9999  col10000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 10000 entries, col1 to col10000
# dtypes: float64(10000)
# memory usage: 762.9 MB

# %%
from plotly.express import imshow
from random import sample
from random import seed
seed(2023)
columns = sample(population=df.columns.tolist(), k=10)
imshow(img=df[columns].sample(n=10, random_state=2023).corr())
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from plotly.express import scatter_matrix
scatter_matrix(data_frame=df[sample(population=df.columns.tolist(), k=10)].sample(n=100, random_state=2023))
# Out:
# <div>                            <div id="d58dbe1f-656c-4e00-8457-1d1310170706" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d58dbe1f-656c-4e00-8457-1d1310170706")) {                    Plotly.newPlot(                        "d58dbe1f-656c-4e00-8457-1d1310170706",                        [{"dimensions":[{"axis":{"matches":true},"label":"col8645","values":[0.8643540752596753,0.3806025986401332,0.2423135211319362,0.7074211051012819,0.6218756417584022,0.074971228381061,0.894278927629983,0.6035872419648991,0.3017794173318815,0.1902900677181682,0.9722551659944996,0.7691100419652401,0.5400041836258684,0.6238265491539997,0.7557940837217593,0.5628567587193753,0.174898245228058,0.7597817952649528,0.7940445806423395,0.1009949254077438,0.7580224556168232,0.5
# ...

# %%
from plotly.express import histogram
for column in sample(population=df.columns.tolist(), k=5):
    histogram(data_frame=df, x=column).show()
# Out:
# <div>                            <div id="550633a8-6371-44b0-9489-499f02a0209a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("550633a8-6371-44b0-9489-499f02a0209a")) {                    Plotly.newPlot(                        "550633a8-6371-44b0-9489-499f02a0209a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"col638=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.8010182034907636,0.3962742780575659,0.2904911929020535,0.7860922561013348,0.8786149439845587,0.6163293801911545,0.5145578739715426,0.1094839928395738,0.2179322762201201,0.2444187480922711,0.551
# ...

# %% [markdown]
# Oddly enough the values at the end of the range appear about half as often as they would if these numbers were uniform.
