# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/international-iq-by-countries/International_IQ.csv', index_col=['Ranking'])
df.head()

# %%
from plotly.express import scatter
scatter(data_frame=df, x='Participants', y='Average IQ', hover_name='Country', log_x=True)
