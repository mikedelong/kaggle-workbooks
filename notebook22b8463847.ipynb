# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/cats-vs-dogs/cats_vs_dogs.csv', index_col=['Unnamed: 0'])
df.head()

# %%
df.info()

# %%
from plotly.express import bar
bar(data_frame=df, x='state', y='n_households')
