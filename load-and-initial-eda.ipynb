# %% [markdown]
# <a href="https://www.kaggle.com/code/mikedelong/eda-with-umap-sentence-transformers?scriptVersionId=158732731" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# %env TOKENIZERS_PARALLELISM=false
# !pip install --quiet keybert
print('pip install keybert complete.')
# Out:
# env: TOKENIZERS_PARALLELISM=false
# pip install keybert complete.

# %%
import pandas as pd
from glob import glob

PATHNAME = '/kaggle/input/sentiment-analysis-datasets/*.csv'

df = pd.concat(axis=1, objs=[pd.read_csv(filepath_or_buffer=input_file) for input_file in glob(pathname=PATHNAME)])
df['date'] = pd.to_datetime(df['Timestamp'])
df['token count'] = df['text'].str.split().apply(func=len)
df = df.drop(columns=['Timestamp', 'Hour', 'Month', 'Year', 'Day', 'worlds', 'value_worlds'])
df.head()
# Out:
#                User                     Hashtags   Platform  \
# 0  CathedralVisitor  #Awe #ArchitecturalGrandeur   Facebook
# 1  CathedralVisitor  #Awe #ArchitecturalGrandeur   Facebook
# 2   GreatWallWalker     #Awe #EngineeringMarvels    Twitter
# 3      PuzzleSolver  #Euphoria #PuzzleCompletion  Instagram
# 4      PuzzleSolver     #Euphoria #PerfectPuzzle  Instagram
#
#                                                 text  Likes         Country  \
# 0  Awe-inspired by the grandeur of an ancient cat...   35.0  Czech Republic
# 1  Awe-struck by the grandeur of an ancient cathe...   35.0  Czech Republic
# 2  Walking the Great Wall of China, each step a t...   35.0           China
# 3  Euphoria floods in as the final puzzle piece c...   40.0         Denmark
# 4  Euphoria floods in as the final puzzle piece f...   40.0         Denmark
#
#   Sentiment  Retweets                      date  token count
# 0       Awe      18.0 2018-08-18 14:45:00+00:00           10
# 1       Awe      18.0 2018-08-18 14:45:00+00:00           10
# 2       Awe      18.0 2017-08-18 19:30:00+00:00           14
# 3  Euphoria      20.0 2022-06-08 15:30:00+00:00           11
# 4  Euphoria      20.0 2022-06-08 15:30:00+00:00           10

# %%
from plotly.express import histogram
for x in ['Platform', 'Likes', 'token count', 'Country', 'Retweets']:
    histogram(data_frame=df, x=x).show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d0e0be36-4199-467b-a794-300206feb5ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0e0be36-4199-467b-a794-300206feb5ea")) {                    Plotly.newPlot(                        "d0e0be36-4199-467b-a794-300206feb5ea",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Platform=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Facebook","Facebook","Twitter","Instagram","Instagram","Instagram","Facebook","Facebook","Facebook","Instagram","Instagram","Instagram","Instagram","Facebook","Facebook","Facebook","Facebook","Twitter","Instagram","Instagram","Twitter","Instagram","Twitter","Instagram","Instagram","Facebook","Twitter","Facebook","Facebook","Facebook","Twitter","Facebook","Instagram","Instagram","Facebook","Instagram","Instagram","Facebook","Facebook","Twitter","Facebook","Instagram","Facebook","Instagram","Facebook","Twitter","Twitter","Facebook","Facebook","Instagram","Facebook","Facebook","Twitter","Twitter","Instagram","Twitter","Twitter","Instagram","Twitter","Instagram","Twitter","Twitter","Twitter","Twitter","Instagram","Twitter","Instagram","Twitter","Instagram","Twitter","Twitter","Instagram","Twitter","Instagram","Instagram","Twitter","Instagram","Twitter","Facebook","Instagram","Twitter","Facebook","Twitter","Twitter","Twitter","Facebook","
0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,13.0,13.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,16.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,19.0,19.0,19.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,21.0,21.0,21.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,23.0,23.0,23.0,24.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,27.0,28.0,28.0,28.0,28.0,28.0,28.0,28.0,28.0,28.0,28.0,28.0,28.0,28.0,28.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,35.0,35.0,35.0,35.0,5.0,8.0,8.0,10.0,10.0,10.0,10.0,12.0,12.0,12.0,12.0,13.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,16.0,16.0,16.0,16.0,16.0,17.0,17.0,17.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,19.0,19.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,21.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,23.0,23.0,23.0,23.0,23.0,24.0,24.0,24.0,24.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,26.0,28.0,28.0,28.0,28.0,28.0,28.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,40.0,40.0,40.0,40.0,40.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,35.0,7.0,8.0,8.0,9.0,9.0,10.0,10.0,10.0,10.0,12.0,12.0,12.0,12.0,12.0,14.0,14.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,16.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,20.0,20.0,20.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,28.0,28.0,30.0,30.0,30.0,30.0,30.0,40.0,40.0,15.0,15.0,18.0,20.0,22.0,25.0,25.0,28.0,28.0,28.0,35.0,18.0,18.0,20.0,20.0,22.0,22.0,22.0,25.0,28.0,28.0,30.0,35.0,35.0,35.0,35.0,18.0,18.0,18.0,20.0,22.0,30.0,15.0,20.0,22.0,22.0,22.0,22.0,22.0,25.0,25.0,25.0,25.0,28.0,30.0,30.0,40.0,40.0,35.0,5.0,7.0,7.0,7.0,7.0,8.0,8.0,8.0,8.0,10.0,10.0,10.0,10.0,10.0,10.0,10.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,13.0,13.0,14.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,15.0,16.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,18.0,19.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,20.0,21.0,21.0,21.0,21.0,21.0,21.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,23.0,23.0,23.0,23.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,26.0,26.0,26.0,26.0,27.0,28.0,28.0,28.0,28.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,30.0,40.0,40.0,40.0,35.0,35.0,35.0,35.0,35.0,18.0,18.0,18.0,18.0,18.0,22.0,22.0,22.0,22.0,22.0,28.0,28.0,28.0,28.0,30.0,30.0,18.0,18.0,18.0,22.0,35.0,15.0,15.0,18.0,22.0,22.0,22.0,22.0,28.0,28.0,28.0,28.0,28.0,28.0, ...

# %%
df['Sentiment'].nunique(), len(df)
# Out:
# (191, 732)

# %%
df['Sentiment'].value_counts().head(n=20)
# Out:
# Sentiment
# Positive         45
# Joy              44
# Excitement       37
# Contentment      19
# Neutral          18
# Gratitude        18
# Curiosity        16
# Serenity         15
# Happy            14
# Despair          11
# Nostalgia        11
# Loneliness        9
# Sad               9
# Awe               9
# Hopeful           9
# Grief             9
# Embarrassed       8
# Confusion         8
# Acceptance        8
# Determination     7
# Name: count, dtype: int64

# %% [markdown]
# We have a lot of different sentiment classes, so we may need to pick some or combine some to get reasonable results.

# %%
keep = {'Positive', 'Neutral', 'Despair', 'Sad', 'Loneliness', 'Joy', 'Nostalgia'}
df = df[df['Sentiment'].isin(keep)].copy()

# %%
from arrow import now
from keybert import KeyBERT
from sklearn.feature_extraction.text import TfidfVectorizer

MAX_DF = 1.0
MIN_DF = 2
MODEL = 'all-MiniLM-L12-v2'
STOP_WORDS = 'english'
DOCS = df['text'].values.tolist()

model_start = now()
model = KeyBERT(model=MODEL,)
model.max_seq_length = 64
vectorizer = TfidfVectorizer(ngram_range=(1, 1), stop_words=STOP_WORDS, min_df=MIN_DF, max_df=MAX_DF, )
document_embeddings, word_embeddings = model.extract_embeddings(docs=DOCS, vectorizer=vectorizer, )
print('embedding time: {}'.format(now() - model_start))
print('we have {} documents and {} words.'.format(len(document_embeddings), len(word_embeddings)))
keywords = model.extract_keywords(docs=DOCS, top_n=1, stop_words=STOP_WORDS, vectorizer=vectorizer,
                                  doc_embeddings=document_embeddings, word_embeddings=word_embeddings, min_df=MIN_DF, )
print('model time: {}'.format(now() - model_start))
df['keyword'] = [keyword[0][0] if len(keyword) else '-none-' for keyword in keywords]
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# embedding time: 0:00:20.020701
# we have 147 documents and 193 words.
# model time: 0:00:20.148673

# %%
import pandas as pd
from plotly.express import scatter
from umap import UMAP

IGNORE = {'-none-', }

umap_start = now()
df['short text'] = df['text'].apply(func=lambda x: ' '.join(x.split()[:20]) + '...' if len(x.split()) > 20 else x)
umap_model = UMAP(n_components=2, random_state=2024, verbose=False, n_jobs=1)
df[['u0', 'u1']] = umap_model.fit_transform(X=document_embeddings)
scatter(data_frame=df[~df['keyword'].isin(IGNORE)], x='u0', y='u1', hover_name='short text',
        hover_data=['keyword', ], color = 'Sentiment', size='token count').show()
print('UMAP time: {}'.format(now() - umap_start))
# Out:
# <div>                            <div id="5191c1ca-bc1f-4ca3-b443-390bc03fac41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5191c1ca-bc1f-4ca3-b443-390bc03fac41")) {                    Plotly.newPlot(                        "5191c1ca-bc1f-4ca3-b443-390bc03fac41",                        [{"customdata":[["weekend"],["exploring"],["book"],["sunday"],["birthday"],["gaming"],["scenic"],["workout"],["weekend"],["fitness"],["park"],["movie"],["virtual"],["exploring"],["concert"],["scenic"],["workout"],["reflecting"],["dinner"],["new"],["reflecting"],["workshop"],["garden"],["fitness"],["class"],["productive"],["project"],["excited"],["enjoying"],["practicing"],["enjoying"],["productive"],["feeling"],["learning"],["virtual"],["cozy"],["celebrating"],["painting"],["recipe"],["friend"],["park"],["feeling"],["cozy"],["evening"],["nature"]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSentiment=Positive\u003cbr\u003eu0=%{x}\u003cbr\u003eu1=%{y}\u003cbr\u003etoken count=%{marker.size}\u003cbr\u003ekeyword=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Excited about the upcoming weekend getaway!","Exploring the city's hidden gems.","New book release from my favorite author!","Sunday brunch with friends.","Celebrating a friend's birthday tonight! 🎂","Late-night gaming session with friends.","Weekend road trip to explore scenic views.","Just finished a challenging workout routine.","Quality time with family this weekend.","Starting a new fitness challenge tomorrow! 💪","Enjoying a beautiful day at the park!","The new movie release is a must-watch!","Exploring the world of virtual reality.","Exploring local art galleries this weekend.","Attending a live music concert tonight.","Sunday bike ride through scenic trails.","Just finished an amazing workout! 💪","Reflecting on the past and looking ahead.","Cooking a special dinner for loved ones.","Just published a new blog post. Check it out!","Reflecting on the importance of mental health.","Feeling inspired after attending a workshop.","Planning a garden makeover for spring."," New year, new fitness goals! 💪                    ","Convinced the teacher to have class outdoors. Learning equations with a side of fresh air!","Productive day ticking off my to-do list.","Coding a new project with enthusiasm.","Excited about the upcoming gaming tournament.","Enjoying a cup of tea and watching the sunset.","Practicing mindfulness with meditation.","Sipping coffee and enjoying a good book.","Feeling accomplished after a productive day.","Feeling grateful for the little things in life.","Learning a new language for personal growth.","Attending a virtual reality meetup.","Rainy days call for cozy blankets and hot cocoa.","Celebrating a milestone at work! 🎉","New painting in progress! 🎨","Trying out a new dessert recipe.","Just adopted a cute furry friend! 🐾","Winter sports day at the local park.","Feeling optimistic about the week ahead.","A cozy evening with a good movie.","Quiet evening with a good book.","Reflecting on the beauty of nature."],"legendgroup":"Positive","marker":{"color":"#636efa","size":[6,5,7,4,6,5,7,6,6,7,7,7,6,6,6,6,6,7,7,9,7,6,6,6,15,7,6,6,9,4,7,6,8,7,5,9,6,5,6,7,7,6,7,6,6],"sizemode":"area","sizeref":0.0625,"symbol":"circle"},"mode":"markers","name":"Positive","orientation":"v","showlegend":true,"x":[8.475881,8.191226,5.7766147,7.261699,5.357383,7.5241613,8.387578,5.346777,7.3228445,5.298925,8.1207285,5.963638,7.85106,7.9943814,5.8216853,8.395706,5.197264,8.730132,6.709926,5.61391,8.958294,6.6374035,7.565564,5.1042924,6.2074246,6.317555,6.430378,8.268976,7.30975,8.630401,7.1366196,6.742837,8.658247,7.539866,7.0275607,7.5733867,5.2674694,5.4602733,6.3876724,4.9728346,8.045452,8.5890 ...
# UMAP time: 0:00:09.980040

# %% [markdown]
# Working with this little model and only a few sentiments we can see occasionally interesting results; for example sports are associated with sadness and despair.

# %%
# let's look at words our little model thinks are related
from sklearn.metrics.pairwise import linear_kernel
words_df = pd.DataFrame(data=linear_kernel(X=word_embeddings), columns=vectorizer.get_feature_names_out())
# we want to ignore self-similarity and focus on medium-strong to strong similarity
words_df = words_df[(words_df < 0.9999) & (words_df > 0.66)]
words = words_df.columns.tolist()

for index, row in words_df.iterrows():
    related = words_df.index[row.notnull()].tolist()
    related = [item for item in related if abs(item - index) > 2]
    related_words = [words[item] for item in related]
    if len(related_words):
        print(index, words[index], related_words)
# Out:
# 4 age ['old']
# 7 art ['creativity', 'painting']
# 25 class ['lecture']
# 35 creates ['making']
# 36 creating ['making']
# 37 creativity ['art']
# 44 despair ['hopelessness']
# 47 drowning ['sinking']
# 53 evening ['night']
# 66 fitness ['workout']
# 72 gaming ['sports']
# 82 hopelessness ['despair']
# 86 journey ['trip']
# 92 lecture ['class']
# 98 loneliness ['solitude']
# 100 making ['creates', 'creating']
# 107 music ['tunes']
# 111 night ['evening']
# 114 old ['age']
# 119 painting ['art']
# 156 sinking ['drowning']
# 161 solitude ['loneliness']
# 165 sports ['gaming']
# 169 sunday ['tonight', 'weekend']
# 177 tonight ['sunday']
# 178 trip ['journey']
# 180 tunes ['music']
# 186 weekend ['sunday']
# 188 workout ['fitness']

# %% [markdown]
# Our little model does not pick out a lot of of true synonyms with cosine similarity, which suggests that most of the semantic work is being done by groups of words more than individual words.
