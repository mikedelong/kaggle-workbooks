# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/water-quality-dataset-for-crop/water_quality_.csv')
df.head()

# %%
df['Check'].value_counts()

# %%
from plotly.express import histogram
for column in df.columns[:-1]:
    histogram(data_frame=df, x=column, color='Check').show()

# %%
from plotly.express import imshow
imshow(img=df.drop(columns=['Check']).corr())
