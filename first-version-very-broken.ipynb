# %%
import pandas as pd

GALAXY = '/kaggle/input/sdss-galaxy-classification-dr18/sdss_100k_galaxy_form_burst.csv'
df = pd.read_csv(filepath_or_buffer=GALAXY, low_memory=False, header=1, index_col=['specobjid']).drop(columns=['objid', 'class'])
df.head()
# Out:
#                              ra       dec           u           g         r  \
# specobjid
# 8175185722644649984   82.038679  0.847177    21.73818    20.26633  19.32409
# 8175186822156277760   82.138894  1.063072    20.66761    19.32016  18.67888
# 8175187097034184704   82.028510  1.104003    23.63531    21.19671  19.92297
# 332152325571373056   198.544469 -1.097059    20.12374    18.41520  17.47202
# 332154249716721664   198.706864 -1.046217 -9999.00000 -9999.00000  18.37762
#
#                             i         z  modelFlux_u  modelFlux_g  \
# specobjid
# 8175185722644649984  18.64037  18.23833     2.007378     7.823640
# 8175186822156277760  18.24693  18.04122     5.403369    18.703640
# 8175187097034184704  19.31443  18.68396     0.295693     3.318924
# 332152325571373056   17.05297  16.72423     8.920645    43.044740
# 332154249716721664   18.13383  17.78497     0.000000     0.000000
#
#                      modelFlux_r  ...  psfMag_i  psfMag_z      expAB_u  \
# ...

# %%
df.nunique()
# Out:
# ra              99998
# dec             99998
# u               88195
# g               87212
# r               86341
# i               86606
# z               87317
# modelFlux_u     99311
# modelFlux_g     99523
# modelFlux_r     99232
# modelFlux_i     98970
# modelFlux_z     99250
# petroRad_u      93340
# petroRad_g      98537
# petroRad_i      99351
# petroRad_r      99205
# petroRad_z      99062
# petroFlux_u     99347
# petroFlux_g     99550
# petroFlux_i     98911
# petroFlux_r     99243
# petroFlux_z     99115
# petroR50_u      97416
# petroR50_g      98685
# petroR50_i      98664
# petroR50_r      98771
# petroR50_z      97702
# psfMag_u        86415
# psfMag_r        86267
# psfMag_g        86110
# psfMag_i        86804
# psfMag_z        86519
# expAB_u         92592
# expAB_g         97955
# expAB_r         98490
# expAB_i         98472
# expAB_z         96524
# subclass            2
# redshift        99260
# redshift_err    98738
# dtype: int64

# %%
from umap import UMAP
from plotly import express

columns = [column for column in df.columns if column != 'subclass']

reducer = UMAP(n_components=2, random_state=2024, transform_seed=2024, verbose=True, n_jobs=1, n_epochs=100)
df[['x', 'y']] = pd.DataFrame(data=reducer.fit_transform(X=df[columns].fillna(value=0)))
express.scatter(data_frame=df, x='x', y='y', color='subclass', height=800, )
# Out:
# 2024-03-05 16:05:27.868888: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-05 16:05:27.869185: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-05 16:05:28.045660: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# UMAP(n_epochs=100, n_jobs=1, random_state=2024, transform_seed=2024, verbose=True)
# Tue Mar  5 16:05:43 2024 Construct fuzzy simplicial set
# Tue Mar  5 16:05:43 2024 Finding Nearest Neighbors
# Tue Mar  5 16:05:43 2024 Building RP forest with 21 trees
# Tue Mar  5 16:05:51 2024 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# ...
