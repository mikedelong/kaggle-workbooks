# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/civil-conflict-ceasefires/ceasefires_dataset.csv', 
                 index_col=['id']).drop(columns=['evidence_onset', 'evidence_end', 'comment', 'factivia_source'])
df.head(10)
# Out:
#     cc  cf_id  uniq_id location  region  link  ucdp_actor_id  \
# id
# 1   70      1    70001   Mexico       5     0             10
# 2   70      2    70002   Mexico       5     0            767
# 3   70      3    70003   Mexico       5     0            767
# 4   70      4    70004   Mexico       5     1            767
# 5   70      5    70005   Mexico       5     1            767
# 6   70      6    70006   Mexico       5     1            767
# 7   70      7    70007   Mexico       5     0             10
# 8   70      8    70008   Mexico       5     0            768
# 9   70      9    70009   Mexico       5     0            768
# 10  70     10    70010   Mexico       5     0            768
#
#               actor_name  ucdp_acd_id  ucdp_dyad  ...  link_id27  link_id28  \
# id                                                ...
# 1   Government of Mexico          400      850.0  ...          0        NaN
# 2                   EZLN          400      850.0  ...          0        0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4091 entries, 1 to 4091
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cc               4091 non-null   int64
#  1   cf_id            4091 non-null   int64
#  2   uniq_id          4091 non-null   int64
#  3   location         4091 non-null   object
#  4   region           4091 non-null   int64
#  5   link             4091 non-null   int64
#  6   ucdp_actor_id    4091 non-null   int64
#  7   actor_name       4091 non-null   object
#  8   ucdp_acd_id      4091 non-null   int64
#  9   ucdp_dyad        4090 non-null   float64
#  10  pax_id           4091 non-null   int64
#  11  cf_dec_yr        4091 non-null   int64
#  12  cf_dec_month     4091 non-null   int64
#  13  cf_dec_day       4091 non-null   int64
#  14  cf_effect_yr     4091 non-null   int64
#  15  cf_effect_month  4091 non-null   int64
#  16  cf_effect_day    4091 non-null   int64
# ...

# %%
df.nunique()
# Out:
# cc             66
# cf_id         194
# uniq_id      2203
# location       66
# region          5
#              ...
# link_id32       3
# link_id33       2
# link_id34       2
# link_id35       2
# coder          23
# Length: 82, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# 4    1347
# 3    1211
# 1     754
# 2     676
# 5     103
# Name: count, dtype: int64
