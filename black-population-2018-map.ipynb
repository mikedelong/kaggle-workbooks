# %%
import pandas as pd
from plotly.express import choropleth
choropleth(data_frame=pd.read_csv(filepath_or_buffer='/kaggle/input/percent-black-population-for-every-state-in-usa/percent_black_in_2018.csv').drop(columns=['State']), locations='State Code', color='Percent Black', projection='albers usa', locationmode='USA-states', title='US Black population (pct), 2018')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from plotly.express import line
df = pd.read_csv(filepath_or_buffer='/kaggle/input/percent-black-population-for-every-state-in-usa/percent_black_over_time.csv')

# we need to transpose the data to look at the time series, and we need to fix the headers
t_df = df.T.copy()
header = t_df.iloc[0]
t_df = t_df[1:] 
t_df.columns = header 
for column in t_df.columns:
    t_df[column] = t_df[column].str.replace(r'%', r'').astype('float')
line(data_frame=t_df.reset_index(), x='index', y=t_df.columns, height=1300, log_y=False)
# Out:
# <div>                            <div id="47abf4fb-5780-4983-9a3e-537117400806" class="plotly-graph-div" style="height:1300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47abf4fb-5780-4983-9a3e-537117400806")) {                    Plotly.newPlot(                        "47abf4fb-5780-4983-9a3e-537117400806",                        [{"hovertemplate":"variable=United States of America\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States of America","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States of America","showlegend":true,"x":["1790","1800","1810","1820","1830","1840","1850","1860","1870","1880","1890","1900","1910","1920","1930","1940","1950","1960","1970","1980","
# ...

# %% [markdown]
# This chart has to be massive to include all 57 rows; are we more interested in variation across the states with higher percentages or the ones with lower percentages? Because we can either see the high ones clearly (log_y=False) or the low ones clearly (log_y=True) but not both.

# %%
from plotly.express import scatter
scatter(data_frame=t_df.mean().to_frame().reset_index().merge(right=t_df.std().to_frame().reset_index(), on='State/Territory').rename(columns={'0_x': 'mean', '0_y': 'stddev'}),
        x='mean', y='stddev', hover_name='State/Territory', color='mean', )
# Out:
# <div>                            <div id="a4116760-3c80-4b1a-90f6-2ccdc46f0f6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4116760-3c80-4b1a-90f6-2ccdc46f0f6d")) {                    Plotly.newPlot(                        "a4116760-3c80-4b1a-90f6-2ccdc46f0f6d",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003emean=%{marker.color}\u003cbr\u003estddev=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["United States of America","Alabama","Alaska","American Samoa","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","District of Columbia","Florida","Georgia","Guam","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland
# ...

# %% [markdown]
# Essentially all of the states or territories with high means also have relatively high variability except for the US Virgin Islands.
