# %%
import pandas as pd
ZEPHYR = '/kaggle/input/q-and-a-with-zephyr-7b/zephyr.json'
df = pd.read_json(lines=True, path_or_buf=ZEPHYR)
df['prompt token count'] = df['prompt'].str.split().str.len()
df['response token count'] = df['response'].str.split().str.len()
df.head()
# Out:
#                                               prompt  \
# 0  Delve into the intricate ways Histochemistry i...
# 1  How does Chemical engineering intersect with t...
# 2  What are the implications of Outline of paraps...
# 3  How does Phytopathology influence the developm...
# 4  Delve into the detailed ethical dilemmas posed...
#
#                                             response  prompt token count  \
# 0  Histochemistry, the study of the chemical comp...                  10
# 1  Chemical engineering plays a significant role ...                  11
# 2  The "Outline of parapsychology" is a scientifi...                  11
# 3  Phytopathology, the scientific study of plant ...                   9
# 4  The insurance industry has witnessed significa...                  11
#
#    response token count
# 0                   546
# 1                   226
# 2                   276
# 3                   107
# 4                   477

# %%
df.shape
# Out:
# (179759, 4)

# %%
# %env TOKENIZERS_PARALLELISM=false
# !pip install --quiet keybert
print('pip install keybert complete.')
# Out:
# env: TOKENIZERS_PARALLELISM=false
# pip install keybert complete.

# %%
df.nunique()
# Out:
# prompt                  168394
# response                179759
# prompt token count          22
# response token count      1198
# dtype: int64

# %%
prompt_df = df[['prompt']].drop_duplicates(ignore_index=True).copy().sample(n=20000, random_state=2024)

# %%
from arrow import now
from keybert import KeyBERT
from sklearn.feature_extraction.text import TfidfVectorizer

MAX_DF = 1.0
MIN_DF = 10 # we have a lot of documents so we can contract our token space somewhat without fear
MODEL = 'all-MiniLM-L12-v2'
STOP_WORDS = 'english'
# we use the clean text for keywords even though we show a truncated original message
DOCS = prompt_df['prompt'].values.tolist()

model_start = now()
model = KeyBERT(model=MODEL,)
# we will capture almost all of the content with the default max sequence length of 128
vectorizer = TfidfVectorizer(ngram_range=(1, 1), stop_words=STOP_WORDS, min_df=MIN_DF, max_df=MAX_DF, )
document_embeddings, word_embeddings = model.extract_embeddings(docs=DOCS, vectorizer=vectorizer, )
print('embedding time: {}'.format(now() - model_start))
print('we have {} documents and {} words.'.format(len(document_embeddings), len(word_embeddings)))
keywords = model.extract_keywords(docs=DOCS, top_n=1, stop_words=STOP_WORDS, vectorizer=vectorizer,
                                  doc_embeddings=document_embeddings, word_embeddings=word_embeddings, min_df=MIN_DF, )
print('model time: {}'.format(now() - model_start))
prompt_df['keyword'] = [keyword[0][0] if len(keyword) else '-none-' for keyword in keywords]
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# embedding time: 0:03:12.109555
# we have 20000 documents and 1333 words.
# model time: 0:03:28.704075

# %%
prompt_df['keyword'].value_counts(normalize=True).head(n=20)
# Out:
# keyword
# sociology         0.02585
# archaeology       0.01870
# psychology        0.01360
# anthropology      0.01340
# ethical           0.01290
# cultural          0.01270
# ethics            0.01230
# economics         0.01190
# history           0.01090
# chemistry         0.00970
# quantum           0.00935
# climate           0.00885
# engineering       0.00885
# geography         0.00860
# economic          0.00770
# astronomy         0.00720
# governance        0.00645
# technology        0.00615
# environmental     0.00595
# sustainability    0.00595
# Name: proportion, dtype: float64

# %%
from plotly.express import histogram
histogram(data_frame=prompt_df[prompt_df['keyword'] != '-none-']['keyword'].value_counts().to_frame().reset_index().head(n=40), x='keyword', y='count', marginal='box')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="91699836-e392-4f40-81d7-50ca6fbf5301" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91699836-e392-4f40-81d7-50ca6fbf5301")) {                    Plotly.newPlot(                        "91699836-e392-4f40-81d7-50ca6fbf5301",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"keyword=%{x}\u003cbr\u003esum of count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["sociology","archaeology","psychology","anthropology","ethical","cultural","ethics","economics","history","chemistry","quantum","climate","engineering","geography","economic","astronomy","governance","technology","environmental","sustainability","theory","music","linguistics","technological","consciousness","physics","sustainable","biology","innovation","architecture","philosophy","literature","diplomacy","interdisciplinary","ecology","education","historical","art","health","philosophical"],"xaxis":"x","y":[517,374,272,268,258,254,246,238,218,194,187,177,177,172,154,144,129,123,119,119,118,118,117,116,115,112,111,110,109,109,103,101,100,94,92,92,90,87,87,87],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"keyword=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":["sociology","archaeology","psychology","anthropology","ethical","cultural","ethics","economics","history","chemistry","quantum","climate","engineering","geography","economic","astronomy","governance","technology","environmental","sustainability","theory","music","linguistics","technological","consciousness","physics","sustainable","biology","innovation","architecture","philosophy","literature","diplomacy","interdisciplinary","ecology","education","historical","art","health","philosophical"],"xaxis":"x2","yaxis":"y2","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type": ...

# %%
import pandas as pd
from umap import UMAP

IGNORE = {'-none-', }

umap_start = now()
umap_model = UMAP(n_components=2, random_state=2024, verbose=False, n_jobs=1)
prompt_df[['u0', 'u1']] = umap_model.fit_transform(X=document_embeddings)
print('UMAP time: {}'.format(now() - umap_start))
# Out:
# UMAP time: 0:00:56.810576

# %%
prompt_df.head()
# Out:
#                                                    prompt      keyword  \
# 34551   What are the implications of Digital Marketing...    marketing
# 54975   How does Jewish studies interact with the envi...  environment
# 100544  What are some common myths and truths in Socio...     religion
# 144655  What are the key skills needed to excel in Anc...        egypt
# 47362   Detail the impact of Health informatics on sha...  informatics
#
#                u0         u1
# 34551   10.612553   9.961064
# 54975   11.373621  11.424912
# 100544   9.142626  11.945827
# 144655   7.924094  12.861188
# 47362    7.809591   8.158966

# %%
from plotly.express import scatter
top_keywords = prompt_df[prompt_df['keyword'] != '-none-']['keyword'].value_counts().head(n=12).index.tolist()
top_df = prompt_df[prompt_df['keyword'].isin(top_keywords)]
scatter(data_frame=top_df, x='u0', y='u1', hover_name='prompt', color='keyword' ).update_xaxes(showticklabels=False).update_yaxes(showticklabels=False).update_xaxes(visible=False).update_yaxes(visible=False)
# Out:
# <div>                            <div id="880f3acb-d83b-4c07-93ba-a83a9cc5f888" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("880f3acb-d83b-4c07-93ba-a83a9cc5f888")) {                    Plotly.newPlot(                        "880f3acb-d83b-4c07-93ba-a83a9cc5f888",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ekeyword=sociology\u003cbr\u003eu0=%{x}\u003cbr\u003eu1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["How does Sociology of the family shape the future of global commerce and trade?","How does Sociology of the Internet interact with the fields of art and culture?","How has Sociology of film influenced philosophical thought?","What are the legal aspects of Economic sociology?","What are the impacts of Economic sociology on the theory of universal connectedness?","Explain the intersection of Sociology of law with the study of ethics and morality.","How does Theoretical sociology affect the global discourse on human rights?","Explain the role of Cultural sociology in the future of healthcare.","Explain the role of Sociology of scientific knowledge in developing new business models.","What role does Edit section: Sociology play in understanding human behavior and cognition?","Describe a hobby related to Sociology of the family.","Describe how Theoretical sociology is revolutionizing the entertainment industry.","What are innovative approaches in Jealousy sociology?","Detail the intricate legal aspects and regulations pertaining to Sociology of the family.","What are the ethical considerations in the advancement of Economic sociology?","How does Visual sociology interact with modern scientific discoveries?","How does Critical sociology intersect with ethics in technology?","How does Visual sociology influence the development of new technologies?","Explain the role of Sociology of the family in conflict and peace studies.","Explain how Sociology of space shapes our understanding of history.","How does Marxist sociology intersect with the challenges of aging populations?","What are the connections between Sociology and global health?","How does Computational sociology interact with other scientific fields?","How does Edit section: Sociology affect mental health?","What are the implications of Sociology of the history of science on future generations?","Describe how Digital sociology influences urban planning and design.","How does Critical sociology shape the future of transportation?","How has Urban sociology evolved in response to technological advancements?","How does Environmental sociology differ in various cultures?","Explain the relationship between Comparative sociology and the exploration of consciousness.","Discuss the extensive influence of Policy sociology on personal identity formation,","How does Sociology of scientific knowledge contribute to understanding global cultures?","How is Comparative sociology being transformed by digital innovations?","Describe a critical issue in Sociology of food.","Detail the comprehensive strategies employed in research and practice of Visual sociology,","How does Phenomenological sociology intersect with the development of drones?","How has Polish sociology evolved over time?","What are the innovative teaching methods for Public sociology?","How does Sociology of the history of science influence the development of new materials?","How does Chinese sociology impact the development of personal and collective identity?","How does Architectural sociology affect mental health?","How does Sociology of art affect the development of educational methodologies?","Explain the role of Urban sociology in addressing global health crises.","What challenges does Historical sociolo ...

# %% [markdown]
# Let's take our top prompts with top keywords and go back to our original data to get the responses.

# %%
top_response_df = top_df.merge(right=df, on='prompt', how='inner').drop(columns=['prompt token count', 'response token count'])
top_response_df.head()
# Out:
#                                               prompt      keyword         u0  \
# 0  How does Sociology of the family shape the fut...    sociology  13.131643
# 1  Explain the role of Faculty (division) in the ...      ethical   7.598007
# 2  Investigate the role of Biblical archaeology i...  archaeology   7.362773
# 3  How does Dendrochronology influence the evolut...     cultural  10.139025
# 4  Explore the detailed ethical challenges and de...      ethical   8.590603
#
#           u1                                           response
# 0   8.422988  The Sociology of the Family does not directly ...
# 1   9.709886  Faculty (division) plays a crucial role in sha...
# 2  12.497229  The role of Biblical archaeology in the future...
# 3  12.163044  Dendrochronology, which is the scientific stud...
# 4   9.110418  Linear programming (LP) is a mathematical opti...

# %% [markdown]
# And use the model above to get the response keywords.

# %%
time_start = now()
RESPONSES = top_response_df['response'].values.tolist()
response_document_embeddings, response_word_embeddings = model.extract_embeddings(docs=RESPONSES, vectorizer=vectorizer, )

top_response_df[['response keyword']] = model.extract_keywords(docs=RESPONSES, 
                                                              top_n=1, stop_words=STOP_WORDS, vectorizer=vectorizer, 
                                                              doc_embeddings=response_document_embeddings, 
                                                              word_embeddings=response_word_embeddings, min_df=MIN_DF, )
top_response_df['response keyword'] = [keyword[0][0] if len(keyword) else '-none-' for keyword in top_response_df['response keyword'].values.tolist()]
print('got response keywords in {}'.format(now() - time_start))
# Out:
# got response keywords in 0:04:23.566598

# %% [markdown]
# How often do we get the same keywords for both prompt and response?

# %%
top_response_df.head()
# Out:
#                                               prompt      keyword         u0  \
# 0  How does Sociology of the family shape the fut...    sociology  13.131643
# 1  Explain the role of Faculty (division) in the ...      ethical   7.598007
# 2  Investigate the role of Biblical archaeology i...  archaeology   7.362773
# 3  How does Dendrochronology influence the evolut...     cultural  10.139025
# 4  Explore the detailed ethical challenges and de...      ethical   8.590603
#
#           u1                                           response  \
# 0   8.422988  The Sociology of the Family does not directly ...
# 1   9.709886  Faculty (division) plays a crucial role in sha...
# 2  12.497229  The role of Biblical archaeology in the future...
# 3  12.163044  Dendrochronology, which is the scientific stud...
# 4   9.110418  Linear programming (LP) is a mathematical opti...
#
#   response keyword
# 0                s
# 1                e
# 2                a
# 3                t
# 4                e
