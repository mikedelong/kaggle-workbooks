# %%
import pandas as pd

NFLX = '/kaggle/input/netflix-stock-price-dataset/Netflix Dataset.csv'
df = pd.read_csv(filepath_or_buffer=NFLX, parse_dates=['Date'])
df['year'] = df['Date'].dt.year
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume  \
# 0 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200
#
#    year
# 0  2002
# 1  2002
# 2  2002
# 3  2002
# 4  2002

# %% [markdown]
# On a split-adjusted basis the stock has gained so much we need to use a log plot to see any change in the early years.

# %%
from plotly import express

express.line(data_frame=df, x='Date', y=['Open', 'High', 'Low', 'Close'], log_y=True).show()
express.line(data_frame=df, x='Date', y=['Close', 'Adj Close'], log_y=True).show()
express.line(data_frame=df, x='Date', y='Volume', log_y=True).show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# It is interesting to see that as the stock price has risen the volume has declined.

# %%
express.scatter(data_frame=df, x='Date', y='Volume', trendline='lowess', log_y=True, color='year')
# Out:
# <div>                            <div id="39600284-21e8-40fe-9fb2-89f547e85a39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39600284-21e8-40fe-9fb2-89f547e85a39")) {                    Plotly.newPlot(                        "39600284-21e8-40fe-9fb2-89f547e85a39",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eVolume=%{y}\u003cbr\u003eyear=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,200
# ...

# %%
express.scatter(data_frame=df, x='Date', y='Adj Close', trendline='lowess', color='year', log_y=True)
# Out:
# <div>                            <div id="7a129ebe-2c7e-4ae6-b424-a5cf53bb6edd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a129ebe-2c7e-4ae6-b424-a5cf53bb6edd")) {                    Plotly.newPlot(                        "7a129ebe-2c7e-4ae6-b424-a5cf53bb6edd",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eAdj Close=%{y}\u003cbr\u003eyear=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,
# ...

# %%
express.scatter(data_frame=df[['Date', 'Adj Close']].set_index(keys=['Date']).resample('ME').mean().reset_index(), x='Date', y='Adj Close', trendline='lowess', log_y=True)
# Out:
# <div>                            <div id="387b6687-2315-4608-a5cd-93f411ff235b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("387b6687-2315-4608-a5cd-93f411ff235b")) {                    Plotly.newPlot(                        "387b6687-2315-4608-a5cd-93f411ff235b",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eAdj Close=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2002-05-31T00:00:00","2002-06-30T00:00:00","2002-07-31T00:00:00","2002-08-31T00:00:00","2002-09-30T00:00:00","2002-10-31T00:00:00","2002-11-30T00:00:00","2002-12-31T00:00:00","2003-01-31T00:00:00","2003-02-28T00:00:00","2003-03-31T00:00
# ...

# %%
express.scatter(data_frame=df, x='Volume', y='Adj Close', color='year', log_x=True, log_y=True)
# Out:
# <div>                            <div id="aa8bcd83-7727-4387-9fca-4e5315dc0649" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa8bcd83-7727-4387-9fca-4e5315dc0649")) {                    Plotly.newPlot(                        "aa8bcd83-7727-4387-9fca-4e5315dc0649",                        [{"hovertemplate":"Volume=%{x}\u003cbr\u003eAdj Close=%{y}\u003cbr\u003eyear=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,200
# ...
