# %%
# %env TOKENIZERS_PARALLELISM=false
# !pip install --quiet keybert
print('pip install keybert complete')
# Out:
# env: TOKENIZERS_PARALLELISM=false
# pip install keybert complete

# %%
from urllib import request
url = 'https://www.gutenberg.org/cache/epub/56796/pg56796.txt'
lines = [line.decode('utf-8') for line in request.urlopen(url=url)]
print(len(lines))
text = ' '.join(lines).replace('\n', ' ').replace('\r', ' ')
text = ' '.join(text.split())
# Out:
# 8355

# %%
import nltk.data

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
sentences = list(tokenizer.tokenize(text))
print(len(sentences))
# Out:
# 2668

# %%
# remove boilerplate
sentences = sentences[13:-120]

# %%
from arrow import now
from keybert import KeyBERT
from sklearn.feature_extraction.text import CountVectorizer

MIN_DF = 3
MODEL = 'all-MiniLM-L12-v2'
STOP_WORDS = 'english'

model_start = now()
model = KeyBERT(model=MODEL,)
# model.max_seq_length = 512
vectorizer = CountVectorizer(ngram_range=(1, 2), stop_words=STOP_WORDS, min_df=MIN_DF,)
document_embeddings, word_embeddings = model.extract_embeddings(docs=sentences, vectorizer=vectorizer, )
print('embedding time: {}'.format(now() - model_start))
print('we have {} documents and {} words.'.format(len(document_embeddings), len(word_embeddings)))
keywords = model.extract_keywords(docs=sentences, top_n=1, stop_words=STOP_WORDS, vectorizer=vectorizer,
                                  doc_embeddings=document_embeddings, word_embeddings=word_embeddings, min_df=MIN_DF, )
print('model time: {}'.format(now() - model_start))
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# embedding time: 0:01:01.604893
# we have 2535 documents and 2913 words.
# model time: 0:01:04.781363

# %%
import pandas as pd
from plotly.express import scatter
from umap import UMAP

umap_start = now()
umap_model = UMAP(n_components=2, random_state=2024, verbose=False, n_jobs=1)
df = pd.DataFrame(data=umap_model.fit_transform(X=document_embeddings), columns=['u0', 'u1'])
df['text'] = sentences
df['short text'] = [' '.join(item.split()[:20]) for item in sentences]
df['keyword'] = [keyword[0][0] if len(keyword) else '-none-' for keyword in keywords]
IGNORE = {'-none-', 'section', 'paragraph'}
scatter(data_frame=df[~df['keyword'].isin(IGNORE)], x='u0', y='u1', hover_name='short text',
        height=900, hover_data=['keyword']
       ).show()
print('UMAP time: {}'.format(now() - umap_start))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="8d5712be-aee8-4f16-af7b-29363e0271d4" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d5712be-aee8-4f16-af7b-29363e0271d4")) {                    Plotly.newPlot(                        "8d5712be-aee8-4f16-af7b-29363e0271d4",                        [{"customdata":[["index"],["abbreviations"],["abbreviations"],["bachelor"],["year"],["arts"],["barrel"],["agriculture"],["christ"],["bachelor"],["bachelor"],["mus"],["pd"],["philosophy"],["bachelor"],["sc"],["capt"],["civil"],["col"],["district columbia"],["law"],["doctor"],["doctor"],["litt"],["mus"],["philosophy"],["doctor"],["doctor"],["doctor"],["electricity"],["electrical"],["board"],["army"],["general"],["governor"],["doctor"],["doctor"],["peace"],["jr"],["latitude"],["lb"],["litt"],["bachelor"],["litt"],["literature"],["ll"],["bachelor"],["ll"],["doctor"],["agriculture"],["congress"],["doctor"],["canada"],["master"],["mus"],["bachelor"],["mus"],["doctor"],["pd"],["bachelor"],["pd"],["pedagogy"],["ph"],["bachelor"],["ph"],["philosophy"],["office"],["professor"],["reverend"],["sc"],["bachelor"],["sc"],["doctor"],["bachelor"],["theology"],["right"],["reverend"],["reverend"],["yard"],["year"],["gas"],["composed"],["adventists"],["100 000"],["instrument"],["winds"],["box"],["stretched"],["50"],["age"],["60 years"],["age"],["average"],["percentage"],["industry"],["60 000"],["alaska"],["square miles"],["climate"],["algebra"],["inventor"],["spain"],["algebra"],["algebra"],["origin"],["amazons"],["marriage"],["burned"],["amazons"],["apostles"],["apostles"],["latin"],["catholic church"],["april"],["day"],["public schools"],["trees"],["arithmetic"],["artesian"],["oldest"],["paris"],["gallons"],["feet deep"],["invention"],["artificial ice"],["artificial ice"],["years"],["atlantic cable"],["cable"],["cable laid"],["atlantic cable"],["maintained"],["electricity"],["batteries"],["current"],["currents"],["messages"],["instrument"],["lamp"],["needle"],["telegraphic"],["superseded"],["needle"],["needle"],["ink"],["tube"],["ink"],["letters"],["cable"],["professor morse"],["field"],["wires"],["cable"],["wires"],["steamers"],["cable"],["cable"],["pieces"],["cable"],["ocean"],["cable"],["break injury"],["cable"],["cable"],["sails"],["sail"],["cable"],["break"],["vessel"],["cable"],["cable"],["break injury"],["batteries"],["receiving"],["break"],["break injury"],["simplest"],["scientific"],["altitude"],["atmosphere"],["aurora"],["electricity"],["poles"],["automobiles"],["automobile"],["million"],["bank"],["treasury"],["governor"],["prison"],["destroyed"],["seat"],["festival"],["1876"],["bible"],["translated"],["bible"],["bible"],["bible"],["silver"],["stones"],["half"],["males"],["temperature"],["arctic"],["likely"],["animals"],["maintain"],["grass region"],["lime"],["soil"],["tobacco"],["grass"],["grass region"],["boxers"],["boxers"],["brain"],["brain"],["brain"],["volume"],["brain"],["brain"],["female"],["brains"],["size brain"],["brains"],["size brain"],["bread"],["bread"],["foods"],["trade"],["grain"],["grain"],["farm"],["acres"],["1846"],["nathaniel"],["cent"],["cent"],["divide product"],["days"],["sum"],["month"],["feb"],["june"],["february"],["miles long"],["100 000"],["canal"],["cost"],["canal"],["40 000"],["panama canal"],["canal"],["canal"],["canal"],["gallons"],["east"],["length"],["square feet"],["copper"],["iron"],["weight"],["dome"],["dome"],["height"],["feet inches"],["height"],["senate"],["000"],["representatives"],["chamber"],["court"],["celluloid"],["paper"],["acid"],["camphor"],["steam"],["celluloid"],["celluloid"],["certified"],["liable"],["certified"],["average weight"],["iron"],["origin"],["persia"],["invented"],["festival"],["98"],["april"],["december"],["circulation"],["climate"],["equator"],["poles ...
# UMAP time: 0:00:24.721034

# %%
df['keyword'].value_counts().head(n=50)
# Out:
# keyword
# -none-                    94
# patient                   18
# physician                 16
# mls                       14
# doctor                    13
# temperature               13
# cable                     12
# bachelor                  11
# bleeding                  11
# square miles              11
# artificial respiration    10
# exercise                  10
# electricity               10
# wound                     10
# 1898                      10
# bath                      10
# pa                         9
# vomiting                   8
# height                     8
# patent medicines           8
# soap                       7
# tunnel                     7
# postage cents              7
# bandages                   7
# miles                      7
# poison                     7
# breathing                  7
# physicians                 7
# invented                   7
# consult physician          6
# cloth                      6
# surgeon                    6
# climate                    6
# earthquakes                6
# summon physician           6
# sick room                  6
# bible                      6
# literature                 6
# ocean                      6
# moon                       6
# nose                       6
# medicine                   6
# brain                      6
# shot                       5
# air                        5
# newspapers                 5
# partnership                5
# fainting                   5
# tongue                     5
# stomach                    5
# Name: count, dtype: int64

# %%
import numpy as np
from plotly.express import scatter
from plotly.graph_objects import Figure

def plot_words(arg_words: list, arg_keywords: list, arg_model: UMAP, arg_embeddings: np.ndarray) -> Figure:
    top_indices = [arg_words.tolist().index(keyword) for keyword in arg_keywords]
    result_df = pd.DataFrame(data=arg_model.transform(X=[arg_embeddings[index] for index in top_indices]), 
                             columns=['u0', 'u1'])
    result_df['word'] = arg_keywords
    return scatter(data_frame=result_df, x='u0', y='u1', text='word', height=900).update_traces(marker={'size': 3})

plot_words(arg_words=vectorizer.get_feature_names_out(),
           arg_keywords=[key for key, value in df['keyword'].value_counts().head(n=100).to_dict().items() if key != '-none-'],
           arg_model=umap_model, arg_embeddings=word_embeddings).show()
# Out:
# <div>                            <div id="fbd1f93d-561d-4e4e-979d-ce6e6129b1cc" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f