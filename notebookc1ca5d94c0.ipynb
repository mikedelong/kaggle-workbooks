# %%
import pandas as pd
import numpy as np
df = pd.read_csv(filepath_or_buffer='/kaggle/input/indian-prime-ministers-performance-data/Indian_Prime_Miniters.csv')
df = df.replace(to_replace={'Not available': np.nan})
df.head()

# %%
df.info()
