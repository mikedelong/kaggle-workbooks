# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/the-economists-big-mac-index/big-mac-adjusted-index.csv', parse_dates=['date'])
df['year'] = df['date'].dt.year
df.head()
# Out:
#         date iso_a3 currency_code       name  local_price  dollar_ex  \
# 0 2000-04-01    ARG           ARS  Argentina         2.50   1.000000
# 1 2000-04-01    AUS           AUD  Australia         2.59   1.680000
# 2 2000-04-01    BRA           BRL     Brazil         2.95   1.790000
# 3 2000-04-01    GBR           GBP    Britain         1.90   0.632911
# 4 2000-04-01    CAN           CAD     Canada         2.85   1.470000
#
#    dollar_price    GDP_bigmac  adj_price      USD  EUR      GBP      JPY  \
# 0      2.500000   7803.328512   1.922652  0.39117  NaN -0.06626  0.10096
# 1      1.541667  29144.876973   2.301550 -0.28335  NaN -0.51898 -0.43285
# 2      1.648045   4822.738983   1.869734 -0.05696  NaN -0.36704 -0.25369
# 3      3.002000  20932.924968   2.155755  0.48988  NaN  0.00000  0.17908
# 4      1.938776  26087.329235   2.247266 -0.07698  NaN -0.38047 -0.26953
#
#        CNY  year
# 0  0.97153  2000
# 1  0.01563  2000
# 2  0.33645  2000
# 3  1.11143  2000
# 4  0.30809  2000

# %%
# how many years of data do we have and how many datapoints per year?
from plotly.express import histogram
histogram(data_frame=df, x='year')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from plotly.express import choropleth
choropleth(data_frame=df[df['year'] == 2022], locations='iso_a3', color='dollar_price', hover_name='name', title='2022 global Big Mac dollar prices')
# Out:
# <div>                            <div id="7043ce34-a22c-4361-bd51-cbccb5ea1252" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7043ce34-a22c-4361-bd51-cbccb5ea1252")) {                    Plotly.newPlot(                        "7043ce34-a22c-4361-bd51-cbccb5ea1252",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eiso_a3=%{location}\u003cbr\u003edollar_price=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Argentina","Australia","Azerbaijan","Bahrain","Brazil","Britain","Canada","Chile","China","Colombia","Costa Rica","Croatia","Czech Republic","Denmark","Egypt","Euro area","Guatemala","Honduras","Hong Kong","Hungary","India","Indonesia",
# ...

# %% [markdown]
# I think we would like to get an idea of how Big Mac prices cluster or diverge over time on a year x country basis. A big line plot seems like a good idea.

# %%
from plotly.express import line
line(data_frame=df, x='date', y='dollar_price', color='name')
# Out:
# <div>                            <div id="790cb776-7e8b-473e-a1cf-ddf576c2711b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("790cb776-7e8b-473e-a1cf-ddf576c2711b")) {                    Plotly.newPlot(                        "790cb776-7e8b-473e-a1cf-ddf576c2711b",                        [{"hovertemplate":"name=Argentina\u003cbr\u003edate=%{x}\u003cbr\u003edollar_price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Argentina","showlegend":true,"x":["2000-04-01T00:00:00","2001-04-01T00:00:00","2002-04-01T00:00:00","2003-04-01T00:00:00","2004-05-01T00:00:00","2005-06-01T00:00:00","2006-01-01T00:00:00","2006-05-01T00:00:00","2007-01-
# ...

# %% [markdown]
# We can sort of see the general trend and the divergence from it over time; let's add a scatter plot with a non-linear trendline.

# %%
from plotly.express import scatter
scatter(data_frame=df, x='date', y='dollar_price', color='name', trendline='lowess', trendline_scope='overall')
# Out:
# <div>                            <div id="f01975c8-6b38-49de-8558-82a4172b726c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f01975c8-6b38-49de-8558-82a4172b726c")) {                    Plotly.newPlot(                        "f01975c8-6b38-49de-8558-82a4172b726c",                        [{"hovertemplate":"name=Argentina\u003cbr\u003edate=%{x}\u003cbr\u003edollar_price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Argentina","showlegend":true,"x":["2000-04-01T00:00:00","2001-04-01T00:00:00","2002-04-01T00:00:00","2003-04-01T00:00:00","2004-05-01T00:00:00","2005-06-01T00:00:00","2006-01-01T00:00:00","2006-05-01T00:00:00","2007-01-01T00:00:00","2007-06-
# ...
