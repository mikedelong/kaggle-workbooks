# %%
TRAIN = '/kaggle/input/datasets/parvezkabir221155539/rose-leaf-disease-dataset/Precessed_Rose_Leaf_Dataset/Precessed_Rose_Leaf_Dataset/Train'
TEST = '/kaggle/input/datasets/parvezkabir221155539/rose-leaf-disease-dataset/Precessed_Rose_Leaf_Dataset/Precessed_Rose_Leaf_Dataset/Test'
