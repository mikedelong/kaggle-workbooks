# %% [markdown]
# <a href="https://www.kaggle.com/code/mikedelong/understand-danger-with-scatter-plots?scriptVersionId=174340196" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/nasa-neo-near-earth-object-dataset/neo_data.csv', 
                 parse_dates=['Close Approach Date', 'Close Approach Date (Full)']).drop(columns=['NASA JPL URL'])
df['year'] = df['Close Approach Date'].dt.year
df.head()
# Out:
#         ID  Neo Reference ID                Name Limited Name  Designation  \
# 0  2000433           2000433  433 Eros (A898 PA)         Eros          433
# 1  2000433           2000433  433 Eros (A898 PA)         Eros          433
# 2  2000433           2000433  433 Eros (A898 PA)         Eros          433
# 3  2000433           2000433  433 Eros (A898 PA)         Eros          433
# 4  2000433           2000433  433 Eros (A898 PA)         Eros          433
#
#    Absolute Magnitude (H)  Min Diameter (km)  Max Diameter (km)  \
# 0                   10.41          22.006703          49.208483
# 1                   10.41          22.006703          49.208483
# 2                   10.41          22.006703          49.208483
# 3                   10.41          22.006703          49.208483
# 4                   10.41          22.006703          49.208483
#
#    Min Diameter (m)  Max Diameter (m)  ...  Epoch Date Close Approach  \
# ...

# %%
from plotly import express
columns = ['Limited Name', 'Orbiting Body']
express.bar(data_frame=df[columns].groupby(by=columns).size().reset_index().sort_values(ascending=False, by=0), x='Limited Name', y=0, color='Orbiting Body')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# Most of the Near Earth Objects mostly or entirely orbit Earth.

# %%
express.bar(data_frame=df, x='Limited Name', color='year')
# Out:
# <div>                            <div id="44559a73-71fe-42b8-8b4c-039170a4ff53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44559a73-71fe-42b8-8b4c-039170a4ff53")) {                    Plotly.newPlot(                        "44559a73-71fe-42b8-8b4c-039170a4ff53",                        [{"alignmentgroup":"True","hovertemplate":"Limited Name=%{x}\u003cbr\u003ecount=%{y}\u003cbr\u003eyear=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1900,1907,1917,1924,1931,1938,1944,1961,1968,1975,1981,1988,2005,2012,2019,2025,2042,2049,2056,2062,2069,2086,2093,2100,2106,2123,2130,2137,2144,2150,2167,2174,2181,2187,1909,1911,1941,1956,1971,2001,2003,2048,2050,2063,2078,2108,2110,2138,2157,2170,2185,1910,1914,1918,19
# ...

# %% [markdown]
# Here we learn that some of our data is historical and some of it is forecast.

# %%
express.histogram(data_frame=df[df['year'] <2024].sort_values(by='Limited Name'), x='year', color='Limited Name', nbins=124).show()
express.histogram(data_frame=df[df['year'] <2024].sort_values(by='Limited Name'), x='year', color='Is Potentially Hazardous', nbins=124).show()
# Out:
# <div>                            <div id="27d86f59-03df-4dcf-9cfa-80c062249179" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27d86f59-03df-4dcf-9cfa-80c062249179")) {                    Plotly.newPlot(                        "27d86f59-03df-4dcf-9cfa-80c062249179",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Limited Name=Albert\u003cbr\u003eyear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albert","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Albert","nbinsx":124,"offsetgroup":"Albert","orientation":"v","showlegend":true,"x":[2003,2001,1971,1956,1941,1911,1909],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate
# ...

# %% [markdown]
# If we look at just the historical data relative to 2023, we see that we do not have observations of every object every year.

# %%
express.scatter(data_frame=df.sort_values(by='Limited Name'), x='Limited Name', y='year', color='Miss Distance (km)')
# Out:
# <div>                            <div id="d8644f82-062e-4b64-8c1e-ed6a28bd3713" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8644f82-062e-4b64-8c1e-ed6a28bd3713")) {                    Plotly.newPlot(                        "d8644f82-062e-4b64-8c1e-ed6a28bd3713",                        [{"hovertemplate":"Limited Name=%{x}\u003cbr\u003eyear=%{y}\u003cbr\u003eMiss Distance (km)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[293085928.07566476,211999593.1458578,47085964.48368307,42582881.24031068,222392006.90369737,63678315.77663409,255628975.88870153,233945031.3203244,31933101.431212846,30767547.759604916,38425895.242266655,55016469.31252208,246002794.58207357,272693358.8610249,32922264.56845932,207934
# ...

# %% [markdown]
# This chart breaks out our data by object, but because most of the miss distances are clustered the color doesn't tell us much.

# %%
express.scatter(data_frame=df.sort_values(by='Limited Name'), x='Limited Name', y='year', color='Is Potentially Hazardous')
# Out:
# <div>                            <div id="390b5d6b-8b04-43c6-8a11-0c3af337fa6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("390b5d6b-8b04-43c6-8a11-0c3af337fa6c")) {                    Plotly.newPlot(                        "390b5d6b-8b04-43c6-8a11-0c3af337fa6c",                        [{"hovertemplate":"Is Potentially Hazardous=False\u003cbr\u003eLimited Name=%{x}\u003cbr\u003eyear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"False","orientation":"v","showlegend":true,"x":["Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Albert","Alinda","Alinda","Alinda","
# ...

# %% [markdown]
# This is what we really want to know: according to the dataset only three of these objects are potentially hazardous.

# %%
express.histogram(data_frame=df, x='Miss Distance (km)', facet_col='Is Potentially Hazardous',)
# Out:
# <div>                            <div id="9094fe09-1966-4d5f-8bc0-c7c29090aec6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9094fe09-1966-4d5f-8bc0-c7c29090aec6")) {                    Plotly.newPlot(                        "9094fe09-1966-4d5f-8bc0-c7c29090aec6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Is Potentially Hazardous=False\u003cbr\u003eMiss Distance (km)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[47112732.928149395,70533232.89379448,74687814.59975122,53823292.39421864,26040971.83587945,32164326.017637733,60289296.3832705,66195880.154
# ...

# %% [markdown]
# Distance and danger are only somewhat correlated: all dangerous objects are close, but not all close objects are dangerous.

# %%
express.histogram(data_frame=df, x='Relative Velocity (km/s)', facet_col='Is Potentially Hazardous',)
# Out:
# <div>                            <div id="c96cc0a5-21c5-4345-8d5f-ce0767094674" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c96cc0a5-21c5-4345-8d5f-ce0767094674")) {                    Plotly.newPlot(                        "c96cc0a5-21c5-4345-8d5f-ce0767094674",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Is Potentially Hazardous=False\u003cbr\u003eRelative Velocity (km\u002fs)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[5.5786191875,4.3944908885,4.8167840184,4.5960548855,5.9208185341,6.0840524046,3.626098636,3.7078364482,6.0668849725,5.8253076833
# ...

# %% [markdown]
# Similarly relative velocity and danger are not highly correlated; we might expect the more hazardous objects to be moving quickly, but the not-hazardous cohort is actually moving faster on average.

# %%
express.scatter(data_frame=df, y='Relative Velocity (km/s)', x='Miss Distance (km)', hover_name='Limited Name', size='Min Diameter (km)', color='year', log_x=True)
# Out:
# <div>                            <div id="ae15ba52-3cbb-40d1-a1a1-4bd74506b736" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae15ba52-3cbb-40d1-a1a1-4bd74506b736")) {                    Plotly.newPlot(                        "ae15ba52-3cbb-40d1-a1a1-4bd74506b736",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eMiss Distance (km)=%{x}\u003cbr\u003eRelative Velocity (km\u002fs)=%{y}\u003cbr\u003eMin Diameter (km)=%{marker.size}\u003cbr\u003eyear=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Er
# ...

# %% [markdown]
# If we plot distance, velocity, size, and time together we can sort of see orbits of specific objects in some cases.

# %%
express.scatter(data_frame=df, y='Relative Velocity (km/s)', x='Miss Distance (km)', hover_name='Limited Name', size='Min Diameter (km)', color='Is Potentially Hazardous', symbol='Orbiting Body', log_x=True)
# Out:
# <div>                            <div id="0038e471-42a1-413b-9f02-2ba0934286cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0038e471-42a1-413b-9f02-2ba0934286cb")) {                    Plotly.newPlot(                        "0038e471-42a1-413b-9f02-2ba0934286cb",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eIs Potentially Hazardous=False\u003cbr\u003eOrbiting Body=Earth\u003cbr\u003eMiss Distance (km)=%{x}\u003cbr\u003eRelative Velocity (km\u002fs)=%{y}\u003cbr\u003eMin Diameter (km)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","E
# ...

# %% [markdown]
# We can color the same plot by danger rather than year; this looks kind of cool but I'm not sure it tells us anything.

# %%
express.scatter(data_frame=df, x='year', y='Miss Distance (km)', hover_name='Limited Name', size='Min Diameter (km)', color='Is Potentially Hazardous', log_y=True)
# Out:
# <div>                            <div id="c92022b8-6ac2-41d9-932a-b9e7e24946f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c92022b8-6ac2-41d9-932a-b9e7e24946f8")) {                    Plotly.newPlot(                        "c92022b8-6ac2-41d9-932a-b9e7e24946f8",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eIs Potentially Hazardous=False\u003cbr\u003eyear=%{x}\u003cbr\u003eMiss Distance (km)=%{y}\u003cbr\u003eMin Diameter (km)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Eros","Ero
# ...

# %% [markdown]
# Similarly we can plot year x distance and the nearest near-miss events stand out, sort of.
