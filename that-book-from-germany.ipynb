# %%
# %env TOKENIZERS_PARALLELISM=false
# !pip install --quiet keybert
print('pip install keybert complete')
# Out:
# env: TOKENIZERS_PARALLELISM=false
# pip install keybert complete

# %%
from urllib import request

ENCODING = 'windows-1252'
url = 'https://gutenberg.net.au/ebooks02/0200601.txt'

response = request.urlopen(url=url)
lines = [line.decode(ENCODING) for line in request.urlopen(url=url)]
print(len(lines))
text = ' '.join(lines).replace('\n', ' ').replace('\r', ' ')
text = ' '.join(text.split())
# Out:
# 26912

# %%
import nltk.data

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
sentences = list(tokenizer.tokenize(text))
print(len(sentences))
# Out:
# 10381

# %%
# remove boilerplate text
sentences = sentences[13:-120]
# remove short sentences 
sentences = [sentence for sentence in sentences if len(sentence.split()) > 2]

# %%
from arrow import now
from keybert import KeyBERT
from sklearn.feature_extraction.text import CountVectorizer

MIN_DF = 3
MODEL = 'all-MiniLM-L12-v2'
STOP_WORDS = 'english'

model_start = now()
model = KeyBERT(model=MODEL,)
# model.max_seq_length = 512
vectorizer = CountVectorizer(ngram_range=(1, 2), stop_words=STOP_WORDS, min_df=MIN_DF,)
document_embeddings, word_embeddings = model.extract_embeddings(docs=sentences, vectorizer=vectorizer, )
print('embedding time: {}'.format(now() - model_start))
print('we have {} documents and {} words.'.format(len(document_embeddings), len(word_embeddings)))
keywords = model.extract_keywords(docs=sentences, top_n=1, stop_words=STOP_WORDS, vectorizer=vectorizer,
                                  doc_embeddings=document_embeddings, word_embeddings=word_embeddings, min_df=MIN_DF, )
print('model time: {}'.format(now() - model_start))
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# embedding time: 0:03:22.492663
# we have 10163 documents and 7984 words.
# model time: 0:03:37.939923

# %%
import pandas as pd
from plotly.express import scatter
from umap import UMAP

umap_start = now()
umap_model = UMAP(n_components=2, random_state=2024, verbose=False, n_jobs=1)
df = pd.DataFrame(data=umap_model.fit_transform(X=document_embeddings), columns=['u0', 'u1'])
df['text'] = sentences
df['short text'] = [' '.join(item.split()[:20]) for item in sentences]
df['keyword'] = [keyword[0][0] if len(keyword) else '-none-' for keyword in keywords]
IGNORE = {'-none-', 'section', 'paragraph'}
scatter(data_frame=df[~df['keyword'].isin(IGNORE)], x='u0', y='u1', hover_name='short text',
        height=900, hover_data=['keyword']
       ).show()
print('UMAP time: {}'.format(now() - umap_start))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="65f64d1e-47ca-440e-8ae2-eb2ec3c325c0" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65f64d1e-47ca-440e-8ae2-eb2ec3c325c0")) {                    Plotly.newPlot(                        "65f64d1e-47ca-440e-8ae2-eb2ec3c325c0",                        [{"customdata":[["doctrinaire"],["jewish press"],["followers movement"],["written word"],["principles"],["building stones"],["fortress landsberg"],["9th 1923"],["followers movement"],["mein kampf"],["mein kampf"],["did"],["stress"],["german empire"],["occupied ruhr"],["protested"],["versailles treaty"],["rhineland"],["money"],["bavaria"],["rhineland"],["bavaria"],["german austria"],["habsburg"],["rhineland"],["dream"],["dismemberment germany"],["aim"],["mein kampf"],["autumn 1923"],["reichswehr"],["flag german"],["9th 1918"],["hitler"],["munich"],["ludendorff"],["army"],["meeting announced"],["bavarian"],["ludendorff"],["meeting broken"],["battalions"],["marched"],["army"],["reichswehr"],["wounded"],["hitler"],["marched"],["fortress landsberg"],["1924"],["sentenced"],["imprisonment"],["prison"],["mein kampf"],["mein kampf"],["bavarian government"],["natural"],["france"],["pacifists"],["mein kampf"],["cent"],["french invasion"],["mein kampf"],["mein kampf"],["revise"],["revision"],["mein kampf"],["interests germany"],["chancellor reich"],["references"],["hitler speaks"],["german empire"],["mein kampf"],["habsburg empire"],["references"],["reich"],["constitution"],["empire"],["german empire"],["charlemagne"],["charlemagne"],["empire german"],["emperor"],["napoleon"],["german states"],["german empire"],["habsburg"],["german austria"],["german empire"],["states reich"],["east mark"],["east mark"],["charlemagne"],["tribes"],["german austria"],["note"],["weltanschauung"],["german"],["weltanschauung"],["human life"],["weltanschauung"],["national socialism"],["völkisch"],["volk"],["national stock"],["1918"],["societies"],["socialist concept"],["hitler"],["social democracy"],["socialist party"],["social democrat"],["inn"],["reunion"],["german austria"],["whatsoever"],["union"],["reich"],["colonial policy"],["territory"],["plough"],["frontier"],["lesson"],["german history"],["palm"],["refused disclose"],["schlageter"],["denounced french"],["reich"],["mein kampf"],["munich"],["napoleon"],["bavaria"],["deepest humiliation"],["deepest humiliation"],["pamphlet"],["denounced french"],["refused disclose"],["napoleon"],["monument erected"],["schlageter"],["schlageter"],["artillery"],["occupied ruhr"],["coal"],["denounced french"],["schlageter"],["refused disclose"],["1923"],["minister"],["schlageter"],["schlageter"],["membership"],["austrian state"],["civil servant"],["mother"],["frontier"],["civil servant"],["linz"],["old gentleman"],["restless"],["thirteen"],["vienna"],["century"],["trial"],["thirteen"],["quite contrary"],["misery"],["highest"],["young man"],["civil servant"],["years old"],["native village"],["end"],["village"],["idle"],["austria"],["father"],["ideals"],["anxious"],["home"],["vocation"],["speaking"],["juvenile"],["ecclesiastical"],["priest"],["idea"],["father"],["anxious"],["temperament"],["military"],["war 1870"],["illustrated"],["reading"],["conflict"],["war"],["german war"],["war germans"],["austria"],["fight"],["germans"],["belong"],["problem"],["bismarck"],["understand"],["study"],["classical"],["realschule"],["drawing"],["classical"],["government"],["career"],["career"],["pride"],["career"],["school"],["classical"],["incapable"],["father"],["struggle existence"],["parental"],["opposition"],["obstinate"],["civil servant"],["persuasion"],["state official"],["career"],["office"],["boy"],["school"],["hitler"],["disputes"],["realschule"],["battle"],["conflict"],["discreet"],["government"],["resolution"], ...
# UMAP time: 0:00:42.120109

# %%
print(df['keyword'].value_counts().head(n=100).to_dict())
# Out:
# {'jew': 96, 'propaganda': 87, 'jews': 63, 'revolution': 52, 'marxism': 45, 'reich': 41, 'vienna': 37, '-none-': 36, 'foreign policy': 35, 'munich': 30, 'parliamentary': 29, 'german people': 28, 'army': 28, 'weltanschauung': 27, 'meeting': 27, 'nation': 27, 'race': 26, 'german empire': 25, 'bismarck': 25, 'france': 24, 'socialist movement': 24, 'storm detachment': 24, 'jewish': 24, 'organization': 23, 'national socialist': 23, 'parliament': 23, 'marxist': 22, 'aryan': 22, 'austria': 22, 'german nation': 21, 'bourgeois parties': 21, 'fate': 21, 'prussia': 21, 'bourgeois': 21, 'soldiers': 20, 'war': 20, 'civilization': 20, 'party': 19, 'nature': 19, 'monarchy': 18, 'principles': 18, 'labour party': 18, 'authority state': 18, 'social democracy': 18, 'marxists': 18, 'trades unions': 17, 'government': 17, 'austrian state': 17, 'policy': 17, 'leader': 17, 'alliance': 17, 'movement': 17, 'leadership': 16, 'habsburg': 16, 'political': 16, '1918': 16, 'meetings': 16, 'trades union': 16, 'principle': 15, 'russia': 15, 'self preservation': 15, 'conflict': 15, 'liberty': 15, 'national socialists': 14, 'bourgeoisie': 14, 'revolutionary': 14, 'authority': 14, 'troops': 14, 'germany': 14, 'hatred': 14, 'men': 14, 'sacrifice': 14, 'father': 14, 'success': 14, 'faith': 13, 'courage': 13, 'culture': 13, 'empire': 13, 'comrades': 13, 'politics': 12, 'alliances': 12, 'german reich': 12, 'lesson': 12, 'future': 12, 'disease': 12, 'education': 12, 'soldier': 12, 'new movement': 12, 'committee': 12, 'followers': 12, 'responsibility': 12, 'social democrats': 12, 'mein kampf': 12, 'jewry': 11, 'state': 11, 'war propaganda': 11, 'victory': 11, 'idealism': 11, 'work': 11, 'republic': 11}

# %%
import numpy as np
from plotly.express import scatter
from plotly.graph_objects import Figure

def plot_words(arg_words: list, arg_keywords: list, arg_model: UMAP, arg_embeddings: np.ndarray) -> Figure:
    top_indices = [arg_words.tolist().index(keyword) for keyword in arg_keywords]
    result_df = pd.DataFrame(data=arg_model.transform(X=[arg_embeddings[index] for index in top_indices]), 
                             columns=['u0', 'u1'])
    result_df['word'] = arg_keywords
    return scatter(data_frame=result_df, x='u0', y='u1', text='word', height=900).update_traces(marker={'size': 3})

plot_words(arg_words=vectorizer.get_feature_names_out(),
           arg_keywords=[item for item in df['keyword'].value_counts().head(n=150).index.tolist() if item != '-none-'],
           arg_model=umap_model, arg_embeddings=word_embeddings).show()
# Out:
# <div>                            <div id="a4a55dca-d710-4e49-949d-29f190cd011b" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4a55dca-d710-4e49-949d-29f190cd011b")) {                    Plotly.newPlot(                        "a4a55dca-d710-4e49-949d-29f190cd011b",                        [{"hovertemplate":"u0=%{x}\u003cbr\u003eu1=%{y}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":