# %%
import pandas as pd

DATA = '/kaggle/input/hemoglobin-data/Hemoglobin Data.csv'

df = pd.read_csv(filepath_or_buffer=DATA, index_col=['image_name'])
df.head()
# Out:
#             hbvalues     model  mid_b_mean  mid_g_mean  mid_r_mean  \
# image_name
# image1           9.9    IN2011   49.807024   12.985241  235.497289
# image2          12.8   CPH2413   52.194535   78.836233  207.620027
# image3           9.4   CPH2413   73.868254   92.552331  211.318028
# image4          12.9    IN2011   29.654361    0.164809  246.117047
# image5           9.3  SM-A032F  121.105467  119.894385  178.069980
#
#             mid_b_median  mid_g_median  mid_r_median  mid_l_mean  mid_a_mean  \
# image_name
# image1              45.0          12.0         240.0  128.758904  204.229714
# image2              48.0          81.0         212.0  131.390442  178.746410
# image3              71.0          94.5         216.0  139.659873  174.789434
# image4              24.0           0.0         254.0  133.043224  207.267783
# image5             119.5         123.0         181.0  144.987079  151.822994
#
#             mid_br_mean  mid_l_median  mid_a_median  mid_br_median  \
# image_name
# image1       171.903989         129.0         204.0          175.0
# image2       170.015752         133.0         178.0          173.0
# image3       162.233389         141.0         174.0          165.0
# image4       183.640993         136.0         208.0          188.0
# image5       137.230241         147.0         150.0          139.0
#
#             mid_h_mean  mid_s_mean  mid_v_mean  mid_h_median  mid_s_median  \
# image_name
# image1      174.682041  241.407604  240.891782           176         242.0
# image2        8.421965  199.132372  213.014520             6         198.0
# image3        7.462358  174.399350  216.712522             5         172.0
# image4      175.836184  254.835191  251.511541           177         255.0
# image5        4.632829   93.131766  183.464474             2          88.0
#
#             mid_v_median
# image_name
# image1             240.0
# image2             212.5
# image3             217.0
# image4             255.0
# image5             181.5

# %%
df.dtypes
# Out:
# hbvalues         float64
# model             object
# mid_b_mean       float64
# mid_g_mean       float64
# mid_r_mean       float64
# mid_b_median     float64
# mid_g_median     float64
# mid_r_median     float64
# mid_l_mean       float64
# mid_a_mean       float64
# mid_br_mean      float64
# mid_l_median     float64
# mid_a_median     float64
# mid_br_median    float64
# mid_h_mean       float64
# mid_s_mean       float64
# mid_v_mean       float64
# mid_h_median       int64
# mid_s_median     float64
# mid_v_median     float64
# dtype: object

# %%
import arrow
from plotly import express
from umap import UMAP

COLUMNS = ['mid_b_mean', 'mid_g_mean', 'mid_r_mean',
       'mid_b_median', 'mid_g_median', 'mid_r_median', 'mid_l_mean',
       'mid_a_mean', 'mid_br_mean', 'mid_l_median', 'mid_a_median',
       'mid_br_median', 'mid_h_mean', 'mid_s_mean', 'mid_v_mean',
       'mid_h_median', 'mid_s_median', 'mid_v_median']
TARGET = 'hbvalues'
time_start = arrow.now()
reducer = UMAP(n_components=2, random_state=2024, transform_seed=2024, verbose=True, n_jobs=1, n_epochs=100)
umap_df = pd.DataFrame(data=reducer.fit_transform(X=df[COLUMNS]), columns=['x', 'y'])
umap_df[TARGET] = df[TARGET].tolist()
express.scatter(data_frame=umap_df, x='x', y='y', color=TARGET, ).show()
print('UMAP done in {}'.format(arrow.now() - time_start))
# Out:
# 2024-05-21 18:04:04.973134: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05