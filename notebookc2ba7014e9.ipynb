# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/laptops-and-notebooks-from-2020-2023/mindfactory_done.csv')
df.head()

# %%
df.info()

# %%
from plotly.express import scatter
scatter(data_frame=df.dropna(subset=['depth_mm']), x='width_mm', y='height_mm', hover_name='name', color='display_cm',
        size='depth_mm', opacity=0.2, log_y=True)
