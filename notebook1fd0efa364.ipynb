# %% [markdown]
# We're going to rely on scatter plots for some of our analysis, so let's install a package that will help us do meaningful dimension reduction.

# %%
# !pip install --quiet umap-learn

# %% [markdown]
# Let's load our data; we will defer doing any feature engineering for the moment.

# %%
import pandas as pd

CARS = '/kaggle/input/car-evaluation-classification/cars.csv'
df = pd.read_csv(filepath_or_buffer=CARS)
TARGET = 'class'
df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %% [markdown]
# Is our target class balanced?

# %%
df[TARGET].value_counts().to_frame().T
# Out:
# class  unacc  acc  good  vgood
# count   1210  384    69     65

# %% [markdown]
# Most cars are unacceptable; we will probably have a hard time predicting good or very good cars reliably.

# %% [markdown]
# Let's add a bunch of dummy variables to make all of our features numerical or numeric-like.

# %%
data_df = pd.get_dummies(data=df, columns=['doors', 'persons', 'buying', 'maint', 'lug_boot', 'safety'])
COLUMNS = ['doors_2', 'doors_3', 'doors_4', 'doors_5more', 'persons_2',
       'persons_4', 'persons_more', 'buying_high', 'buying_low', 'buying_med',
       'buying_vhigh', 'maint_high', 'maint_low', 'maint_med', 'maint_vhigh',
       'lug_boot_big', 'lug_boot_med', 'lug_boot_small', 'safety_high',
       'safety_low', 'safety_med']
data_df.head()
# Out:
#    class  doors_2  doors_3  doors_4  doors_5more  persons_2  persons_4  \
# 0  unacc     True    False    False        False       True      False
# 1  unacc     True    False    False        False       True      False
# 2  unacc     True    False    False        False       True      False
# 3  unacc     True    False    False        False       True      False
# 4  unacc     True    False    False        False       True      False
#
#    persons_more  buying_high  buying_low  ...  maint_high  maint_low  \
# 0         False        False       False  ...       False      False
# 1         False        False       False  ...       False      False
# 2         False        False       False  ...       False      False
# 3         False        False       False  ...       False      False
# 4         False        False       False  ...       False      False
#
#    maint_med  maint_vhigh  lug_boot_big  lug_boot_med  lug_boot_small  \
# 0      False         True         False         False            True
# 1      False         True         False         False            True
# 2      False         True         False         False            True
# 3      False         True         False          True           False
# 4      False         True         False          True           False
#
#    safety_high  safety_low  safety_med
# 0        False        True       False
# 1        False       False        True
# 2         True       False       False
# 3        False        True       False
# 4        False       False        True
#
# [5 rows x 22 columns]

# %% [markdown]
# Now let's do dimension reduction to see if our data clusters naturally.

# %%
import arrow
from umap import UMAP

time_start = arrow.now()
reducer = UMAP(random_state=2024, verbose=False, n_jobs=1, low_memory=False, n_epochs=201)
data_df[['x', 'y']] = reducer.fit_transform(X=data_df[COLUMNS])
print('done with UMAP in {}'.format(arrow.now() - time_start))
# Out:
# done with UMAP in 0:00:15.677619

# %%
from plotly import express
express.scatter(data_frame=data_df, x='x', y='y', color=TARGET, height=600)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e4f20e9b-9453-4cac-b166-d1a2a6921643" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4f20e9b-9453-4cac-b166-d1a2a6921643")) {                    Plotly.newPlot(                        "e4f20e9b-9453-4cac-b166-d1a2a6921643",                        [{"hovertemplate":"class=unacc\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"unacc","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"unacc","showlegend":true,"x":[5.362602,5.064028,5.4568653,6.3783045,5.610884,6.4027367,7.1172996,6.1809344,6.872525,4.2820215,3.8182375,3.2173803,3.514481,3.44229,2.6392255,2.8524413,2.832409,2.145663,4.843394,4.308568,3.6096864,5.8525324,5.0861235,4.0687237,6.098631,5.534568,4.3417473,5.4860325,4.9938283,5.4193134,6.413476,5.6675014,6.450685,7.119522,6.2745795,6.989844,4.3763685,3.9740741,3.2967248,3.5878143,3.451993,2.6308908,2.6666744,2.8905635,2.2142596,5.028925,4.3624597,3.7366474,6.024918,5.1028724,3.9882455,6.0826344,5.39627,4.442788,5.511667,5.100607,5.5239983,6.4085503,5.6260214,6.456083,7.145386,6.1105194,6.9000645,4.3798103,3.940017,3.1786103,3.523726,3.4444714,2.710523,2.9195573,2.84943,2.190573,4.970256,4.2517815,3.64486,6.0355587,4.8745728,4.061286,6.181447,5.3971004,4.600343,5.6019034,5.1745653,5.633103,6.524887,5.6847005,6.538311,7.295711,6.2833576,6.8070426,4.1478567,3.8684816,3.1427028,3.458646,3.319916,2.5933168,2.7878666,2.885857,2.0647814,4.966757,4.446298,3.7049816,5.964624,4.9246283,4.054142,5.965987,5.4170494,4.499797,5.3001995,5.066225,5.342357,6.376451,5.658489,6.257503,7.1181054,6.204715,6.901351,4.328612,3.96477,3.1935863,3.535844,3.355442,2.6583414,2.9481728,2.74737,2.0324013,4.8913145,4.256768,3.5583057,5.889714,5.025506,4.051159,5.9396973,5.4945097,4.3643174,5.4291005,4.961437,5.447734,6.3881235,5.7854457,6.207917,7.211575,6.3018436,7.0478344,4.3867407,4.179472,3.2359462,3.4572926,3.454058,2.5142057,2.6322832,2.767039,2.0278242,4.9349213,4.4415784,3.710602,5.8999715,5.1335,4.0054913,6.033134,5.3775344,4.2985997,5.387002,5.087365,5.497631,6.4998894,5.73236,6.2311254,7.1869526,6.2003393,6.8120365,4.244004,4.039874,3.086887,3.4941213,3.3452158,2.4756632,2.8142111,2.7424495,2.0948656,5.012544,4.356634,3.7292156,5.951497,4.821289,3.9552732,5.958683,5.2548943,4.417498,5.610013,5.0715685,5.700348,6.665562,5.825986,6.2232614,7.2872257,6.4086623,6.94634,4.3821783,4.0777917,3.0285354,3.3964105,3.2264605,2.534304,2.709413,2.7765253,2.053507,5.0943317,4.488588,3.711076,5.9821997,5.0097265,4.121056,5.8247266,5.3432527,4.369012,5.3438206,4.9768696,5.3918386,6.449023,5.675622,6.3903203,7.155389,6.1278996,6.7869177,4.385926,3.9170117,3.2841938,3.3568308,2.6169934,4.860574,4.290228,3.720526,5.7744265,5.0555453,6.1571283,5.3941984,5.0538955,5.509829,6.439288,5.666248,6.424628,7.191544,6.235714,7.0006824,4.328013,4.0312862,3.3483992,3.3294117,2.4851975,4.980368,4.325562,5.8493986,6.3294764,5.45953,5.0470934,5.5780334,6.3077745,5.764535,6.499697,7.11513,6.2846484,6.883825,4.374085,3.930512,3.3447616,2.4702637,4.939474,4.2607155,5.7490745,6.0964575,5.649826,4.9504614,5.466028,6.511944,5.7486553,6.544316,7.3961487,6.258014,7.0274467,4.18124,3.9099255,3.3525488,2.3978617,4.8707447,4.5132723,5.735898,6.0040402,5.735682,5.128479,5.44717,6.402418,5.705036,6.42213,7.156027,6.165276,7.056044,4.217167,3.8381445,3.3754911,3.3733025,2.4032385,4.9530196,4.3066597,3.569432,6.0088506,4.964161,6.1544495,5.826323,5.1264477,5.5842004,6.446531,5.713322,6.5669723,7.3053503,6.1867533,7.2305284,4.2004104,3.750174,3.3205462,3.4735537,2.375621,5.295071,4.447933,5.871201,6.310475,5.5979996,5.1599526,5.4783397,6.5659227,5.801337,6.4157195,7.392526,6.216572,7.107999,3.9586947,3.7363744,3.3395247,2.3990057,5.0965376,4.41 ...

# %% [markdown]
# Boy does it ever; we get a lot of local clustering, and a lot of separation between our clusters. But the clusters don't generally correspond to our classes. Let's build a model and see the bad news.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(data_df[COLUMNS], data_df[TARGET], test_size=0.2, random_state=2024, stratify=data_df[TARGET])

logreg = LogisticRegression(max_iter=100, tol=1e-12).fit(X_train, y_train)
print('model fit in {} iterations'.format(logreg.n_iter_[0]))
print('accuracy: {:5.4f} f1: {:5.4f}'.format(accuracy_score(y_true=y_test, y_pred=logreg.predict(X=X_test)), f1_score(average='weighted', y_true=y_test, y_pred=logreg.predict(X=X_test), zero_division=0)))
print(classification_report(y_true=y_test, y_pred=logreg.predict(X=X_test), zero_division=0))
# Out:
# model fit in 86 iterations
# accuracy: 0.9133 f1: 0.9062
#               precision    recall  f1-score   support
#
#          acc       0.83      0.83      0.83        77
#         good       0.50      0.21      0.30        14
#        unacc       0.96      0.98      0.97       242
#        vgood       0.75      0.92      0.83        13
#
#     accuracy                           0.91       346
#    macro avg       0.76      0.74      0.73       346
# weighted avg       0.90      0.91      0.91       346

# %% [markdown]
# Our accuracy/f1 is good, but this is driving mostly by the fact that we are predicting unacceptable cars well.

# %% [markdown]
# We can do somewhat better with a neural net.

# %%
from sklearn.neural_network import MLPClassifier

neural = MLPClassifier(alpha=1, max_iter=1000, random_state=2024).fit(X=X_train, y=y_train)
print('accuracy: {:5.4f} f1: {:5.4f}'.format(accuracy_score(y_true=y_test, y_pred=neural.predict(X=X_test)), f1_score(average='micro', y_true=y_test, y_pred=logreg.predict(X=X_test), zero_division=0)))
print(classification_report(y_true=y_test, y_pred=neural.predict(X=X_test), zero_division=0))
# Out:
# accuracy: 0.9740 f1: 0.9133
#               precision    recall  f1-score   support
#
#          acc       0.95      0.97      0.96        77
#         good       0.91      0.71      0.80        14
#        unacc       1.00      1.00      1.00       242
#        vgood       0.79      0.85      0.81        13
#
#     accuracy                           0.97       346
#    macro avg       0.91      0.88      0.89       346
# weighted avg       0.97      0.97      0.97       346

# %% [markdown]
# Let's take a look at the model results through the lens of the model probabilities.

# %%
probability_df = pd.DataFrame(data=neural.predict_proba(X=X_test).max(axis=1), columns=['probability'])
probability_df['true'] = y_test.tolist()
probability_df['pred'] = neural.predict(X=X_test)
probability_df['correct'] = probability_df['true'] == probability_df['pred']
probability_df[['x', 'y']] = reducer.transform(X=X_test)

probability_df.head()
# Out:
#    probability   true   pred  correct         x         y
# 0     0.768072    acc    acc     True  3.460157  3.953948
# 1     0.999126  unacc  unacc     True  7.409603  7.377582
# 2     0.992469  unacc  unacc     True  3.625695  6.544508
# 3     0.999995  unacc  unacc     True  6.999966  5.743499
# 4     0.999791  unacc  unacc     True  5.101852  7.833376

# %% [markdown]
# What does our mean model probability look like conditioned on whether the prediction is correct?

# %%
probability_df[['probability', 'correct']].groupby(by=['correct']).mean().to_dict()
# Out:
# {'probability': {False: 0.5647966183387692, True: 0.9153586805266136}}

# %% [markdown]
# In other words, when our model is correct is produces a high probability most of the time; when it is incorrect it produces a low probability.

# %%
express.histogram(data_frame=probability_df, x='probability', facet_col='correct', )
# Out:
# <div>                            <div id="40e4235c-d522-48c5-be9a-9dd27a1a50ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40e4235c-d522-48c5-be9a-9dd27a1a50ad")) {                    Plotly.newPlot(                        "40e4235c-d522-48c5-be9a-9dd27a1a50ad",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"correct=True\u003cbr\u003eprobability=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.768072066179717,0.999126131089065,0.9924689400602617,0.999995280585623,0.9997909432222498,0.9999935678059861,0.9982367648961635,0.7199374451869964,0.9967346385709899,0.999947556890311,0.857651239432313,0.9970972621516917,0.7493634127643277,0.9965156731482606,0.5933957299337693,0.9910006321042086,0.996697547509227,0.9963261423424995,0.9949382708646098,0.9993363499080171,0.9998774790018752,0.9996752282052505,0.9999347900071074,0.9999956186369596,0.995513577604814,0.9997843701033068,0.9906014489257702,0.9999927711815442,0.6269999354681098,0.999806694872687,0.9957070987119476,0.9123233450836832,0.9969123067274429,0.9500942991399238,0.8205837089649494,0.9999926697722527,0.5571894965204947,0.8044640953102992,0.9931482638379661,0.9999919737915296,0.695981522478341,0.7109853876417278,0.9548888773800411,0.9944400225306238,0.9163716583329838,0.7711550303897408,0.7814573283250559,0.7273414651242693,0.8905493146072428,0.9926959438761548,0.7212398574033757,0.9998339096217286,0.9163133187772837,0.9944776890666897,0.522854916269448,0.8771444466450415,0.9994130725707596,0.9776647906725835,0.9996831351324251,0.9885903330123592,0.7862295953547731,0.7411952358123304,0.9974364745808484,0.9995634689276436,0.7801196268740864,0.9999906056656656,0.9840648901739334,0.9979667046703852,0.9942678546353292,0.8529928039231865,0.9997729300264651,0.9994504823385497,0.992564918940493,0.903351068919829,0.9985625473638473,0.999476651031624,0.9699699058338153,0.9940103863660603,0.6002877239983774,0.9763219943142383,0.9957207462463251,0.6778097263325026,0.9609769423481563,0.9922452972997734,0.8730602970118158,0.9102472070699642,0.9923121927649241,0.9792128734503583,0.9188232374507863,0.884205636721738,0.9964316193076314,0.9948475046580395,0.9960792313765671,0.9080929578022641,0.999147906868399,0.9999064449062744,0.9999184477886663,0.9966623224373865,0.8439771053308706,0.9999950814311933,0.812065604235786,0.988711808535579,0.8215316149285197,0.8705524749042083,0.9999968342584611,0.6255096785707348,0.9999991153568718,0.9984662309990342,0.9999953003254687,0.9968820946443785,0.9994396785502072,0.9987044430334628,0.9999938705007084,0.9999948678921746,0.9990076435429935,0.8562802975882111,0.9980127034076806,0.9999946711379274,0.4612685317872492,0.8953609178035982,0.9960277635725681,0.9688344433958312,0.816081544810164,0.8017166247908493,0.9998565247763986,0.99995428504981,0.5293819358346696,0.9873934114392691,0.8471750632797742,0.5763359958519014,0.9999923301160474,0.891838376209615,0.9722091413493663,0.7917588812563151,0.6598564481950471,0.9999460842272929,0.9934373698692416,0.9956275380997768,0.9999677600339949,0.819253681998632,0.9957557410573465,0.9305884424942854,0.8905331141996454,0.9999955695338688,0.9978542649203656,0.4630494353605475,0.9926544310349888,0.9988006682688871,0.9926196526038225,0.9488285810922799,0.9998069409352467,0.831002031254583,0.7063159878957566,0.9999380995619793,0.9999995021170583,0.9987025578952228,0.6290654392275845,0.8258728449206056,0.9956966952982615,0.8802476857094649,0.9856568907436518,0.9998928831619328,0.9906573352872073,0.9855028345873857,0.9978353382804545,0.973927896999566,0.999245253852419,0.9999921481461339 ...

# %% [markdown]
# We don't have a lot of incorrect predictions, but let's look at our predictions in terms of the scatter plot we made above, with the model probabilities.

# %%
express.scatter(data_frame=probability_df, x='x', y='y', color='probability', facet_col='correct', hover_name='true')
# Out:
# <div>                            <div id="f6e5e7b8-b539-458b-87a5-f217820b9146" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6e5e7b8-b539-458b-87a5-f217820b9146")) {                    Plotly.newPlot(                        "f6e5e7b8-b539-458b-87a5-f217820b9146",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecorrect=True\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eprobability=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["acc","unacc","unacc","unacc","unacc","unacc","unacc","acc","unacc","unacc","unacc","unacc","acc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","acc","unacc","unacc","unacc","unacc","acc","acc","unacc","acc","acc","unacc","unacc","unacc","acc","acc","unacc","acc","acc","acc","acc","acc","unacc","acc","unacc","acc","unacc","acc","unacc","unacc","unacc","unacc","unacc","acc","acc","unacc","unacc","acc","unacc","unacc","unacc","unacc","acc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","acc","acc","unacc","unacc","acc","acc","unacc","unacc","unacc","acc","unacc","unacc","unacc","unacc","unacc","unacc","acc","unacc","acc","vgood","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","acc","unacc","unacc","acc","vgood","unacc","unacc","unacc","vgood","unacc","unacc","acc","unacc","acc","vgood","unacc","acc","acc","acc","vgood","unacc","unacc","unacc","unacc","unacc","unacc","acc","unacc","unacc","unacc","good","unacc","unacc","unacc","unacc","unacc","acc","acc","unacc","unacc","unacc","good","vgood","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","acc","acc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","acc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","acc","acc","unacc","good","unacc","acc","unacc","acc","unacc","acc","acc","unacc","acc","unacc","unacc","unacc","unacc","unacc","unacc","acc","acc","unacc","acc","unacc","unacc","unacc","acc","unacc","unacc","unacc","acc","unacc","acc","unacc","unacc","acc","acc","unacc","unacc","unacc","unacc","unacc","vgood","unacc","unacc","acc","unacc","unacc","acc","unacc","unacc","acc","vgood","acc","vgood","good","unacc","acc","vgood","unacc","unacc","unacc","good","unacc","unacc","unacc","unacc","acc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","acc","unacc","unacc","unacc","good","unacc","acc","unacc","unacc","unacc","acc","unacc","unacc","acc","unacc","acc","unacc","unacc","unacc","unacc","good","unacc","acc","acc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","unacc","good","unacc","unacc","acc","unacc","unacc","unacc","unacc","acc","unacc","acc","acc","unacc","unacc","unacc","unacc","vgood","unacc","unacc","good","unacc","good","acc","unacc","unacc","unacc","unacc","unacc"],"legendgroup":"","marker":{"color":[0.768072066179717,0.999126131089065,0.9924689400602617,0.999995280585623,0.9997909432222498,0.9999935678059861,0.9982367648961635,0.7199374451869964,0.9967346385709899,0.999947556890311,0.857651239432313,0.9970972621516917,0.7493634127643277,0.9965156731482606,0.5933957299337693,0.9910006321042086,0.996697547509227,0.9963261423424995,0.9949382708646098,0.9993363499080171,0.9998774790018752,0.9996752282052505,0.9999347900071074,0.9999956186369596,0.995513577604814,0.9997843701033068,0.9906014489257702,0.9999927711815442,0.6269999354681098,0.999806694872687,0.9957070987119476,0.9123233450836832,0.9969123067274429,0.9500942991399238,0.8205837089649494,0 ...

# %% [markdown]
# Our incorrect predictions are mostly acceptable/good cars that UMAP projects near unacceptable cars, meaning that they are probably marginal cars. And not surprisingly the correct predictions with low model probabilities are mostly good/acceptable cars.
