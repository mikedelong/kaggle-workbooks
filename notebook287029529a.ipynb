# %%
import pandas as pd

BBSI = '/kaggle/input/krom-bank-indonesia-stock-historical-price/BBSI.JK.csv'

df = pd.read_csv(filepath_or_buffer=BBSI, parse_dates=['Date'])
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-09-07  549.837036  549.837036  458.197540  549.837036  549.837036
# 1 2020-09-08  595.656799  687.296326  595.656799  687.296326  687.296326
# 2 2020-09-09  733.116089  856.829407  687.296326  765.189880  765.189880
# 3 2020-09-10  765.189880  797.263733  714.788147  714.788147  714.788147
# 4 2020-09-11  668.968384  668.968384  668.968384  668.968384  668.968384
#
#      Volume
# 0  29516635
# 1  19232861
# 2  33271020
# 3   1050747
# 4    500439

# %%
from plotly.express import scatter
scatter(data_frame=df, x='Date', y='Volume', log_y=True, trendline='lowess')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from plotly.express import line
line(data_frame=df, x='Date', y=df.columns[1:-1])
# Out:
# <div>                            <div id="f4771a41-c0bd-447f-99de-7da41a124154" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4771a41-c0bd-447f-99de-7da41a124154")) {                    Plotly.newPlot(                        "f4771a41-c0bd-447f-99de-7da41a124154",                        [{"hovertemplate":"variable=Open\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open","showlegend":true,"x":["2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020
# ...

# %% [markdown]
# Our price data clearly has two periods where prices behaved differently: a run-up through August 2021 and a gradual decline thereafter. The trend becomes clearly if we look at moving averages.

# %%
from plotly.express import scatter
for rule in ['W', 'ME', 'QE']:
    line(data_frame=df.set_index(keys=['Date']).resample(rule=rule).mean().reset_index(), x='Date', y=df.columns[2:-1]).show()
# Out:
# <div>                            <div id="26a94350-0880-469d-b579-62e3297eef36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26a94350-0880-469d-b579-62e3297eef36")) {                    Plotly.newPlot(                        "26a94350-0880-469d-b579-62e3297eef36",                        [{"hovertemplate":"variable=High\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"High","orientation":"v","showlegend":true,"x":["2020-09-13T00:00:00","2020-09-20T00:00:00","2020-09-27T00:00:00","2020-10-04T00:00:00","2020-10-11T00:00:00","2020-10-18T00:00:00","2020-10-25T00:00:00","2020-11-01T00:00:00","2020-11-
# ...
