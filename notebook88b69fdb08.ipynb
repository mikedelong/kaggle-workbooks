# %%
import pandas as pd

TRAIN_METADATA = '/kaggle/input/isic-2024-challenge/train-metadata.csv'

df = pd.read_csv(filepath_or_buffer=TRAIN_METADATA, index_col=['isic_id'], low_memory=False)
df.head()
# Out:
#               target  patient_id  age_approx   sex anatom_site_general  \
# isic_id
# ISIC_0015670       0  IP_1235828        60.0  male     lower extremity
# ISIC_0015845       0  IP_8170065        60.0  male           head/neck
# ISIC_0015864       0  IP_6724798        60.0  male     posterior torso
# ISIC_0015902       0  IP_4111386        65.0  male      anterior torso
# ISIC_0024200       0  IP_8313778        55.0  male      anterior torso
#
#               clin_size_long_diam_mm          image_type tbp_tile_type  \
# isic_id
# ISIC_0015670                    3.04  TBP tile: close-up     3D: white
# ISIC_0015845                    1.10  TBP tile: close-up     3D: white
# ISIC_0015864                    3.40  TBP tile: close-up        3D: XP
# ISIC_0015902                    3.22  TBP tile: close-up        3D: XP
# ISIC_0024200                    2.73  TBP tile: close-up     3D: white
#
#                tbp_lv_A  tbp_lv_Aext  ...   lesion_id  iddx_full  iddx_1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 401059 entries, ISIC_0015670 to ISIC_9999967
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   target                        401059 non-null  int64
#  1   patient_id                    401059 non-null  object
#  2   age_approx                    398261 non-null  float64
#  3   sex                           389542 non-null  object
#  4   anatom_site_general           395303 non-null  object
#  5   clin_size_long_diam_mm        401059 non-null  float64
#  6   image_type                    401059 non-null  object
#  7   tbp_tile_type                 401059 non-null  object
#  8   tbp_lv_A                      401059 non-null  float64
#  9   tbp_lv_Aext                   401059 non-null  float64
#  10  tbp_lv_B                      401059 non-null  float64
#  11  tbp_lv_Bext                   401059 non-null  float64
# ...

# %%
df.nunique()
# Out:
# target                               2
# patient_id                        1042
# age_approx                          16
# sex                                  2
# anatom_site_general                  5
# clin_size_long_diam_mm            1758
# image_type                           1
# tbp_tile_type                        2
# tbp_lv_A                        386052
# tbp_lv_Aext                     385304
# tbp_lv_B                        389890
# tbp_lv_Bext                     387763
# tbp_lv_C                        390703
# tbp_lv_Cext                     388865
# tbp_lv_H                        389798
# tbp_lv_Hext                     390743
# tbp_lv_L                        395726
# tbp_lv_Lext                     396358
# tbp_lv_areaMM2                    8029
# tbp_lv_area_perim_ratio         167648
# tbp_lv_color_std_mean           371189
# tbp_lv_deltaA                   398257
# tbp_lv_deltaB                   398886
# tbp_lv_deltaL                   396505
# ...

# %%
df['target'].value_counts().to_dict()
# Out:
# {0: 400666, 1: 393}
