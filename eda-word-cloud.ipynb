# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/d-and-d-5th-edition-powers-and-abilities/D_and_D_5th_EDITION.csv')
df.head()
# Out:
#                         index                        name  \
# 0          action-surge-1-use        Action Surge (1 use)
# 1         action-surge-2-uses       Action Surge (2 uses)
# 2   additional-fighting-style   Additional Fighting Style
# 3  additional-magical-secrets  Additional Magical Secrets
# 4             arcane-recovery             Arcane Recovery
#
#                                         url
# 0          /api/features/action-surge-1-use
# 1         /api/features/action-surge-2-uses
# 2   /api/features/additional-fighting-style
# 3  /api/features/additional-magical-secrets
# 4             /api/features/arcane-recovery

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   370 non-null    object
#  1   name    370 non-null    object
#  2   url     370 non-null    object
# dtypes: object(3)
# memory usage: 8.8+ KB

# %%
from matplotlib.pyplot import subplots
from matplotlib.pyplot import axis
from matplotlib.pyplot import imshow
from wordcloud import WordCloud
subplots(figsize=(12, 12))
imshow(X=WordCloud(random_state=2023, height=1200, width=1200 ).generate(text=' '.join(df['name'].values )))
axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)
