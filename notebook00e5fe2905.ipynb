# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/obesity/csv-1.csv').drop(columns=['Datasource', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value_Footnote_Symbol',
                                                                                    'Data_Value_Footnote', 'Total', 'DataValueTypeID'])
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc                    Class  \
# 0       2011     2011           AL      Alabama  Obesity / Weight Status
# 1       2011     2011           AL      Alabama  Obesity / Weight Status
# 2       2011     2011           AL      Alabama  Obesity / Weight Status
# 3       2011     2011           AL      Alabama  Obesity / Weight Status
# 4       2011     2011           AL      Alabama  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 3  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 4  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
#
# ...

# %%
df.nunique(), df.isna().sum()
# Out:
# (YearStart                       7
#  YearEnd                         7
#  LocationAbbr                   55
#  LocationDesc                   55
#  Class                           3
#  Topic                           3
#  Question                        9
#  Data_Value                    681
#  Data_Value_Alt                681
#  Low_Confidence_Limit          658
#  High_Confidence_Limit         743
#  Sample_Size                  8286
#  Age(years)                      6
#  Education                       4
#  Gender                          2
#  Income                          7
#  Race/Ethnicity                  8
#  GeoLocation                    54
#  ClassID                         3
#  TopicID                         3
#  QuestionID                      9
#  LocationID                     55
#  StratificationCategory1         6
#  Stratification1                28
#  StratificationCategoryId1       6
#  StratificationID1              28
#  dtype: int64,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58408 entries, 0 to 58407
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  58408 non-null  int64
#  1   YearEnd                    58408 non-null  int64
#  2   LocationAbbr               58408 non-null  object
#  3   LocationDesc               58408 non-null  object
#  4   Class                      58408 non-null  object
#  5   Topic                      58408 non-null  object
#  6   Question                   58408 non-null  object
#  7   Data_Value                 52681 non-null  float64
#  8   Data_Value_Alt             52681 non-null  float64
#  9   Low_Confidence_Limit       52681 non-null  float64
#  10  High_Confidence_Limit      52681 non-null  float64
#  11  Sample_Size                52681 non-null  float64
#  12  Age(years)                 12516 non-null  object
# ...

# %%
from plotly.express import bar
for column, value in df.nunique().to_dict().items():
    if value < 60:
        bar(data_frame=df[column].value_counts().to_frame().reset_index(), x=column, y='count').show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
