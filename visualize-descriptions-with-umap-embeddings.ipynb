# %%
# %env TOKENIZERS_PARALLELISM=false
# !pip install --quiet keybert
print('pip install keybert complete.')
# Out:
# env: TOKENIZERS_PARALLELISM=false
# pip install keybert complete.

# %%
import pandas as pd

ESSAYS = '/kaggle/input/aeon-essays-dataset/essays.csv'
USECOLS = ['title', 'description', 'essay', 'authors', ]
df = pd.read_csv(filepath_or_buffer=ESSAYS, usecols=USECOLS)
df['title token count'] = df['title'].apply(func=lambda x: len(x.split()))
df['description token count'] = df['description'].apply(func=lambda x: len(x.split()))
df['essay token count'] = df['essay'].apply(func=lambda x: len(x.split()))
df.head()
# Out:
#                    title                                        description  \
# 0      Space exploration  When self-replicating craft bring life to the ...
# 1     History of science  To the detriment of the public, scientists and...
# 2               Religion  Once a centre of Afghan culture, Sufism seems ...
# 3  Thinkers and theories  The intrepid logician Kurt Gödel believed in t...
# 4  Thinkers and theories  For Rachel Bespaloff, philosophy was a sensual...
#
#                                                essay  \
# 0  Some time late this century, someone will push...
# 1  Would boycotting Russian scientists be an effe...
# 2  My introduction into the world of Afghanistan’...
# 3  As the foremost logician of the 20th century, ...
# 4  Shortly after Rachel Bespaloff’s suicide in 19...
#
#                             authors  title token count  \
# 0                         Jay Olson                  2
# 1  Lorraine Daston & Peter Harrison                  3
# 2                  Annika Schmeding                  1
# 3               Alexander T Englert                  3
# 4                     Isabel Jacobs                  3
#
#    description token count  essay token count
# 0                       21               3608
# 1                       20               3372
# 2                       22               3798
# 3                       19               4168
# 4                       20               2790

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2235 entries, 0 to 2234
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    2235 non-null   object
#  1   description              2235 non-null   object
#  2   essay                    2235 non-null   object
#  3   authors                  2235 non-null   object
#  4   title token count        2235 non-null   int64
#  5   description token count  2235 non-null   int64
#  6   essay token count        2235 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 122.4+ KB

# %%
from plotly.express import histogram
histogram(data_frame=df, x='description token count')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c6049716-9b34-4bf6-adba-afbed74e046e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6049716-9b34-4bf6-adba-afbed74e046e")) {                    Plotly.newPlot(                        "c6049716-9b34-4bf6-adba-afbed74e046e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"description token count=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[21,20,22,19,20,18,21,22,22,22,17,20,19,21,20,26,22,19,16,22,21,23,21,18,19,19,23,16,20,19,21,17,22,13,21,22,18,22,17,22,20,17,20,23,19,18,16,19,20,19,18,20,21,21,22,17,21,18,20,21,18,19,19,20,21,23,20,23,16,20,21,18,22,20,21,19,25,17,21,19,18,17,18,19,22,19,22,18,17,18,17,22,16,20,19,19,20,22,21,18,20,19,23,18,20,19,19,20,19,19,21,20,20,20,21,20,18,18,21,17,21,22,21,18,19,20,19,16,22,23,18,19,19,18,15,20,21,19,20,20,20,18,20,18,20,23,19,21,19,19,18,19,20,20,17,20,18,19,16,21,25,21,25,19,23,17,19,23,24,20,17,20,19,18,21,24,17,24,17,18,21,20,21,18,20,21,20,16,14,21,20,19,20,22,20,20,21,20,18,21,18,21,20,20,16,19,22,20,15,15,16,19,20,21,23,17,19,24,18,16,21,15,21,17,23,18,16,19,16,20,17,20,19,17,18
# %% [markdown]
# To capture the entire essay 90% of the time we will need a max sequence size of 4k or so.

# %%
histogram(data_frame=df, y='title', height=1900)
# Out:
# <div>                            <div id="5d9f9550-e156-4f13-9997-4fc039ba0979" class="plotly-graph-div" style="height:1900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d9f9550-e156-4f13-9997-4fc039ba0979")) {                    Plotly.newPlot(                        "5d9f9550-e156-4f13-9997-4fc039ba0979",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"count=%{x}\u003cbr\u003etitle=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"xaxis":"x","y":["Space exploration","History of science","Religion","Thinkers and theories","Thinkers and theories","Architecture","Stories and literature","History of technology","Earth science and climate","Subcultures","Philosophy of mind","Psychiatry and psychotherapy","War and peace","History of science","Comparative philosophy","Stories and literature","Anthropology","Space exploration","Ageing and death","Race and ethnicity","Ethics","Economics","Metaphysics","Philosophy of mind","Psychiatry and psychotherapy","Metaphysics","Logic and probability","Values and beliefs","Cities","Love and friendship","Language and linguistics","Religion","Cities","History of ideas","Film and visual culture","Work","Nature and landscape","Cognition and intelligence","Space exploration","Consciousness and altered states","Ethics","Education","Astronomy","Religion","Mental health","Thinkers and theories","Medicine","Economics","Space exploration","Nations and empires","Bioethics","Political philosophy","Knowledge","Biography and memoir","Music","Economic history","Nations and empires","Stories and literature","Illness and disease","Work","Film and visual culture","Philosophy of language","Human rights and justice","Archaeology","Quantum theory","Thinkers and theories","Film and visual culture","Mood and emotion","Global history","History of ideas","Palaeontology","Political philosophy","Thinkers and theories","Psychiatry and psychotherapy","Nations and empires","The ancient world","Philosophy of religion","Thinkers and theories","War and peace","Stories and literature","Thinkers and theories","Art","Human rights and justice","Religion","Art","Stories and literature","Environmental history","Information and communication","Human evolution","Food and drink","Genetics","The ancient world","Thinkers and theories","Economic history","Quantum theory","Personality","Virtues and vices","History","Family life","Oceans and water","Stories and literature","Quantum theory","Demography and migration","Psychiatry and psychotherapy","Art","Earth science and climate","History","History of technology","Social psychology","Economic history","Politics and government","Art","Thinkers and theories","Stories and literature","Anthropology","Physics","Political philosophy","History of ideas","Philosophy of religion","Mood and emotion","Philosophy of science","Illness and disease","Neuroscience","Animals and humans","History of ideas","Philosophy of religion","Quantum theory","History of ideas","Mood and emotion","Virtues and vices","Biology","The ancient world","Beauty and aesthetics","Consciousness and altered states","History of science","Human evolution","Economics","Anthropology","History of ideas","Knowledge","Family life","Earth science and climate","Thinkers and theories","Human rights and justice","Metaphysics","Education","Thinkers and theories","Consciousness and altered states","Art","Language and linguistics","Gender and identity","Religion","Space exploration","Animals and humans","Global history","Thinkers and theories","Anthropology","Music","History","Politics and government","Computing and artificial intelligence","Psychiatry and psychotherapy","Ethics","Bioethics" ...

# %% [markdown]
# Here the title is more of a category, and clearly we have a smallish corpus that has a lot of classes of widely varying sizes. Let's try picking a subset.

# %%
from arrow import now
from keybert import KeyBERT
from sklearn.feature_extraction.text import CountVectorizer

MAX_DF = 1.0
MIN_DF = 4
MODEL = 'all-MiniLM-L12-v2'
STOP_WORDS = 'english'
DOCS = df['description'].values.tolist()

model_start = now()
model = KeyBERT(model=MODEL,)
# model.max_seq_length = 
vectorizer = CountVectorizer(ngram_range=(1, 1), stop_words=STOP_WORDS, min_df=MIN_DF, max_df=MAX_DF, )
document_embeddings, word_embeddings = model.extract_embeddings(docs=DOCS, vectorizer=vectorizer, )
print('embedding time: {}'.format(now() - model_start))
print('we have {} documents and {} words.'.format(len(document_embeddings), len(word_embeddings)))
keywords = model.extract_keywords(docs=DOCS, top_n=1, stop_words=STOP_WORDS, vectorizer=vectorizer,
                                  doc_embeddings=document_embeddings, word_embeddings=word_embeddings, min_df=MIN_DF, )
print('model time: {}'.format(now() - model_start))
df['keyword'] = [keyword[0][0] if len(keyword) else '-none-' for keyword in keywords]
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# embedding time: 0:00:41.418503
# we have 2235 documents and 1313 words.
# model time: 0:00:43.276491

# %%
df['keyword'].value_counts().head(n=20)
# Out:
# keyword
# philosophy       42
# brain            19
# science          19
# art              17
# music            17
# women            17
# history          16
# consciousness    16
# animals          16
# death            16
# nature           15
# slavery          14
# evolution        14
# philosophers     13
# theory           13
# democracy        13
# culture          13
# freedom          12
# moral            12
# therapy          12
# Name: count, dtype: int64

# %% [markdown]
# We have a lot of keywords with relatively low cardinality each.

# %%
import pandas as pd
from plotly.express import scatter
from umap import UMAP

umap_start = now()
umap_model = UMAP(n_components=2, random_state=2024, verbose=False, n_jobs=1)
df[['u0', 'u1']] = umap_model.fit_transform(X=document_embeddings)
df['short text'] = df['essay'].apply(func=lambda x: ' '.join(x.split()[:20]) + '...')
IGNORE = {'-none-', }
scatter(data_frame=df[~df['keyword'].isin(IGNORE)], x='u0', y='u1', hover_name='short text',
        hover_data=['keyword', 'title', 'description'],
        color = 'title', height=900
       ).show()
print('UMAP time: {}'.format(now() - umap_start))
# Out:
# <div>                            <div id="3eae2d06-1ded-407c-bc58-bad651fb08d4" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3eae2d06-1ded-407c-bc58-bad651fb08d4")) {                    Plotly.newPlot(                        "3eae2d06-1ded-407c-bc58-bad651fb08d4",                        [{"customdata":[["cult","Space exploration","When self-replicating craft bring life to the far Universe, a religious cult, not science, is likely to be the driving force"],["space","Space exploration","Space junk surrounds Earth, posing a dangerous threat. But there is a way to turn the debris into opportunity"],["exploration","Space exploration","Earthbound exploration was plagued with colonialism, exploitation and extraction. Can we hope to make space any different?"],["alien","Space exploration","The detection of alien life won’t be obvious. It’ll be partial and inconclusive: a perfect task for the scientific method"],["cosmos","Space exploration","By showing us a new cosmos, the discoveries of the James Webb Space Telescope will ripple through our moral universe"],["support","Space exploration","The scientific evidence is clear: the only celestial body that can support us is the one we evolved with. Here’s why"],["moon","Space exploration","Our future in space relies on settling the Moon and using it as a base to probe the deepest questions in the cosmos"],["mars","Space exploration","Instead of treating Mars and the Moon as sites of conquest and settlement, we need a radical new ethics of space exploration"],["exploration","Space exploration","Asteroids could pay for so much space exploration. We just need to mine those valuable resources – and duck a direct hit"],["moon","Space exploration","In the 1960s, NASA went to huge expense to contain possible pathogens from the Moon. What can we learn from the attempt?"],["life","Space exploration","The ability to stir new life into being, all across the Universe, compels us to ask why life matters in the first place"],["space","Space exploration","If we don’t invent a legal framework for space colonisation the consequences could be catastrophic: the time to act is now"],["life","Space exploration","After centuries searching for extraterrestrial life, we might find that first contact is not with organic creatures at all"],["silicon","Space exploration","Elon Musk and the rise of Silicon Valley’s strange trickle-down science"],["research","Space exploration","If head-on problem-solving can’t save the Earth, maybe lateral innovation can. Will low-cost space research pave the way?"]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etitle=%{customdata[1]}\u003cbr\u003eu0=%{x}\u003cbr\u003eu1=%{y}\u003cbr\u003ekeyword=%{customdata[0]}\u003cbr\u003edescription=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Some time late this century, someone will push a button, unleashing a life force on the cosmos. Within 1,000 years,...","Every human-made object sent into orbit around Earth will meet a fiery death. It will fall out of orbit, and...","When he rode to the edge of space on board Jeff Bezos’s reusable New Shepard rocket, William Shatner found the...","The first images beamed back from the James Webb Space Telescope (JWST) were filled with jewels and fire. That’s what...","Two things fill the mind with ever new and increasing wonder and awe, the more often and steadily we reflect...","At the start of the 22nd century, humanity left Earth for the stars. The enormous ecological and climatic devastation that...","From Blue Origin and SpaceX, to the new James Webb Space Telescope, to space agencies worldwide, we’ve set our sights...","Within four years, American astronauts will once again plant their feet an ...
# UMAP time: 0:00:21.209973

# %% [markdown]
# Essays differ from e.g. scientific papers or social media messages in that they by design don't have to stick to one topic, so it probably isn't surprising that we have a fair amount of mixing here; especially since the differences among these categories are somewhat arbitrary.

# %%
from plotly.express import parallel_categories
parallel_categories(data_frame=df[df['title'] == 'History'], dimensions=['title', 'keyword'], height=800)
# Out:
# <div>                            <div id="65f3c2e2-bbb4-407c-b136-dd5d7f57565d" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65f3c2e2-bbb4-407c-b136-dd5d7f57565d")) {                    Plotly.newPlot(                        "65f3c2e2-bbb4-407c-b136-dd5d7f57565d",                        [{"dimensions":[{"label":"title","values":["History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History","History"]},{"label":"keyword","values":["war","paul","parenting","revolutionary","pain","paris","historical","history","painting","west","imagination","courage","future","slavery","soviet","economic","historian","history","historians","trans","philosophy","history","care","nazi","christianity","psychiatry","war","political","genetics","locke","islam","history","medieval","medieval","americans","communist","psychoanalysis","secular","medieval","philosophy","democracy","philosophy","freedom","nazis","women","men","drugs","nation","old","human","border","archaeology","books","religion","refugee","public","books","revolution","runs","national","stories","war","church","invented","kings","slavery","myth","political","nazi","green","war"]}],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"name":"","type":"parcats"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...
