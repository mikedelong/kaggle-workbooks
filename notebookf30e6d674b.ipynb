# %% [markdown]
# Let's load up our data and do some feature engineering to turn all of our features into numerical data.

# %%
import pandas as pd

DATA = '/kaggle/input/telecom-customers/Telecom Customers Churn.csv'
TARGET = 'Churn'

df = pd.read_csv(filepath_or_buffer=DATA, index_col=['customerID'])
for column in ['Partner', 'Dependents', 'PhoneService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']:
    df[column] = df[column] == 'Yes'
df = pd.get_dummies(data=df, columns=['gender', 'Contract', 'MultipleLines', 'InternetService', 'PaymentMethod'])
df['TotalCharges'] = df['TotalCharges'].replace(' ', '0')
df['TotalCharges'] = df['TotalCharges'].astype(float)
df.head()
# Out:
#             SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG              0     True       False       1         False
# 5575-GNVDE              0    False       False      34          True
# 3668-QPYBK              0    False       False       2          True
# 7795-CFOCW              0    False       False      45         False
# 9237-HQITU              0    False       False       2          True
#
#             OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# customerID
# 7590-VHVEG           False          True             False        False
# 5575-GNVDE            True         False              True        False
# 3668-QPYBK            True          True             False        False
# 7795-CFOCW            True         False              True         True
# 9237-HQITU           False         False             False        False
#
#             StreamingTV  ...  MultipleLines_No  \
# customerID               ...
# 7590-VHVEG        False  ...             False
# 5575-GNVDE        False  ...              True
# 3668-QPYBK        False  ...              True
# 7795-CFOCW        False  ...             False
# 9237-HQITU        False  ...              True
#
#             MultipleLines_No phone service  MultipleLines_Yes  \
# customerID
# 7590-VHVEG                            True              False
# 5575-GNVDE                           False              False
# 3668-QPYBK                           False              False
# 7795-CFOCW                            True              False
# 9237-HQITU                           False              False
#
#             InternetService_DSL  InternetService_Fiber optic  \
# customerID
# 7590-VHVEG                 True                        False
# 5575-GNVDE                 True                        False
# 3668-QPYBK                 True                        False
# 7795-CFOCW                 True                        False
# 9237-HQITU                False                         True
#
#             InternetService_No  PaymentMethod_Bank transfer (automatic)  \
# customerID
# 7590-VHVEG               False                                    False
# 5575-GNVDE               False                                    False
# 3668-QPYBK               False                                    False
# 7795-CFOCW               False                                     True
# 9237-HQITU               False                                    False
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                  False
# 5575-GNVDE                                  False
# 3668-QPYBK                                  False
# 7795-CFOCW                                  False
# 9237-HQITU                                  False
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check
# customerID
# 7590-VHVEG                            True                       False
# 5575-GNVDE                           False                        True
# 3668-QPYBK                           False                        True
# 7795-CFOCW                           False                       False
# 9237-HQITU                            True                       False
#
# [5 rows x 30 columns]

# %% [markdown]
# Are the classes in our target variable balanced?

# %%
df[TARGET].value_counts().to_dict()
# Out:
# {False: 5174, True: 1869}

# %% [markdown]
# One class outnumbers the other about about three to one. Let's use dimension reduction to visualize our data.

# %%
import arrow
from umap import UMAP

time_start = arrow.now()
umap = UMAP(random_state=2024, verbose=False, n_jobs=1, low_memory=False, n_epochs=201)
df[['x', 'y']] = umap.fit_transform(X=df.drop(columns=[TARGET]))
print('done with UMAP in {}'.format(arrow.now() - time_start))
# Out:
# done with UMAP in 0:00:42.633292

# %%
from plotly import express

express.scatter(data_frame=df, x='x', y='y', color=TARGET)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="9fe40460-8dd9-4ef0-8487-84bf62ed72a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fe40460-8dd9-4ef0-8487-84bf62ed72a0")) {                    Plotly.newPlot(                        "9fe40460-8dd9-4ef0-8487-84bf62ed72a0",                        [{"hovertemplate":"Churn=False\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"False","showlegend":true,"x":[7.1700597,7.313204,7.1040683,7.196655,2.5540116,13.537823,2.8071454,1.6783849,17.345394,4.282948,14.172798,9.05734,15.904551,6.855121,9.672678,13.751074,8.606826,2.0693011,14.138564,18.038614,6.2459373,7.135019,4.367555,8.6065855,14.679284,14.102007,-0.38225293,14.614437,-2.1474311,14.672407,8.105585,12.82258,9.450217,13.795538,14.281023,13.430842,5.686156,17.165361,14.745443,15.137274,7.0002203,14.792136,17.33879,18.453375,8.594617,7.488057,3.6939428,14.379574,1.5240526,7.5152