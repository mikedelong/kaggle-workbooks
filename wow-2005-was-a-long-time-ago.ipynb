# %%
import pandas as pd

YT = '/kaggle/input/youtube-origins-trailblazing-early-uploads/yt_oldest.csv'
df = pd.read_csv(filepath_or_buffer=YT, parse_dates=['published_at'])
df.head()
# Out:
#                     title     video_id                channel_id  \
# 0           Me at the zoo  jNQXAC9IVRw  UC4QobU6STFB0P71PMvOGN5A
# 1  My Snowboarding Skillz          NaN  UC7DazZtuimjEKKjU2M6aq8w
# 2                 tribute          NaN  UCBE8t4E44we_imhhyszl1UA
# 3    carrie rides a truck          NaN  UC7K5am1UAQEsCRhzXpi9i1g
# 4          Vernal Lullaby          NaN  UClQYeQWfUg0zSyMPPCagpXQ
#
#   channel_title              published_at  view_count  like_count  \
# 0         jawed 2005-04-24 03:31:52+00:00   302611983    15514886
# 1           NaN 2005-04-24 03:56:09+00:00     3690565      164284
# 2           NaN 2005-04-24 22:15:20+00:00     2556256       79806
# 3           NaN 2005-04-30 14:24:14+00:00      512381        6748
# 4           NaN 2005-05-03 02:33:33+00:00      440455        8829
#
#    comment_count
# 0       10376746
# 1          29119
# 2           9832
# 3           2064
# 4           2378

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          964 non-null    object
#  1   video_id       957 non-null    object
#  2   channel_id     401 non-null    object
#  3   channel_title  393 non-null    object
#  4   published_at   964 non-null    datetime64[ns, UTC]
#  5   view_count     964 non-null    int64
#  6   like_count     964 non-null    int64
#  7   comment_count  964 non-null    int64
# dtypes: datetime64[ns, UTC](1), int64(3), object(4)
# memory usage: 60.4+ KB

# %%
from plotly.express import histogram
histogram(data_frame=df, x='published_at')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# YouTube started off very slowly.

# %%
from plotly.express import scatter
scatter(data_frame=df, x='view_count', y='like_count', color='comment_count', hover_name='title', log_x=True, log_y=True,
       trendline='lowess')
# Out:
# <div>                            <div id="1ca8f123-2f3a-4f27-a8ce-1b07d6ee57ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ca8f123-2f3a-4f27-a8ce-1b07d6ee57ec")) {                    Plotly.newPlot(                        "1ca8f123-2f3a-4f27-a8ce-1b07d6ee57ec",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eview_count=%{x}\u003cbr\u003elike_count=%{y}\u003cbr\u003ecomment_count=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Me at the zoo","My Snowboarding Skillz","tribute","carrie rides a truck","Vernal Lullaby","Good Times!!!","Pajamas and Nick Drake","First Back Flip on Youtube! (House dismount)","Stadion Bayen München","GTA:SA","Wanna See Brian Very H
# ...

# %% [markdown]
# There's exactly one historically significant video in this sample and it really stands out. It's an outlier in every dimension.
