# %%
import pandas as pd

REDDIT = '/kaggle/input/stress-detection-from-social-media-articles/Reddit_Combi.csv'
USECOLS = ['Body_Title', 'label']
df = pd.read_csv(filepath_or_buffer=REDDIT, sep=';', usecols=USECOLS)
df['label'] = df['label'] == 1
df.head()
# Out:
#                                           Body_Title  label
# 0  Envy to other is swallowing me Im from develop...   True
# 1  Nothin outta the ordinary. Paradise. Job stres...   True
# 2  Almost 49 and the chasm of emptiness has never...   True
# 3  I’m happy again After my closest friend left m...  False
# 4  Is it possible to recover from such a traumati...   True

# %% [markdown]
# Are our classes balanced?

# %%
df['label'].value_counts(normalize=True).to_frame().T
# Out:
# label          True      False
# proportion  0.878963  0.121037

# %% [markdown]
# No they are not; the False/0 class outnumbers the True/1 class about eight to one.

# %%
from plotly import express
from plotly.io import renderers

express.histogram(x=df['Body_Title'].str.len(), log_y=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1ba87eb7-895d-4758-8df2-71ab15db0bb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ba87eb7-895d-4758-8df2-71ab15db0bb1")) {                    Plotly.newPlot(                        "1ba87eb7-895d-4758-8df2-71ab15db0bb1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[1196,3902,554,137,1587,623,648,539,878,851,309,149,364,190,920,1412,840,378,2068,313,620,1023,548,928,420,1005,1457,683,1744,520,968,232,854,366,1082,396,407,1602,171,822,1176,141,448,572,2271,342,165,2848,373,551,177,326,887,1126,304,819,315,113,674,1378,697,853,1617,1016,250,565,375,724,599,696,1070,2314,324,800,364,695,1011,177,1023,193,1455,557,260,1261,1250,5174,53,1787,305,1581,1549,29376,632,2260,2143,750,1032,320,170,703,398,709,526,1150,408,1307,844,637,1796,577,776,403,1835,1622,2778,4348,230,493,1967,1903,1609,301,274,4212,1033,1638,1126,746,589,1000,1043,341,455,246,97,227,838,297,299,775,805,200,1004,2721,511,322,1639,599,747,618,620,452,817,184,2978,758,670,1132,1027,852,1219,257,2304,349,1797,687,395,407,286,742,359,76,1377,422,1184,1833,186,530,439,890,838,2513,62,322,314,1817,1276,222,419,2373,173,530,1006,295,257,1506,475,2311,38,1050,1061,6243,148,237,444,865,595,1299,64,247,791,1212,1052,909,356,163,437,86,405,90,669,231,1873,164,1087,579,881,708,572,426,325,2118,688,3055,903,1958,1334,112,831,702,87,200,1197,1394,2272,860,270,1236,717,325,353,882,882,361,259,534,378,2946,1740,332,128,688,549,5794,170,310,255,991,422,1342,203,157,864,398,280,612,686,777,132,138,1784,1003,249,1738,210,758,812,1925,449,640,2364,571,211,199,831,1096,5833,591,59,1631,293,1195,362,702,551,310,1125,685,1812,341,893,312,990,454,596,674,723,680,1215,137,330,428,370,474,568,641,800,502,3402,234,216,1310,336,396,1107,184,1284,705,388,293,328,872,402,1210,331,628,342,1438,513,458,676,1859,1220,205,562,316,857,312,186,1085,613,540,417,287,1487,487,537,386,521,765,92,2012,50,1851,1262,3016,894,969,575,721,2074,435,319,455,1609,1492,583,1148,4480,352,408,1150,253,306,329,926,72,889,1481,2818,3228,69,1514,433,764,635,1326,311,245,1060,2236,473,870,91,
gensim.parsing.preprocessing import remove_stopwords
from gensim.parsing.preprocessing import strip_multiple_whitespaces
from gensim.parsing.preprocessing import strip_numeric
from gensim.parsing.preprocessing import strip_punctuation
from gensim.parsing.preprocessing import strip_short
from gensim.parsing.preprocessing import strip_tags
CUSTOM_FILTERS = [lambda x: x.lower(), 
                  remove_stopwords, 
                  strip_multiple_whitespaces, 
                  strip_numeric,
                  strip_punctuation,
                  strip_short,
                  strip_tags, 
                 ]
documents = df['Body_Title'].values.tolist()
texts = [preprocess_string(s=document, filters=CUSTOM_FILTERS) for document in documents]
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]
print(dictionary)
# Out:
# Dictionary<14372 unique tokens: ['afford', 'age', 'beetwen', 'better', 'big']...>

# %% [markdown]
# Now we are ready to train our doc2vec model.

# %%
from arrow import now
from gensim.models.doc2vec import Doc2Vec
from gensim.models.doc2vec import TaggedDocument
doc2vec_start = now()
doc2vec_model = Doc2Vec(vector_size=100, min_count=20, epochs=40)
corpus_iterable = [TaggedDocument(item, [index]) for index, item in enumerate(corpus) ]
doc2vec_model.build_vocab(corpus_iterable=corpus_iterable)
doc2vec_model.train(corpus_iterable=corpus_iterable, total_examples=doc2vec_model.corpus_count, epochs=doc2vec_model.epochs,)
df['vectors'] = doc2vec_model.dv.vectors.tolist()
print('doc2vec training time: {}'.format(now() - doc2vec_start))
# Out:
# doc2vec training time: 0:00:18.230343

# %% [markdown]
# Let's use dimension reduction to see if our document vectors contain a signal that will be easy for a model to find; i.e. do our labels cluster in a UMAP projection?

# %%
from umap import UMAP

doc2vec_umap_start = now()
doc2vec_umap_model = UMAP(n_components=2, random_state=2024, verbose=1, init='pca', n_jobs=1)
df[['x', 'y']] = doc2vec_umap_model.fit_transform(X=df['vectors'].apply(func=pd.Series),)
df['short document'] = df['Body_Title'].str[:80]
print('doc2vec umap time: {}'.format(now() - doc2vec_umap_start))
# Out:
# 2025-07-07 16:14:59.940674: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-07 16:14:59.940816: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-07 16:15:00.109129: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# UMAP(init='pca', n_jobs=1, random_state=2024, verbose=1)
# Mon Jul  7 16:15:13 2025 Construct fuzzy simplicial set
# Mon Jul  7 16:15:19 2025 Finding Nearest Neighbors
# Mon Jul  7 16:15:23 2025 Finished Nearest Neighbor Search
# Mon Jul  7 16:15:26 2025 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Mon Jul  7 16:15:33 2025 Finished embedding
# doc2vec umap time: 0:00:20.704430

# %%
express.scatter(data_frame=df, x='x', y='y', color='label', height=800, hover_name='short document')
# Out:
# /opt/conda/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <div>                            <div id="87bd1991-db29-421e-93bb-f50ab9ad9ccd" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87bd1991-db29-421e-93bb-f50ab9ad9ccd")) {                    Plotly.newPlot(                        "87bd1991-db29-421e-93bb-f50ab9ad9ccd",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elabel=True\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Envy to other is swallowing me Im from developingcountry, Indonesia , and for no","Nothin outta the ordinary. Paradise. Job stress. Life stress. (F bombs call me h","Almost 49 and the chasm of emptiness has never been greater I’ve been diagnosed ","Is it possible to recover from such a traumatic childhood? I am only 15, and yet","I’m finding it hard to find a reason to get up in the mornings again. Isn’t it s","I convinced myself I was going to commit suicide sometime in the next 2 weeks. T","all i do is work and i can never catch a break literally i always have assignmen","Ive decided to get admitted to a hospital instead of just killing myself Hi, im ","I’m doing well, but not feeling well. A reflection. I’ve been under a lot of str","LoL Im trapped in hell Literally every little thing that goes wrong couses me un","Today depression is hitting so strong in the morning I feel like today is my las","Fun fact when I was younger many people told me I was a gifted child of above av","You win Guess you win and I lose like always. This fight is over and can’t be bo","Today I witnessed the most horrifying moment of my depression till date [TLDR a ","I'm not lazy at school, I just need some understanding is all. I have to go back","Please tell me it gets easier Hi all. I am two years into my career with a new m","DEPRESSION MAKES NO FUCKING SENSE One minute you’re fine and the next you feel s","I just realized that I believe that if I'm not constantly under a lot of pressur","23yo Male. Losing my best friend I have lost who I considered my best friend. Sh","I (16M) might be clinically depressed? I (16M) don't understand if I am just fee","Losing Streak I feel like I'm really close to the end of my rope. I can't rememb","So stressed out it’s become a multitasking event I’ve just noticed recently. I’v","School during Covid sucks I swear my teachers don’t even care about any of their","Please i need a break so badly Shits been rough. Looking back at the last 10 yea","Useless brain I'm useless, I'm dumb I will never be anything I just keep fucking","Trying medication again\u002fA needed ramble Hi I’m new here. I’ve battled with depre","Just speaking my mind. Don't mind me. I am scared. I am falling into darkness. I","Diagnosed with cancer, mom passed away, wife asking for a divorce. All within a ","I Feel Like a Waste I had so much potential. So many opportunities to become who","My symptoms 1,5 years after Burning out ( & getting Diagnosed with Fatigue Syndr","what do i tell my doctor when i he asked this question When the doctor asks are ","Am I Not in Control? Does anybody else get this feeling from stress like you're ","Staying busy to stay out of my own head. Stressed and overwhelmed just don't cov","Could this all be stress from an exam? Sorry for long post. 25M. The last month ","One of the worst side effects of my depression is the brain fog, but I never see","My worst enemy is myself when it comes to stress Yes, I'm stuck in a job I hate ","Anyone else have semi-suicidal thoughts on a regular basis? I’m not saying gun t","For the first time in 4 years, I feel hopeful for what the future holds for me. ","just need some support (´ω｀) currently going through my national exams and i’ve ","Do you ever feel like you are j ...

# %% [markdown]
# This is not particularly encouraging. Doc2vec does not appear to cluster our documents according to their labels.

# %%
import arrow
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['vectors'].apply(func=pd.Series), df['label'], test_size=0.25, random_state=2024, stratify=df['label'])

time_start = arrow.now()
regression = LogisticRegression(max_iter=100000, tol=1e-12).fit(X=X_train, y=y_train)
print('model fit in {} iterations took {}'.format(regression.n_iter_[0], arrow.now() - time_start))

print('accuracy: {:5.4f}'.format(accuracy_score(y_true=y_test, y_pred=regression.predict(X=X_test))))
print('model done in {}'.format(now() - time_start))
# Out:
# model fit in 57 iterations took 0:00:00.058061
# accuracy: 0.8886
# model done in 0:00:00.068969

# %% [markdown]
# An accuracy of nearly 0.9 seems encouraging, but our classes are unbalanced to the point that we can get an accuracy of nearly 0.9 with a dummy model that labels every document 1. Let's look at the classification report.

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true=y_test, y_pred=regression.predict(X=X_test)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.68      0.16      0.26        95
#         True       0.89      0.99      0.94       686
#
#     accuracy                           0.89       781
#    macro avg       0.79      0.57      0.60       781
# weighted avg       0.87      0.89      0.86       781

# %% [markdown]
# Our doc2vec/logistic regression solution does poorly with the 0 class.

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF

gauss = GaussianProcessClassifier(1.0 * RBF(1.0), random_state=2024)
gauss.fit(X=X_train, y=y_train)

print(classification_report(y_true=y_test, y_pred=gauss.predict(X=X_test)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.61      0.24      0.35        95
#         True       0.90      0.98      0.94       686
#
#     accuracy                           0.89       781
#    macro avg       0.75      0.61      0.64       781
# weighted avg       0.87      0.89      0.87       781

# %% [markdown]
# Our Gaussian Process model doesn't do much better.

# %% [markdown]
# Can we do better with BERT embeddings? Let's find out.

# %%
# %env TOKENIZERS_PARALLELISM=false
# !pip install --quiet keybert
print('pip install keybert complete.')
# Out:
# env: TOKENIZERS_PARALLELISM=false
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning:
#
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# pip install keybert complete.

# %%
from arrow import now
from keybert import KeyBERT
from sklearn.feature_extraction.text import TfidfVectorizer

MAX_DF = 1.0
MIN_DF = 4
MODEL = 'all-MiniLM-L12-v2'
STOP_WORDS = 'english'
DOCS = df['Body_Title'].values.tolist()

model_start = now()
bert = KeyBERT(model=MODEL,)
bert.max_seq_length = 512
vectorizer = TfidfVectorizer(ngram_range=(1, 1), stop_words=STOP_WORDS, min_df=MIN_DF, max_df=MAX_DF, )
document_embeddings, word_embeddings = bert.extract_embeddings(docs=DOCS, vectorizer=vectorizer, )
print('embedding time: {}'.format(now() - model_start))
print('we have {} documents and {} words.'.format(len(document_embeddings), len(word_embeddings)))
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# embedding time: 0:03:05.822236
# we have 3123 documents and 4663 words.

# %%
df['embedding'] = document_embeddings.tolist()
embedding_umap_model = UMAP(n_components=2, random_state=2024, verbose=1, init='pca', n_jobs=1)
df[['ex', 'ey']] = embedding_umap_model.fit_transform(X=df['embedding'].apply(func=pd.Series),)
express.scatter(data_frame=df, x='ex', y='ey', color='label', height=800, hover_name='short document')
# Out:
# UMAP(init='pca', n_jobs=1, random_state=2024, verbose=1)
# Mon Jul  7 16:20:59 2025 Construct fuzzy simplicial set
# Mon Jul  7 16:21:05 2025 Finding Nearest Neighbors
# Mon Jul  7 16:21:06 2025 Finished Nearest Neighbor Search
# Mon Jul  7 16:21:06 2025 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Mon Jul  7 16:21:12 2025 Finished embedding
# <div>                            <div id="7add247c-49d3-4f7f-ac1f-981fd82cc402" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7add247c-49d3-4f7f-ac1f-981fd82cc402")) {                    Plotly.newPlot(                        "7add247c-49d3-4f7f-ac1f-981fd82cc402",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elabel=True\u003cbr\u003eex=%{x}\u003cbr\u003eey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Envy to other is swallowing me Im from developingcountry, Indonesia , and for no","Nothin outta the ordinary. Paradise. Job stress. Life stress. (F bombs call me h","Almost 49 and the chasm of emptiness has never been greater I’ve been diagnosed ","Is it possible to recover from such a traumatic childhood? I am only 15, and yet","I’m finding it hard to find a reason to get up in the mornings again. Isn’t it s","I convinced myself I was going to commit suicide sometime in the next 2 weeks. T","all i do is work and i can never catch a break literally i always have assignmen","Ive decided to get admitted to a hospital instead of just killing myself Hi, im ","I’m doing well, but not feeling well. A reflection. I’ve been under a lot of str","LoL Im trapped in hell Literally every little thing that goes wrong couses me un","Today depression is hitting so strong in the morning I feel like today is my las","Fun fact when I was younger many people told me I was a gifted child of above av","You win Guess you win and I lose like always. This fight is over and can’t be bo","Today I witnessed the most horrifying moment of my depression till date [TLDR a ","I'm not lazy at school, I just need some understanding is all. I have to go back","Please tell me it gets easier Hi all. I am two years into my career with a new m","DEPRESSION MAKES NO FUCKING SENSE One minute you’re fine and the next you feel s","I just realized that I believe that if I'm not constantly under a lot of pressur","23yo Male. Losing my best friend I have lost who I considered my best friend. Sh","I (16M) might be clinically depressed? I (16M) don't understand if I am just fee","Losing Streak I feel like I'm really close to the end of my rope. I can't rememb","So stressed out it’s become a multitasking event I’ve just noticed recently. I’v","School during Covid sucks I swear my teachers don’t even care about any of their","Please i need a break so badly Shits been rough. Looking back at the last 10 yea","Useless brain I'm useless, I'm dumb I will never be anything I just keep fucking","Trying medication again\u002fA needed ramble Hi I’m new here. I’ve battled with depre","Just speaking my mind. Don't mind me. I am scared. I am falling into darkness. I","Diagnosed with cancer, mom passed away, wife asking for a divorce. All within a ","I Feel Like a Waste I had so much potential. So many opportunities to become who","My symptoms 1,5 years after Burning out ( & getting Diagnosed with Fatigue Syndr","what do i tell my doctor when i he asked this question When the doctor asks are ","Am I Not in Control? Does anybody else get this feeling from stress like you're ","Staying busy to stay out of my own head. Stressed and overwhelmed just don't cov","Could this all be stress from an exam? Sorry for long post. 25M. The last month ","One of the worst side effects of my depression is the brain fog, but I never see","My worst enemy is myself when it comes to stress Yes, I'm stuck in a job I hate ","Anyone else have semi-suicidal thoughts on a regular basis? I’m not saying gun t","For the first time in 4 years, I feel hopeful for what the future holds for me. ","just need some support (´ω｀) currently going through my national exams and i’ve ","Do you ever feel like you are ...

# %% [markdown]
# This is much better. Let's see how our models do now.

# %%
import arrow
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

Xe_train, Xe_test, ye_train, ye_test = train_test_split(df['embedding'].apply(func=pd.Series), df['label'], test_size=0.25, random_state=2024, stratify=df['label'])

time_start = arrow.now()
embedding_regression = LogisticRegression(max_iter=100000, tol=1e-12).fit(X=Xe_train, y=ye_train)
print('model fit in {} iterations took {}'.format(embedding_regression.n_iter_[0], arrow.now() - time_start))

print('accuracy: {:5.4f}'.format(accuracy_score(y_true=ye_test, y_pred=embedding_regression.predict(X=Xe_test))))
print('model done in {}'.format(now() - time_start))
# Out:
# model fit in 25 iterations took 0:00:00.040424
# accuracy: 0.9449
# model done in 0:00:00.066001

# %%
print(classification_report(y_true=ye_test, y_pred=embedding_regression.predict(X=Xe_test)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.60      0.73        95
#         True       0.95      0.99      0.97       686
#
#     accuracy                           0.94       781
#    macro avg       0.93      0.80      0.85       781
# weighted avg       0.94      0.94      0.94       781

# %% [markdown]
# Logistic Regression performs much better on the 0 class with embeddings than with document vectors.

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(alpha=1.0, max_iter=100000, random_state=2024).fit(X=Xe_train, y=ye_train)
print('score: {:5.4f}'.format(mlp.score(X=Xe_test, y=ye_test)))

print(classification_report(y_true=ye_test, y_pred=mlp.predict(X=Xe_test)))
# Out:
# score: 0.9462
#               precision    recall  f1-score   support
#
#        False       0.92      0.61      0.73        95
#         True       0.95      0.99      0.97       686
#
#     accuracy                           0.95       781
#    macro avg       0.93      0.80      0.85       781
# weighted avg       0.95      0.95      0.94       781

# %% [markdown]
# We can do ever so slightly better with an sklearn neural net model.
