# %% [markdown]
# I mean how could it do otherwise?

# %%
from IPython.display import Image

FILENAME = '/kaggle/input/image-file/depositphotos_250914968-stock-photo-full-length-portrait-young-man.jpg'
Image(filename=FILENAME)

# %% [markdown]
# He seems nice. A little awkward, but nice.
