# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/rsmc-tokyo-typhoon-center-best-track-data/RSMC_Best_Track_Data.csv',
                parse_dates=['Time of analysis'])
df['year'] = df['Time of analysis'].dt.year
df.head()

# %%
df['Name of the storm'].value_counts(dropna=False)

# %%
from plotly.express import scatter_geo
scatter_geo(data_frame=df[df['year'] == 2021], lat='Latitude of the center', lon='Longitude of the center', color='Name of the storm', fitbounds='locations',
           opacity=0.5)
