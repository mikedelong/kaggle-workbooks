# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/aggregate-household-net-worth-usa-1979-2021/aggregate_household_net_worth.csv', index_col='Years')
df = df.sort_index()
df.sample(n=10).sort_index()
# Out:
#        Aggregate household net worth ($)  Agg_Black ($)  Agg_Hispanic ($)  \
# Years
# 1983                            12813350            NaN               NaN
# 1988                            19644382            NaN               NaN
# 1996                            30441845      1082280.0          564417.0
# 1997                            33479062      1160301.0          717972.0
# 1999                            40926802      1330480.0          833288.0
# 2000                            43762222      1360154.0          883573.0
# 2008                            57557971      2139195.0         1421111.0
# 2009                            58422809      2207742.0         1274240.0
# 2014                            81458312      3272747.0         1875534.0
# 2020                           124041707      5014001.0         2883371.0
#
#        Agg_White ($)  Agg_Other ($)      Assets ($)  Assets_Black ($)  \
# Years
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 1979 to 2021
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Aggregate household net worth ($)  43 non-null     int64
#  1   Agg_Black ($)                      33 non-null     float64
#  2   Agg_Hispanic ($)                   33 non-null     float64
#  3   Agg_White ($)                      33 non-null     float64
#  4   Agg_Other ($)                      33 non-null     float64
#  5       Assets ($)                     43 non-null     int64
#  6   Assets_Black ($)                   33 non-null     float64
#  7   Assets_Hispanic ($)                33 non-null     float64
#  8   Assets_White ($)                   33 non-null     float64
#  9   Assets_Other ($)                   33 non-null     float64
#  10  Liabilities ($)                    43 non-null     int64
# ...

# %%
columns = df.columns.tolist()
df[[columns[0], columns[5], columns[10]]].plot()
# Out:
# <Axes: xlabel='Years'>

# %%
columns = df.columns.tolist()
df[[columns[1], columns[6], columns[11]]].plot()
# Out:
# <Axes: xlabel='Years'>

# %%
columns = df.columns.tolist()
df[[columns[2], columns[7], columns[12]]].plot()
# Out:
# <Axes: xlabel='Years'>

# %% [markdown]
# That one year looks weird.

# %%
columns = df.columns.tolist()
df[[columns[3], columns[8], columns[13]]].plot()
# Out:
# <Axes: xlabel='Years'>

# %%
columns = df.columns.tolist()
df[[columns[4], columns[9], columns[14]]].plot()
# Out:
# <Axes: xlabel='Years'>

# %%
from seaborn import heatmap
heatmap(data=df.corr())
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# <Axes: >

# %%
from seaborn import pairplot
pairplot(data=df[[column for column in columns if 'Assets' in column]])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
pairplot(data=df[[column for column in columns if 'Black' in column]])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
