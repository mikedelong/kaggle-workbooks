# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/bike-sharing-networks-dataset/bike.csv')
df.head()
# Out:
#                       company/0                              href  \
# 0                ЗАО «СитиБайк»      /v2/networks/velobike-moscow
# 1  Urban Infrastructure Partner      /v2/networks/baerum-bysykkel
# 2             Comunicare S.r.l.     /v2/networks/bicincitta-siena
# 3            Cyclopolis Systems  /v2/networks/cyclopolis-maroussi
# 4            Cyclopolis Systems   /v2/networks/cyclopolis-nafplio
#
#                     id location/city location/country  location/latitude  \
# 0      velobike-moscow        Moscow               RU          55.750000
# 1      baerum-bysykkel         Bærum               NO          59.894550
# 2     bicincitta-siena         Siena               IT          43.318600
# 3  cyclopolis-maroussi      Maroussi               GR          38.056872
# 4   cyclopolis-nafplio       Nafplio               GR          37.563940
#
#    location/longitude        name  \
# 0           37.616667    Velobike
# 1           10.546343    Bysykkel
# ...

# %%
df.info() ; df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   company/0           619 non-null    object
#  1   href                636 non-null    object
#  2   id                  636 non-null    object
#  3   location/city       636 non-null    object
#  4   location/country    636 non-null    object
#  5   location/latitude   636 non-null    float64
#  6   location/longitude  636 non-null    float64
#  7   name                636 non-null    object
#  8   source              160 non-null    object
#  9   company/1           97 non-null     object
#  10  gbfs_href           110 non-null    object
#  11  license/name        27 non-null     object
#  12  license/url         27 non-null     object
#  13  company             1 non-null      object
#  14  ebikes              32 non-null     object
# ...

# %%
from plotly.express import scatter_geo
scatter_geo(data_frame=df, lat='location/latitude', lon='location/longitude', hover_name='name', color='location/country', height=1000)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from plotly.express import bar
bar(data_frame=df['location/country'].value_counts().to_frame().reset_index(), x='location/country', y='count')
# Out:
# <div>                            <div id="1d7dca31-0570-40db-a8bd-d6062f1c651d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d7dca31-0570-40db-a8bd-d6062f1c651d")) {                    Plotly.newPlot(                        "1d7dca31-0570-40db-a8bd-d6062f1c651d",                        [{"alignmentgroup":"True","hovertemplate":"location\u002fcountry=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["IT","DE","ES","FR","US","GR","CZ","HR","CH","PL","BR","AT","GB","SI","CA","NO","SK","IE","BE","RO","MX","UA","PT","TR","KZ","BA","RU","SE","JP","AR","CY","FI","LU","CO","MT
# ...
