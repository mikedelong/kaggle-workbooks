# %%
# %env TOKENIZERS_PARALLELISM=false
# !pip install --quiet keybert
print('pip install keybert complete')
# Out:
# env: TOKENIZERS_PARALLELISM=false
# pip install keybert complete

# %%
import pandas as pd

ESSAYS = '/kaggle/input/aeon-essays-dataset/essays.csv'
USECOLS = ['title', 'description', 'essay', 'authors', ]
df = pd.read_csv(filepath_or_buffer=ESSAYS, usecols=USECOLS)
df['title token count'] = df['title'].apply(func=lambda x: len(x.split()))
df['description token count'] = df['description'].apply(func=lambda x: len(x.split()))
df['essay token count'] = df['essay'].apply(func=lambda x: len(x.split()))
df.head()
# Out:
#                    title                                        description  \
# 0      Space exploration  When self-replicating craft bring life to the ...
# 1     History of science  To the detriment of the public, scientists and...
# 2               Religion  Once a centre of Afghan culture, Sufism seems ...
# 3  Thinkers and theories  The intrepid logician Kurt Gödel believed in t...
# 4  Thinkers and theories  For Rachel Bespaloff, philosophy was a sensual...
#
#                                                essay  \
# 0  Some time late this century, someone will push...
# 1  Would boycotting Russian scientists be an effe...
# 2  My introduction into the world of Afghanistan’...
# 3  As the foremost logician of the 20th century, ...
# 4  Shortly after Rachel Bespaloff’s suicide in 19...
#
#                             authors  title token count  \
# 0                         Jay Olson                  2
# 1  Lorraine Daston & Peter Harrison                  3
# 2                  Annika Schmeding                  1
# 3               Alexander T Englert                  3
# 4                     Isabel Jacobs                  3
#
#    description token count  essay token count
# 0                       21               3608
# 1                       20               3372
# 2                       22               3798
# 3                       19               4168
# 4                       20               2790

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2235 entries, 0 to 2234
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    2235 non-null   object
#  1   description              2235 non-null   object
#  2   essay                    2235 non-null   object
#  3   authors                  2235 non-null   object
#  4   title token count        2235 non-null   int64
#  5   description token count  2235 non-null   int64
#  6   essay token count        2235 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 122.4+ KB

# %%
from plotly.express import histogram
histogram(data_frame=df, x='essay token count')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="3c4b4de8-14b1-41e5-857c-75cefa3aa7bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c4b4de8-14b1-41e5-857c-75cefa3aa7bf")) {                    Plotly.newPlot(                        "3c4b4de8-14b1-41e5-857c-75cefa3aa7bf",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"essay token count=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3608,3372,3798,4168,2790,2845,3116,5219,3882,4455,4044,3560,5667,3660,3475,4804,5524,3225,3856,3887,3818,4521,2605,3457,3667,4335,4017,3964,3973,3301,4324,3607,4156,3805,3692,2904,4201,4067,4470,5071,3831,4085,3813,3999,3618,3605,5767,3295,4289,4026,3376,3850,3286,3928,3745,3707,4557,3914,3708,3238,2627,3042,3529,4005,3382,3941,4260,3632,3414,4370,2683,4130,2744,3727,3524,3395,3964,3493,3584,3673,3515,3506,6127,4042,3596,3232,4304,2889,3411,4284,5120,4074,2592,3314,6625,3969,2967,3946,4048,3109,3222,4070,3744,4032,3404,5031,3732,2756,3170,2917,3119,4160,3134,2831,4712,5181,4191,3137,3701,2654,3196,3477,3720,2800,
# %% [markdown]
# To capture the entire essay 90% of the time we will need a max sequence size of 4k or so.

# %%
histogram(data_frame=df, y='title', height=1900)
# Out:
# <div>                            <div id="2cd3f05e-5b4a-43a6-a76e-fc34be4489db" class="plotly-graph-div" style="height:1900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cd3f05e-5b4a-43a6-a76e-fc34be4489db")) {                    Plotly.newPlot(                        "2cd3f05e-5b4a-43a6-a76e-fc34be4489db",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"count=%{x}\u003cbr\u003etitle=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"xaxis":"x","y":["Space exploration","History of science","Religion","Thinkers and theories","Thinkers and theories","Architecture","Stories and literature","History of technology","Earth science and climate","Subcultures","Philosophy of mind","Psychiatry and psychotherapy","War and peace","History of science","Comparative philosophy","Stories and literature","Anthropology","Space exploration","Ageing and death","Race and ethnicity","Ethics","Economics","Metaphysics","Philosophy of mind","Psychiatry and psychotherapy","Metaphysics","Logic and probability","Values and beliefs","Cities","Love and friendship","Language and linguistics","Religion","Cities","History of ideas","Film and visual culture","Work","Nature and landscape","Cognition and intelligence","Space exploration","Consciousness and altered states","Ethics","Education","Astronomy","Religion","Mental health","Thinkers and theories","Medicine","Economics","Space exploration","Nations and empires","Bioethics","Political philosophy","Knowledge","Biography and memoir","Music","Economic history","Nations and empires","Stories and literature","Illness and disease","Work","Film and visual culture","Philosophy of language","Human rights and justice","Archaeology","Quantum theory","Thinkers and theories","Film and visual culture","Mood and emotion","Global history","History of ideas","Palaeontology","Political philosophy","Thinkers and theories","Psychiatry and psychotherapy","Nations and empires","The ancient world","Philosophy of religion","Thinkers and theories","War and peace","Stories and literature","Thinkers and theories","Art","Human rights and justice","Religion","Art","Stories and literature","Environmental history","Information and communication","Human evolution","Food and drink","Genetics","The ancient world","Thinkers and theories","Economic history","Quantum theory","Personality","Virtues and vices","History","Family life","Oceans and water","Stories and literature","Quantum theory","Demography and migration","Psychiatry and psychotherapy","Art","Earth science and climate","History","History of technology","Social psychology","Economic history","Politics and government","Art","Thinkers and theories","Stories and literature","Anthropology","Physics","Political philosophy","History of ideas","Philosophy of religion","Mood and emotion","Philosophy of science","Illness and disease","Neuroscience","Animals and humans","History of ideas","Philosophy of religion","Quantum theory","History of ideas","Mood and emotion","Virtues and vices","Biology","The ancient world","Beauty and aesthetics","Consciousness and altered states","History of science","Human evolution","Economics","Anthropology","History of ideas","Knowledge","Family life","Earth science and climate","Thinkers and theories","Human rights and justice","Metaphysics","Education","Thinkers and theories","Consciousness and altered states","Art","Language and linguistics","Gender and identity","Religion","Space exploration","Animals and humans","Global history","Thinkers and theories","Anthropology","Music","History","Politics and government","Computing and artificial intelligence","Psychiatry and psychotherapy","Ethics","Bioethics" ...

# %% [markdown]
# Here the title is more of a category, and clearly we have a smallish corpus that has a lot of classes of widely varying sizes. Let's try picking a subset.

# %%
top_df = df[df['title'].isin(df['title'].value_counts().head(n=5).index.tolist())].copy()
top_df['title'].value_counts()
# Out:
# title
# Stories and literature    73
# History                   71
# Thinkers and theories     70
# Ethics                    69
# Biology                   62
# Name: count, dtype: int64

# %%
from arrow import now
from keybert import KeyBERT
from sklearn.feature_extraction.text import CountVectorizer

MAX_DF = 1.0
MIN_DF = 4
MODEL = 'all-MiniLM-L12-v2'
STOP_WORDS = 'english'

model_start = now()
model = KeyBERT(model=MODEL,)
model.max_seq_length = 4 * 1024
vectorizer = CountVectorizer(ngram_range=(1, 1), stop_words=STOP_WORDS, min_df=MIN_DF, max_df=MAX_DF, )
document_embeddings, word_embeddings = model.extract_embeddings(docs=top_df['essay'].values.tolist(), vectorizer=vectorizer, )
print('embedding time: {}'.format(now() - model_start))
print('we have {} documents and {} words.'.format(len(document_embeddings), len(word_embeddings)))
keywords = model.extract_keywords(docs=top_df['essay'].values.tolist(), top_n=1, stop_words=STOP_WORDS, vectorizer=vectorizer,
                                  doc_embeddings=document_embeddings, word_embeddings=word_embeddings, min_df=MIN_DF, )
print('model time: {}'.format(now() - model_start))
top_df['keyword'] = [keyword[0][0] if len(keyword) else '-none-' for keyword in keywords]
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# embedding time: 0:01:21.044954
# we have 345 documents and 14397 words.
# model time: 0:01:25.749518

# %%
top_df['keyword'].value_counts().head(n=20)
# Out:
# keyword
# historians         4
# morality           4
# literature         4
# animals            4
# plato              3
# totalitarianism    2
# aristotle          2
# philosophy         2
# martians           2
# slavery            2
# secularism         2
# silence            2
# socrates           2
# shakespeare        2
# ethics             2
# selfish            2
# whale              2
# holocaust          2
# philosophers       2
# veganism           2
# Name: count, dtype: int64

# %% [markdown]
# We have a lot of keywords with relatively low cardinality each.

# %%
import pandas as pd
from plotly.express import scatter
from umap import UMAP

umap_start = now()
umap_model = UMAP(n_components=2, random_state=2024, verbose=False, n_jobs=1)
top_df[['u0', 'u1']] = umap_model.fit_transform(X=document_embeddings)
top_df['short text'] = top_df['essay'].apply(func=lambda x: ' '.join(x.split()[:20]) + '...')
IGNORE = {'-none-', }
scatter(data_frame=top_df[~top_df['keyword'].isin(IGNORE)], x='u0', y='u1', hover_name='short text',
        hover_data=['keyword', 'title', 'description'],
        color = 'title',
       ).show()
print('UMAP time: {}'.format(now() - umap_start))
# Out:
# <div>                            <div id="6daa7468-b598-427d-ac40-27df3081299a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6daa7468-b598-427d-ac40-27df3081299a")) {                    Plotly.newPlot(                        "6daa7468-b598-427d-ac40-27df3081299a",                        [{"customdata":[["logician","Thinkers and theories","The intrepid logician Kurt Gödel believed in the afterlife. In four heartfelt letters to his mother he explained why"],["instant","Thinkers and theories","For Rachel Bespaloff, philosophy was a sensual activity shaped by the rhythm of history, embodied in an instant of freedom"],["philosopher","Thinkers and theories","Written for laymen, read by women and kings, Christian Wolff’s mathematical method made him a key Enlightenment philosopher"],["climate","Thinkers and theories","In the face of climate crisis it might seem myopic but philosophers from Spinoza to Næss argue it is the only way forward"],["wittgenstein","Thinkers and theories","The philosopher understood that learning – of a concept, of ourselves, of each other – is the undertaking of a whole life"],["humanities","Thinkers and theories","Twin forces marginalised the women of early analytic philosophy. Correct those mistakes, and the next generation benefits"],["pragmatism","Thinkers and theories","Ambedkar was not only a politician, but a profound thinker whose philosophy of democracy challenged the caste system"],["historian","Thinkers and theories","Demonised by the political establishment for his radical, dissenting views, this 18th-century Welsh polymath deserves better"],["secrets","Thinkers and theories","Jacques Derrida was fascinated by the figure of the Marrano Jew, whose identity could barely be told even to themselves"],["plato","Thinkers and theories","Scholars cannot agree whether the letters of Plato are fake or genuine. Is this just a symptom of misplaced reverence?"],["hegel","Thinkers and theories","Alexandre Kojève was an immense influence on many French thinkers. What was so compelling about his lectures on Hegel?"],["feminist","Thinkers and theories","Were it not for her friendship with John Locke, the radical feminist gems of philosopher Damaris Masham might be unknown"],["existentialism","Thinkers and theories","Sartre gets much of the credit for existentialism. Karl Jaspers not only preceded him, but offered a way out of despair"],["worlds","Thinkers and theories","Bruno Latour showed us how to think with the things of the world, respecting their right to exist and act on their own terms"],["scholars","Thinkers and theories","Eric Voegelin and Hans Kelsen fled the Nazis. In the US, they clashed over the nature of modernity and government"],["fichte","Thinkers and theories","Inspired by Kant, Fichte launched a radical philosophical system based on subjectivity and aspiring to freedom for all"],["kierkegaard","Thinkers and theories","In the long 19th century, many women philosophers were marginalised or ignored. We need to rediscover them"],["totalitarianism","Thinkers and theories","From the ashes of the Second World War, Günther Anders forecast a new catastrophe: technology would overwhelm its creators"],["france","Thinkers and theories","A golden generation of French philosophers dismantled truth and other traditional ideas. What next for their successors?"],["scientist","Thinkers and theories","The history of ideas still struggles to remember the names of notable women philosophers. Mary Hesse is a salient example"],["humility","Thinkers and theories","The desire for certainty is often foolish and sometimes dangerous. Scepticism undermines it, both in oneself and in others"],["nietzsche","Thinkers and theories","Some see Plato as a pure rationalist, others as a fantasti ...
# UMAP time: 0:00:11.329655

# %% [markdown]
# Essays differ from e.g. scientific papers or social media messages in that they by design don't have to stick to one topic, so it probably isn't surprising that we have a fair amount of mixing here; especially since the differences among these categories are somewhat arbitrary.
