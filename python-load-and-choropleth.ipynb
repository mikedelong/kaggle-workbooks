# %%
import pandas as pd
raw_df = pd.read_excel(io='/kaggle/input/global-terrorism-index-2023/Global Terrorism Index 2023.xlsx', sheet_name='Combined raw')
raw_df.head()
# Out:
#   iso3c      Country  Rank     Score  Incidents  Fatalities  Injuries  \
# 0   IRQ         Iraq     1  9.599967       1288        2086      5050
# 1   PAK     Pakistan     2  9.152620        638        1322      2297
# 2   AFG  Afghanistan     3  9.134265        507        1511      2612
# 3   SYR        Syria     4  8.238079        168        1014      1833
# 4   YEM        Yemen     5  8.098513        219         651       798
#
#    Hostages  Year
# 0        16  2012
# 1       160  2012
# 2        67  2012
# 3        71  2012
# 4       121  2012

# %%
from plotly.express import choropleth
choropleth(data_frame=raw_df[raw_df['Year'] == 2022], locations='iso3c', color='Score')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
overall_df = pd.read_excel(io='/kaggle/input/global-terrorism-index-2023/Global Terrorism Index 2023.xlsx', sheet_name='Overall Scores')
overall_df.head()
# Out:
#        Country Iso3c  2012 Rank  2012 Score  2013 Rank  2013 Score  2014 Rank  \
# 0  Afghanistan   AFG          3    9.134265          3    8.935458          4
# 1      Albania   ALB         97    0.826319         99    0.508313        105
# 2      Algeria   DZA         14    6.695682         16    6.476254         20
# 3       Angola   AGO         72    2.364660         82    1.657740         74
# 4    Argentina   ARG         63    2.810899         66    2.581995         75
#
#    2014 Score  2015 Rank  2015 Score  ...  2018 Rank  2018 Score  2019 Rank  \
# 0    8.899861          3    8.864294  ...          2    9.066529          1
# 1    0.226891        106    0.000000  ...        110    0.000000        112
# 2    6.129568         26    5.794741  ...         36    5.113016         39
# 3    2.016820         90    1.241050  ...         90    1.319722         96
# 4    1.991258         94    1.154499  ...         60    3.393403         63
#
# ...

# %%
choropleth(data_frame=overall_df, locations='Iso3c', color='2022 Score')
# Out:
# <div>                            <div id="a5ba1c0a-1424-4f43-a639-ee46263cca49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5ba1c0a-1424-4f43-a639-ee46263cca49")) {                    Plotly.newPlot(                        "a5ba1c0a-1424-4f43-a639-ee46263cca49",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Iso3c=%{location}\u003cbr\u003e2022 Score=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locations":["AFG","ALB","DZA","AGO","ARG","ARM","AUS","AUT","AZE","BHR","BGD","BLR","BEL","BEN","BTN","BOL","BIH","BWA","BRA","BGR","BFA","BDI","KHM","CMR","CAN","CAF","TCD","CHL","CHN","COL","CRI","CIV","HRV","CUB","CYP","CZE","COD","DNK","DJI","DOM","ECU","EGY","SLV","GNQ","ERI","EST","SWZ","ETH","FIN","FRA","GAB","GEO",
# ...
