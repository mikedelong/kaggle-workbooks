# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/us-school-scores/school_scores.csv')
df.head()
# Out:
#    Year State.Code  State.Name  Total.Math  Total.Test-takers  Total.Verbal  \
# 0  2005         AL     Alabama         559               3985           567
# 1  2005         AK      Alaska         519               3996           523
# 2  2005         AZ     Arizona         530              18184           526
# 3  2005         AR    Arkansas         552               1600           563
# 4  2005         CA  California         522             186552           504
#
#    Academic Subjects.Arts/Music.Average GPA  \
# 0                                      3.92
# 1                                      3.76
# 2                                      3.85
# 3                                      3.90
# 4                                      3.76
#
#    Academic Subjects.Arts/Music.Average Years  \
# 0                                         2.2
# 1                                         1.9
# 2                                         2.1
# 3                                         2.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 99 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Year                                                     577 non-null    int64
#  1   State.Code                                               577 non-null    object
#  2   State.Name                                               577 non-null    object
#  3   Total.Math                                               577 non-null    int64
#  4   Total.Test-takers                                        577 non-null    int64
#  5   Total.Verbal                                             577 non-null    int64
#  6   Academic Subjects.Arts/Music.Average GPA                 577 non-null    float64
#  7   Academic Subjects.Arts/Music.Average Years               577 non-null    float64
# ...

# %%
df['Year'].value_counts().sort_index().plot(kind='bar', legend=True)
# Out:
# <Axes: xlabel='Year'>

# %%
from matplotlib.pyplot import subplots
_, ax = subplots(figsize=(14, 6))
df['State.Code'].value_counts().sort_index().plot(ax=ax, kind='bar', legend=True)
# Out:
# <Axes: xlabel='State.Code'>

# %%
df.nunique()
# Out:
# Year                                               11
# State.Code                                         53
# State.Name                                         53
# Total.Math                                        159
# Total.Test-takers                                 561
#                                                  ...
# Score Ranges.Between 700 to 800.Math.Males        465
# Score Ranges.Between 700 to 800.Math.Total        497
# Score Ranges.Between 700 to 800.Verbal.Females    432
# Score Ranges.Between 700 to 800.Verbal.Males      445
# Score Ranges.Between 700 to 800.Verbal.Total      494
# Length: 99, dtype: int64
