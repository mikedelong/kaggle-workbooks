# %%
import pandas as pd
usecols = ['index', 'Year', 'GenArea', 'Area', 'Field', 'Name', 'Description']
df = pd.read_csv(filepath_or_buffer='/kaggle/input/california-university-fields-of-study-distributi/Courses_Berkeley_2018-01-15.csv',
                 index_col=['index'], usecols=usecols)
df = df[usecols[1:]]
df.head()
# Out:
#        Year       GenArea                      Area              Field  \
# index
# 0      1967   Engineering  Aeronautical Engineering  Aerospace Studies
# 1      2011  Professional           Health Sciences      Public Health
# 2      2011  Professional           Health Sciences      Public Health
# 3      2011  Professional           Health Sciences      Public Health
# 4      1971   Engineering  Aeronautical Engineering  Aerospace Studies
#
#                                                     Name  \
# index
# 0                       Officer Basic Military Training
# 1                             Drugs, Health, and Society
# 2      Policy, Planning , and Evaluation of Health Pr...
# 3      Cognitive Science C1 Molecularand Cell Biology...
# 4                    Officer Advanced Military Training
#
#                                              Description
# index
# 0       (6) Study of world military systems and basic...
# ...

# %% [markdown]
# Let's just load the data we're going to use, and let's put the columns in order from most general to most specific.

# %%
from plotly.express import histogram
histogram(data_frame=df, x='Year')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# The number of courses increases steadily if not monotonically; let's start with the earliest/smallest year.

# %%
df.nunique()
# Out:
# Year               98
# GenArea             6
# Area               90
# Field             306
# Name            60402
# Description    214230
# dtype: int64

# %%
df['Year'].value_counts()[-5:]
# Out:
# Year
# 1903    638
# 1901    610
# 1904    598
# 1909    585
# 1900    528
# Name: count, dtype: int64

# %%
y1900_df = df[df['Year'] == 1900]
y1900_df.nunique()
# Out:
# Year             1
# GenArea          6
# Area            23
# Field           26
# Name           488
# Description    440
# dtype: int64

# %% [markdown]
# In 1900 we have more areas than fields, which is weird; we'll need to sort that out eventually.

# %%
import networkx as nx
G = nx.Graph()
G.add_node(node_for_adding='root')
for genarea in y1900_df['GenArea'].unique().tolist():
    G.add_edge(u_of_edge='root', v_of_edge=genarea)
print(G)
# Out:
# Graph with 7 nodes and 6 edges
