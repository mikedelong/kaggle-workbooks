# %%
import pandas as pd

encoding = 'windows-1250'
CENTRAL = '/kaggle/input/global-debt-data/central_government_debt.csv'

central_df = pd.read_csv(filepath_or_buffer=CENTRAL, encoding=encoding, ).drop(columns=['indicator_name'])
central_t_df = central_df.T
central_t_df.columns = central_t_df.iloc[0]
central_t_df = central_t_df.tail(len(central_t_df)-1).reset_index()
central_t_df.head()
# Out:
# country_name index Afghanistan Albania Algeria Angola Antigua and Barbuda  \
# 0             1950         NaN     NaN     NaN    NaN                 NaN
# 1             1951         NaN     NaN     NaN    NaN                 NaN
# 2             1952         NaN     NaN     NaN    NaN                 NaN
# 3             1953         NaN     NaN     NaN    NaN                 NaN
# 4             1954         NaN     NaN     NaN    NaN                 NaN
#
# country_name Argentina Armenia   Australia    Austria  ... United Kingdom  \
# 0                 20.5     NaN  109.598544  20.926788  ...            NaN
# 1                 17.4     NaN   86.927242  14.439416  ...            NaN
# 2                 18.7     NaN   85.901176  12.841726  ...            NaN
# 3                 21.4     NaN   79.711667  15.711377  ...            NaN
# 4                 23.9     NaN   76.699146  13.668105  ...            NaN
#
# country_name United States Uruguay Vanuatu Venezuela Vietnam  \
# ...

# %%
from plotly.express import line
line(data_frame=central_t_df, x='index', y=central_t_df.columns[1:], log_y=False, height=1200)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
