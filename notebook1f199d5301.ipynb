# %%
import pandas as pd

DATA = '/kaggle/input/immigrants-by-citizenship-and-age/DIOC_CITIZEN_AGE_14042024231324790.csv'

df = pd.read_csv(filepath_or_buffer=DATA).drop(columns=['Flag Codes', 'Flags'])

df.head()
# Out:
#    COUB Country of birth      FBORN       Place of birth EDU Education level  \
# 0  AFRI           Africa          1         Foreign-born   2       ISCED 3/4
# 1  AFRI           Africa          1         Foreign-born   2       ISCED 3/4
# 2  AFRI           Africa          1         Foreign-born   2       ISCED 3/4
# 3  AFRI           Africa          1         Foreign-born   2       ISCED 3/4
# 4  AFRI           Africa  ALL_FBORN  All places of birth   2       ISCED 3/4
#
#     AGE          Age      NAT                          Citizenship  COU  \
# 0  3_10  25-64 years        2           Citizen of another country  AUS
# 1  3_10  25-64 years       99           Unknown citizenship status  AUS
# 2  3_10  25-64 years        1  Citizen of the country of residence  AUS
# 3  3_10  25-64 years  ALL_NAT                     All citizenships  AUS
# 4  3_10  25-64 years        2           Citizen of another country  AUS
#
#   Country of residence  Value
# 0            Australia   8034
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30113 entries, 0 to 30112
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   COUB                  30113 non-null  object
#  1   Country of birth      30113 non-null  object
#  2   FBORN                 30113 non-null  object
#  3   Place of birth        30113 non-null  object
#  4   EDU                   30113 non-null  object
#  5   Education level       30113 non-null  object
#  6   AGE                   30113 non-null  object
#  7   Age                   30113 non-null  object
#  8   NAT                   30113 non-null  object
#  9   Citizenship           30113 non-null  object
#  10  COU                   30113 non-null  object
#  11  Country of residence  30113 non-null  object
#  12  Value                 30113 non-null  int64
# dtypes: int64(1), object(12)
# memory usage: 3.0+ MB

# %%
df.nunique()
# Out:
# COUB                        8
# Country of birth            8
# FBORN                       4
# Place of birth              4
# EDU                         5
# Education level             5
# AGE                         5
# Age                         5
# NAT                         4
# Citizenship                 4
# COU                        28
# Country of residence       28
# Value                   12071
# dtype: int64

# %%
from plotly import express

express.parallel_categories(data_frame=df, dimensions=['Country of birth', 'Country of residence'], )
# express.parallel_coordinates(data_frame=df, dimensions=['Country of birth', 'Country of residence'], )
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
