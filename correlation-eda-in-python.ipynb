# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/network-slicing-in-5g/train_dataset.csv')
df.head(n=10)

# %%
df.info()

# %%
from plotly.express import imshow
imshow(img=df.corr()['slice Type'].to_frame().T)

# %% [markdown]
# What really jumps out here? The fact that IoT and slice Type are highly correlated. So we would expect to see it rank high in feature importance.

# %%
imshow(df.drop(columns='slice Type').corr()).show()
imshow(pd.read_csv(filepath_or_buffer='/kaggle/input/network-slicing-in-5g/test_dataset.csv').corr()).show()
