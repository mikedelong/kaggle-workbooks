# %%
import pandas as pd
CRASH2019 = '/kaggle/input/traffic-data-city-of-bloomington/city-of-bloomington-117733fb-31cb-480a-8b30-fbf425a690cd/crash-data-monroe-county-2019-3.csv'
df = pd.read_csv(filepath_or_buffer=CRASH2019, encoding='Windows-1252', parse_dates=['Collision Date'])
df.head()
# Out:
#    Master Record Number                       Agency Local Code  County  \
# 0             903289180               BLOOMINGTON PD   B1900016  MONROE
# 1             903289429               BLOOMINGTON PD   B1900080  MONROE
# 2             903289340  INDIANA UNIV BLOOMINGTON PD     190001  MONROE
# 3             903289285               BLOOMINGTON PD   B1900040  MONROE
# 4             903291376                    MONROE SD     M19A15  MONROE
#
#       Township         City Collision Date Collision Time  Vehicles Involved  \
# 0  BLOOMINGTON  BLOOMINGTON     2019-01-01        1:50 AM                  2
# 1  BLOOMINGTON  BLOOMINGTON     2019-01-01        6:39 PM                  2
# 2  BLOOMINGTON  BLOOMINGTON     2019-01-01       12:47 PM                  1
# 3  BLOOMINGTON  BLOOMINGTON     2019-01-01        8:00 AM                  1
# 4  BLOOMINGTON  BLOOMINGTON     2019-01-01        4:55 AM                  1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3848 entries, 0 to 3847
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Master Record Number      3848 non-null   int64
#  1   Agency                    3848 non-null   object
#  2   Local Code                3848 non-null   object
#  3   County                    3848 non-null   object
#  4   Township                  3848 non-null   object
#  5   City                      3847 non-null   object
#  6   Collision Date            3848 non-null   datetime64[ns]
#  7   Collision Time            3848 non-null   object
#  8   Vehicles Involved         3848 non-null   int64
#  9   Trailers Involved         3758 non-null   float64
#  10  Number Injured            3837 non-null   float64
#  11  Number Dead               3843 non-null   float64
#  12  Number Deer               3846 non-null   float64
# ...

# %%
from plotly.express import histogram
for color in [item for item in df.columns.tolist() if item.endswith('?')]:
    histogram(data_frame=df, x='Collision Date', color=color).show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from plotly.express import scatter_geo
scatter_geo(data_frame=df[df['Latitude'] != 0], lat='Latitude', lon='Longitude', fitbounds='locations', color='City',
           height=800)
# Out:
# <div>                            <div id="e33fabe9-beb3-4284-9303-112b3087c8fb" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e33fabe9-beb3-4284-9303-112b3087c8fb")) {                    Plotly.newPlot(                        "e33fabe9-beb3-4284-9303-112b3087c8fb",                        [{"geo":"geo","hovertemplate":"City=BLOOMINGTON\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[39.16891463,39.169065,39.15555,39.20772792,39.168752,39.17637542,39.11460543,39.175952,39.16657314,39.137088,39.17157317,39.14663,39.14186,39.164255,39.16733,39.156255,39.178992,39.144752,39.250688,39.18686,39.16152,39.10793776,39.179248,39.156255,39.16627714,39.11108,39.020048,39.172752,39.16424,39.1631,39.1727
# ...

# %%
df.nunique()
# Out:
# Master Record Number        3847
# Agency                        11
# Local Code                  3624
# County                         1
# Township                      11
# City                           5
# Collision Date               364
# Collision Time              1197
# Vehicles Involved              7
# Trailers Involved              3
# Number Injured                 8
# Number Dead                    2
# Number Deer                    3
# House Number                 440
# Roadway Name                 750
# Roadway Suffix                26
# Roadway Number                37
# Roadway Interchange           13
# Roadway Ramp                   7
# Roadway Id                   889
# Intersecting Road           1006
# Intersecting Road Number      21
# Mile Marker                   53
# Interchange                    0
# Corporate Limits?              2
# Property Type                  3
# Feet From                    169
# Direction                      4
# ...

# %% [markdown]
# Honestly without a research question it's hard to know how to proceed here; the map isn't especially interesting, and we don't really see any obvious causal relationships in the data.
