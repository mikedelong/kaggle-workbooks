# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/scotlands-common-good/National-Common-Good-Asset-Register-Data-FINAL-for-upload-Full-Data-3.csv',
                index_col=['asset_id'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2960 entries, 1 to 2960
# Data columns (total 19 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   asset_name                              2960 non-null   object
#  1   asset_description                       1629 non-null   object
#  2   moveable_asset                          2952 non-null   object
#  3   address_1                               1731 non-null   object
#  4   address_2                               539 non-null    object
#  5   address_3                               34 non-null     object
#  6   town_or_city                            2090 non-null   object
#  7   postcode                                1137 non-null   object
#  8   latitude                                1226 non-null   object
#  9   longitude                               1225 non-null   float64
# ...

# %%
df.nunique()
# Out:
# asset_name                                2341
# asset_description                          476
# moveable_asset                               2
# address_1                                  905
# address_2                                  150
# address_3                                   19
# town_or_city                               125
# postcode                                   462
# latitude                                   621
# longitude                                  619
# Google Maps                                622
# common_good_fund_name                      112
# local_authority                             27
# asset_value                                181
# date_last_updated                            3
# additional_info                              9
# local_authority_asset_reference_number    1392
# uprn                                       447
# Source                                      28
# dtype: int64

# %%
df.head()
# Out:
#                        asset_name  \
# asset_id
# 1              Oban Swimming Pool
# 2             Inverurie Town Hall
# 3                  The Grand Hall
# 4         West Links Golf Course
# 5            Bearsden Burgh Hall
#
#                                           asset_description moveable_asset  \
# asset_id
# 1                                             Swimming Pool   Non-moveable
# 2         Inverurie Town Hall is a municipal building in...   Non-moveable
# 3         The Palace Theatre & Grand Hall Complex is a m...   Non-moveable
# 4         The West Links Course is a true links located ...   Non-moveable
# 5         The existing Bearsden Burgh hall was completel...   Non-moveable
#
#                    address_1      address_2 address_3   town_or_city  \
# asset_id
# 1         Atlantis Leisure,   Dalriach Road       NaN           Oban
# 2                        NaN            NaN       NaN     Inverrurie
# ...

# %%
from plotly.express import scatter_geo
scatter_geo(data_frame=df, lat='latitude', lon='longitude',  fitbounds='locations', basemap_visible=True, hover_name='asset_name',
            color='local_authority',
            scope='europe').update_layout(autosize=True, ).show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
sheet7_df = pd.read_csv(filepath_or_buffer='/kaggle/input/scotlands-common-good/National-Common-Good-Asset-Register-Data-FINAL-for-upload-Sheet7-1.csv',
                       index_col=['asset_id'])
sheet7_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1226 entries, 1 to 1226
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   asset_name                              1226 non-null   object
#  1   asset_description                       866 non-null    object
#  2   moveable_asset                          1223 non-null   object
#  3   address_1                               619 non-null    object
#  4   address_2                               497 non-null    object
#  5   address_3                               28 non-null     object
#  6   town_or_city                            1098 non-null   object
#  7   postcode                                1125 non-null   object
#  8   latitude                                1226 non-null   object
#  9   longitude                               1225 non-null   float64
# ...

# %%
df.head()
# Out:
#                        asset_name  \
# asset_id
# 1              Oban Swimming Pool
# 2             Inverurie Town Hall
# 3                  The Grand Hall
# 4         West Links Golf Course
# 5            Bearsden Burgh Hall
#
#                                           asset_description moveable_asset  \
# asset_id
# 1                                             Swimming Pool   Non-moveable
# 2         Inverurie Town Hall is a municipal building in...   Non-moveable
# 3         The Palace Theatre & Grand Hall Complex is a m...   Non-moveable
# 4         The West Links Course is a true links located ...   Non-moveable
# 5         The existing Bearsden Burgh hall was completel...   Non-moveable
#
#                    address_1      address_2 address_3   town_or_city  \
# asset_id
# 1         Atlantis Leisure,   Dalriach Road       NaN           Oban
# 2                        NaN            NaN       NaN     Inverrurie
# ...

# %%
sheet7_df.head()
# Out:
#                          asset_name      asset_description moveable_asset  \
# asset_id
# 1               Clock workings only   former Old Town Hall   Non-moveable
# 2                  Whithorn Library                    NaN   Non-moveable
# 3               Tolbooth Art Centre                    NaN   Non-moveable
# 4         Kirkcudbright Art Gallery                    NaN   Non-moveable
# 5                     Tennis Courts                    NaN   Non-moveable
#
#                   address_1        address_2 address_3    town_or_city  \
# asset_id
# 1                        67    George Street       NaN        Whithorn
# 2                        60   St John Street       NaN        Whithorn
# 3               High Street              NaN       NaN   Kirkcudbright
# 4          St Mary's Street              NaN       NaN   Kirkcudbright
# 5          St Mary's Street              NaN       NaN   Kirkcudbright
#
#          postcode   latitude  longitude common_good_fund_name  \
# ...

# %%
scatter_geo(data_frame=sheet7_df, lat='latitude', lon='longitude',  fitbounds='locations', basemap_visible=True, hover_name='asset_name',
            color='town_or_city',
            scope='europe').update_layout(autosize=True, ).show()
# Out:
# <div>                            <div id="ec15cf83-75c1-4d19-b5f2-6b3e1dd874eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec15cf83-75c1-4d19-b5f2-6b3e1dd874eb")) {                    Plotly.newPlot(                        "ec15cf83-75c1-4d19-b5f2-6b3e1dd874eb",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etown_or_city= Whithorn\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Clock workings only","Whithorn Library"],"lat":["54.732826","54.73524"],"legendgroup":" Whithorn","lon":[-4.4162091,-4.4145975],"marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":" Whithorn","showlegend":true
# ...
