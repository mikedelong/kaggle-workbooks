# %%
import pandas as pd
from json import loads
from ast import literal_eval
df = pd.read_csv(filepath_or_buffer='/kaggle/input/text-and-meta-data-analysis/train.csv', )
df['perplexity_score'] = df['meta'].apply(func=lambda x: literal_eval(x)['perplexity_score'])
df['pile_set_name'] = df['meta'].apply(func=lambda x: literal_eval(x)['pile_set_name'])
df = df.drop(columns=['meta'])
df = df.dropna(subset=['text'])
df.head()
# Out:
#                                                 text  perplexity_score  \
# 0  It is done, and submitted. You can play “Survi...             327.0
# 1  <?xml version="1.0" encoding="UTF-8"?>\r\n<seg...             977.7
# 2  Article content\n\nHuman behavior has a tremen...             609.4
# 3  Topic: reinvent midnight madness\n\nAmazon ann...             262.3
# 4  About Grand Slam Fishing Charters\n\nAs a fami...             858.9
#
#   pile_set_name
# 0       Pile-CC
# 1        Github
# 2  OpenWebText2
# 3       Pile-CC
# 4       Pile-CC

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99996 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   text              99996 non-null  object
#  1   perplexity_score  99996 non-null  float64
#  2   pile_set_name     99996 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 3.1+ MB

# %%
df['xml'] = df['text'].apply(func=lambda x: x.startswith('<?xml'))
print('We have {} rows that are XML.'.format(df['xml'].sum()))
# Out:
# We have 321 rows that are XML.

# %%
from numpy import log
# Let's clean up the text
df['clean'] = df['text'].str.replace('\n', ' ') # remove newlines
# extract the clean data as a seprate DataFrame
clean_df = df[~df['xml']].drop(columns=['text', 'perplexity_score', 'pile_set_name', 'xml']).rename(columns={'clean': 'text'})
clean_df['text length'] = clean_df['text'].str.len()
clean_df['log text length'] = log(clean_df['text length'])
clean_df.head()
# Out:
#                                                 text  text length  \
# 0  It is done, and submitted. You can play “Survi...        13274
# 2  Article content  Human behavior has a tremendo...         1235
# 3  Topic: reinvent midnight madness  Amazon annou...          384
# 4  About Grand Slam Fishing Charters  As a family...         1754
# 5  Q:  Why was Mundungus banned from the Hog's He...         2014
#
#    log text length
# 0         9.493563
# 2         7.118826
# 3         5.950643
# 4         7.469654
# 5         7.607878

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text

text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
preprocessor = hub.KerasLayer('https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3')
encoder_inputs = preprocessor(text_input)
encoder = hub.KerasLayer('https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4', trainable=True)
outputs = encoder(encoder_inputs)
pooled_output = outputs['pooled_output']
sequence_output = outputs['sequence_output']
embedding_model = tf.keras.Model(text_input, pooled_output)
embedding_model.compile(optimizer='adam', loss='mse')

# %%
from sklearn.manifold import TSNE
from arrow import now

N = 2000
# we're going to modify this so we need to make a copy
tsne_df = clean_df.sample(n=N, random_state=2023).copy()
tsne = TSNE(n_components=2, verbose=1, random_state=2023)
tsne_start = now()
tsne_df[['t0', 't1']] = tsne.fit_transform(X=embedding_model(tf.constant(tsne_df['text'].values.tolist())).numpy())
print('done in {}'.format(now() - tsne_start))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.003s...
# [t-SNE] Computed neighbors for 2000 samples in 0.262s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 1.418686
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.194382
# [t-SNE] KL divergence after 1000 iterations: 1.327663
# done in 0:09:17.319654

# %%
from plotly.express import scatter
tsne_df['short'] = tsne_df['text'].str[:40]
scatter(data_frame=tsne_df, x='t0', y='t1', hover_name='short', color='log text length')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="cc3ae276-e3d8-4bc1-805c-2dc9d633568e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc3ae276-e3d8-4bc1-805c-2dc9d633568e")) {                    Plotly.newPlot(                        "cc3ae276-e3d8-4bc1-805c-2dc9d633568e",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003et0=%{x}\u003cbr\u003et1=%{y}\u003cbr\u003elog text length=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Q:  Proper way to create an untextured, ","Q:  How to send one value after successf","2003 Clásica de San Sebastián  The 2003 ","Pearson Gardens, U.S. Virgin Islands  Pe","The studies proposed concern the synthes","Atlas-driven lung lobe segmentation in v","North to South First Aid Supplies is off","pose -10*r + 20 = -w*r. Solve 0 = r*y - ","(VALPARAISO) - A Morgan Township High Sc","Populists and socialists have one thing ","Q:  Is this the right way of finding the","Unlike most of the other projects in thi","Or what about Shiatsu and Watsu. Youve c","Cost-Cutting in New York and London = A ","METAphorisms  For META magazine, Berlin,","The police have information that the det","[Justin Timberlake & Chris Stapleton:] S","Marvel is no doubt the king of the comic","[Laparoscopy as essential method in the ","The endangered North Atlantic right whal","a\u003eb","NUMBER 13-12-00290-CR                   ","Introduction {#Sec1} ============  Metab","Natalie Wickman  Milwaukee Journal Senti","At dinner with Bob one night, I averred ","Meta  Second class from the second sessi","PROCESS takes a warmly satirical look at","When I was a #cool #teen, it was a more ","\"All-included\", luxurious and comfortabl","Despite their different political belief","Patient safety in emergency medical serv","Program pro udržitelnou budoucnost všeob","Shaquille O’Neal will be playing basketb","Albaumer Bach  Albaumer Bach is a river ","Living in New York with his heart in Ban","A leading South African newspaper has bl","Q:  Preventing directory traversal with ","Members of the Gujjar and Bakarwal commu","The present invention generally relates ","--- title: Moving ACE3 frameworks to CBA","On Tuesday, April 6, the California Sena","Theoretical study of the temperature dep","(***************************************","Specific anticancer activity of a new bi","Q:  Java 8 Convert a stream of set to Ma","after \"Payment Date(s)\":   Payments:  Fo","According to the estimates of HASH Crypt","--- title: \"Delete androidStoreApp\" desc","The preservation of food by dehydration ","Why Facebook comments is a bad idea for ","Ole Morten Geving  Ole Morten Geving (bo","Distributed systems are like 3D brain te","\u002f*  * Copyright (C) 2014 Saravan Pantham","DNA Modifications: Naturally More Error ","Machine Assisted Translation of Health M","The role of pelvic traction in the manag","Courses  Course Library  This course wil","Archive  HTMLfixIT Archive for February,","Sam's Chicken  Sam's Chicken is a Britis","Is this how aliens text their friends? O","class VisibilityToggle extends React.Com","Coby Whitmore  Maxwell Coburn Whitmore (","Introduction {#sec1} ============  Nanos","Q:  How does ICommand's CanExecute metho","CRATER mouthpiece lubricant is needed to","\u002f\u002f Licensed under the Apache License, Ve","Lajim announced on Saturday that he was ","Q:  MySql Query Help needed  I have a ta","40468959? 7 What is the tens digit of 81","Sweet nothings  Under attack from both t","The Runners production discography  This","National Life Group  National Life Group","715\u002f8 + -89. Put b, 0.3, -4, 0.5 in decr","Adorable! Even drooling-in-her-sleep Rar","How We Do (12)","Why did the Western Roman Empire collaps","Q:  Does one h ...

# %%
from plotly.express import histogram
histogram(data_frame=tsne_df, x='log text length')
# Out:
# <div>                            <div id="cabc93a9-4d7a-48c8-8494-c8ef590dde73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("