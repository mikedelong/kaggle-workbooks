# %%
import pandas as pd

DATA = '/kaggle/input/bicycle-racks/cykelstativ.csv'
df = pd.read_csv(filepath_or_buffer=DATA, parse_dates=['reg_dato', 'rettet_dato']).drop(columns='faerdigmelding')
df.head()
# Out:
#              FID    id  vejkode              vejnavn  park_id  \
# 0  cykelstativ.1  6450      4.0  Abel Cathrines Gade      0.0
# 1  cykelstativ.2  6451      4.0  Abel Cathrines Gade      0.0
# 2  cykelstativ.3  7174     20.0         Absalonsgade      0.0
# 3  cykelstativ.4  6877     20.0         Absalonsgade      0.0
# 4  cykelstativ.5  7175     20.0         Absalonsgade      0.0
#
#                        bydel       stativ_type     stativ_placering  \
# 0  Vesterbro-Kongens Enghave                NO  På fortovsudvidelse
# 1  Vesterbro-Kongens Enghave                NO  På fortovsudvidelse
# 2  Vesterbro-Kongens Enghave  Ikke registreret     Ikke registreret
# 3  Vesterbro-Kongens Enghave              Noli         På gadeareal
# 4  Vesterbro-Kongens Enghave  Ikke registreret     Ikke registreret
#
#   stativ_udformning    cykler_retning  ...  bemaerkning  \
# 0       Enkeltsidet  Ikke registreret  ...          NaN
# 1       Enkeltsidet  Ikke registreret  ...          NaN
# ...

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
gdf = gpd.read_file(DATA)
gdf.crs = 'epsg:4326'
gdf.to_crs(4326)
# Out:
#                    FID    id vejkode              vejnavn park_id  \
# 0        cykelstativ.1  6450    0004  Abel Cathrines Gade       0
# 1        cykelstativ.2  6451    0004  Abel Cathrines Gade       0
# 2        cykelstativ.3  7174    0020         Absalonsgade       0
# 3        cykelstativ.4  6877    0020         Absalonsgade       0
# 4        cykelstativ.5  7175    0020         Absalonsgade       0
# ...                ...   ...     ...                  ...     ...
# 6321  cykelstativ.6392  8002
# 6322  cykelstativ.6393  7859
# 6323  cykelstativ.6410  7706
# 6324  cykelstativ.6413  8086
# 6325  cykelstativ.6424  7724
#
#                           bydel       stativ_type     stativ_placering  \
# 0     Vesterbro-Kongens Enghave                NO  På fortovsudvidelse
# 1     Vesterbro-Kongens Enghave                NO  På fortovsudvidelse
# 2     Vesterbro-Kongens Enghave  Ikke registreret     Ikke registreret
# ...

# %%
gdf.head()
# Out:
#              FID    id vejkode              vejnavn park_id  \
# 0  cykelstativ.1  6450    0004  Abel Cathrines Gade       0
# 1  cykelstativ.2  6451    0004  Abel Cathrines Gade       0
# 2  cykelstativ.3  7174    0020         Absalonsgade       0
# 3  cykelstativ.4  6877    0020         Absalonsgade       0
# 4  cykelstativ.5  7175    0020         Absalonsgade       0
#
#                        bydel       stativ_type     stativ_placering  \
# 0  Vesterbro-Kongens Enghave                NO  På fortovsudvidelse
# 1  Vesterbro-Kongens Enghave                NO  På fortovsudvidelse
# 2  Vesterbro-Kongens Enghave  Ikke registreret     Ikke registreret
# 3  Vesterbro-Kongens Enghave              Noli         På gadeareal
# 4  Vesterbro-Kongens Enghave  Ikke registreret     Ikke registreret
#
#   stativ_udformning    cykler_retning  ...                 reg_dato  \
# 0       Enkeltsidet  Ikke registreret  ...  2017-01-30T13:06:53.911
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6326 entries, 0 to 6325
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   FID                 6326 non-null   object
#  1   id                  6326 non-null   int64
#  2   vejkode             6321 non-null   float64
#  3   vejnavn             6321 non-null   object
#  4   park_id             4984 non-null   float64
#  5   bydel               6220 non-null   object
#  6   stativ_type         6326 non-null   object
#  7   stativ_placering    6326 non-null   object
#  8   stativ_udformning   6326 non-null   object
#  9   cykler_retning      6326 non-null   object
#  10  antal_pladser       6319 non-null   float64
#  11  stativ_tilstand     6326 non-null   object
#  12  stativ_ejer         6326 non-null   object
#  13  stativ_foto         622 non-null    object
#  14  bemaerkning         514 non-null    object
# ...
