# %% [markdown]
# <a href="https://www.kaggle.com/code/mikedelong/male-height-eda-with-lots-of-plots?scriptVersionId=160537049" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

HEIGHT = '/kaggle/input/male-height-dataset/height_dataset.csv'
REGION = '/kaggle/input/country-mapping-iso-continent-region/continents2.csv'

df = pd.read_csv(filepath_or_buffer=HEIGHT, decimal=',', sep=';').drop(columns=['ccode'])
df = df.merge(right=pd.read_csv(filepath_or_buffer=REGION, usecols=['name', 'alpha-3', 'region', 'sub-region']), right_on='name', left_on='country.name').drop(columns=['country.name'])

df.head()
# Out:
#    year  value     name alpha-3  region      sub-region
# 0  1550  167.8  Germany     DEU  Europe  Western Europe
# 1  1650  169.8  Germany     DEU  Europe  Western Europe
# 2  1710  164.0  Germany     DEU  Europe  Western Europe
# 3  1720  163.7  Germany     DEU  Europe  Western Europe
# 4  1730  163.8  Germany     DEU  Europe  Western Europe

# %%
df.nunique()
# Out:
# year           37
# value         695
# name          145
# alpha-3       145
# region          5
# sub-region     15
# dtype: int64

# %%
from plotly.express import line
line(data_frame=df, x='year', y='value', color='name', height=2400, facet_col='region', facet_col_wrap=1)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0ad6425a-fa87-4c53-8046-849db36d34be" class="plotly-graph-div" style="height:2400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ad6425a-fa87-4c53-8046-849db36d34be")) {                    Plotly.newPlot(                        "0ad6425a-fa87-4c53-8046-849db36d34be",                        [{"hovertemplate":"name=Germany\u003cbr\u003eregion=Europe\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":[1550,1650,1710,1720,1730,1740,1750,1760,1770,1780,1790,1800,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980],"xaxis":"x5","y":[167.8,169.8,164.0,163.7,163.8,163.6,168.0,168.3,168.4,165.4,163.3,164.3,167.8,167.3,166.8,166.6,163.8,165.5,166.9,167.9,168.6,169.2,170.5,173.3,174.0,175.2,176.8,178.9,179.4,180.5],"yaxis":"y5","type":"scattergl"},{"hovertemplate":"name=Poland\u003cbr\u003eregion=Europe\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Poland","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Poland","showlegend":true,"x":[1550,1650,1840,1860,1870,1880,1890,1900,1910,1930,1940,1950,1960,1980],"xaxis":"x5","y":[170.1,168.2,163.1,165.5,166.3,166.8,167.2,166.568,169.0,173.0,170.5,173.2,175.3,177.4],"yaxis":"y5","type":"scattergl"},{"hovertemplate":"name=France\u003cbr\u003eregion=Europe\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","showlegend":true,"x":[1660,1670,1680,1690,1710,1720,1730,1740,1750,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980],"xaxis":"x5","y":[162.6,161.2,161.5,161.35,165.0,163.8,166.3,167.1,166.2,163.9,163.9,164.0,164.3,165.2,165.4,165.5,165.9,166.1,166.8,167.8,168.5,169.9,171.7,173.175,174.9,175.1,176.5],"yaxis":"y5","type":"scattergl"},{"hovertemplate":"name=Russia\u003cbr\u003eregion=Europe\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russia","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Russia","showlegend":true,"x":[1700,1710,1720,1730,1740,1750,1760,1770,1780,1790,1800,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980,1990,2000],"xaxis":"x5","y":[163.9,162.8,162.4,163.7,163.9,163.0,163.3,164.5,161.8,160.3,159.8,159.8,162.1,163.0,164.2,163.4,163.3,165.8,166.6,168.3,169.2,169.1,167.0,167.9,169.0,172.0,173.6,177.0,177.0,172.1,172.6],"yaxis":"y5","type":"scattergl"},{"hovertemplate":"name=Ireland\u003cbr\u003eregion=Europe\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ireland","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ireland","showlegend":true,"x":[1710,1720,1730,1740,1750,1810,1820,1830,1840,1870,1880,1890,1900,1920,1930,1950,1960,1970,1980],"xaxis":"x5","y":[167.9,166.8,167.6,167.0,166.5,168.0,165.4,168.1,160.9,168.45,168.7,169.1,170.0,171.919,173.253,174.9,175.8,176.4,176.6],"yaxis":"y5","type":"scattergl"},{"hovertemplate":"name=United Kingdom\u003cbr\u003eregion=Europe\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United Kingdom","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United Kingdom","showlegend":true,"x":[1710,1720,1730,1740,1750,1760,1770,1780,1790,1810,1820,1830,1840,1850,1860 ...

# %% [markdown]
# In a sense we want to see all the data together in a single graph, but that graph is incomprehensible; splitting the data somewhat arbitrarily by region shows that:
# 1. We don't have data from every country from every year
# 2. Generally men are getting taller over time.

# %%
line(data_frame=df[['year', 'value']].groupby(by='year').mean().reset_index(), x='year', y='value')
# Out:
# <div>                            <div id="1e8e98c1-536c-4840-80cf-a20788e4c20f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e8e98c1-536c-4840-80cf-a20788e4c20f")) {                    Plotly.newPlot(                        "1e8e98c1-536c-4840-80cf-a20788e4c20f",                        [{"hovertemplate":"year=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1550,1650,1660,1670,1680,1690,1700,1710,1720,1730,1740,1750,1760,1770,1780,1790,1800,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980,1990,2000],"xaxis":"x","y":[168.95,169.0,162.6,161.2,161.5,161.35,163.9,166.53333333333333,164.01666666666668,166.6,166.04615384615383,166.4625,166.15307692307695,165.63,164.017,163.98863636363637,162.7915789473684,165.1969375,165.56989285714286,165.4714482758621,164.185,165.0911632653061,165.43882758620688,165.90075000000002,165.82245569620252,166.21282894736842,166.66619512195123,166.8178717948718,167.237,167.47791860465117,168.66841666666667,169.4573111111111,170.45591011235956,170.68611363636364,170.67636666666667,169.20802272727272,169.82368421052632],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d": ...

# %% [markdown]
# Obviously if we are averating a different number of values at every point in time we will see impacts on the mean due to the number of values.

# %%
from plotly.express import scatter
scatter(data_frame=df, x='year', y='value', hover_name='name', color='region', trendline='lowess')
# Out:
# <div>                            <div id="fe85a527-49b3-4989-ac00-06d93d535771" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe85a527-49b3-4989-ac00-06d93d535771")) {                    Plotly.newPlot(                        "fe85a527-49b3-4989-ac00-06d93d535771",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eregion=Europe\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Poland","Poland","Poland","Poland","Poland","Poland","Poland","Poland","Poland","Poland","Poland","Poland","Poland","Poland","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","France","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Russia","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","Ireland","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Portugal","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Czech Republic","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Hungary","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Italy","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Sweden","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Spain","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Ukraine","Austria","Austria","Austria","Austria","Austria","Austri ...

# %% [markdown]
# This is probably a better plot than the global average, as different regions have data available for different ranges of years. Maybe the really striking thing here is how dramatically European men seem to have gotten taller since the Industrial Revolution.

# %%
from plotly.express import scatter
scatter(data_frame=df[['year', 'value']].groupby(by='year').mean().reset_index(), x='year', y='value', trendline='lowess')
# Out:
# <div>                            <div id="520adf5e-fbe9-4c50-9a4f-7e0008bec1ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("520adf5e-fbe9-4c50-9a4f-7e0008bec1ff")) {                    Plotly.newPlot(                        "520adf5e-fbe9-4c50-9a4f-7e0008bec1ff",                        [{"hovertemplate":"year=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1550,1650,1660,1670,1680,1690,1700,1710,1720,1730,1740,1750,1760,1770,1780,1790,1800,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980,1990,2000],"xaxis":"x","y":[168.95,169.0,162.6,161.2,161.5,161.35,163.9,166.53333333333333,164.01666666666668,166.6,166.04615384615383,166.4625,166.15307692307695,165.63,164.017,163.98863636363637,162.7915789473684,165.1969375,165.56989285714286,165.4714482758621,164.185,165.0911632653061,165.43882758620688,165.90075000000002,165.82245569620252,166.21282894736842,166.66619512195123,166.8178717948718,167.237,167.47791860465117,168.66841666666667,169.4573111111111,170.45591011235956,170.68611363636364,170.67636666666667,169.20802272727272,169.82368421052632],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1550,1650,1660,1670,1680,1690,1700,1710,1720,1730,1740,1750,1760,1770,1780,1790,1800,1810,1820,1830,1840,1850,1860,1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980,1990,2000],"xaxis":"x","y":[164.60905865014422,164.21771587308726,164.16675907436195,164.1075827002871,164.04994710183303,164.02031506762648,164.06390712317787,164.2017447518579,164.35288739212427,164.49686574253545,164.64421450685435,164.80070889644068,164.96641543760276,165.05490103591953,165.11836177430317,165.15918858241267,165.1843885737497,165.20550132258876,165.23870417705325,165.29838908466752,165.39560278595565,165.54302036934254,165.74705318116807,166.00746310890273,166.3152302333721,166.65155754699282,167.03023401754456,167.39185783540026,167.74737953488508,168.1025163855071,168.46015987009156,168.8218428455975,169.18811704571186,169.55874218500867,169.93277168781003,170.3087504842542,170.68511337858442],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888888 ...

# %% [markdown]
# This is probably the nut graf regarding global means as it implies that men have been getting taller almost monotonically since the beginning of the Industrial Revolution.

# %%
from plotly.express import scatter
scatter(data_frame=df[['name', 'value', 'region']].groupby(by=['name', 'region']).mean().reset_index().rename(columns={'value': 'mean'}).merge(right=df[['name', 'region', 'value']].groupby(by=['name', 'region']).std().reset_index().rename(columns={'value': 'stdev'}), on=['name','region']),
        x='mean', y='stdev', hover_name='name', color='region')
# Out:
# <div>                            <div id="d78dc7e9-bbe5-4867-ad5a-eb9bfd4c0ca0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d78dc7e9-bbe5-4867-ad5a-eb9bfd4c0ca0")) {                    Plotly.newPlot(                        "d78dc7e9-bbe5-4867-ad5a-eb9bfd4c0ca0",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eregion=Asia\u003cbr\u003emean=%{x}\u003cbr\u003estdev=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Armenia","Azerbaijan","Bahrain","Bangladesh","Cambodia","China","Georgia","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Kazakhstan","Kuwait","Kyrgyzstan","Laos","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","South Korea","Sri Lanka","Syria","Tajikistan","Thailand","Turkey","Turkmenistan","United Arab Emirates","Uzbekistan","Vietnam","Yemen"],"legendgroup":"Asia","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[165.878,168.82427272727273,171.42042857142857,162.83333333333334,162.12,162.04375,166.55555555555554,166.49,163.18385714285714,160.477,168.28833333333333,168.23283333333333,167.789,162.39772727272728,170.35142857142858,166.35454545454547,172.9,166.70999999999998,160.40588235294118,167.32639999999998,161.71875,163.7,162.04375,162.14677777777777,170.9,165.2806,161.69722222222222,170.85999999999999,173.55,166.20222222222222,166.737,167.2242857142857,166.0,164.35,168.43435714285715,168.11,169.05,168.58555555555554,160.09444444444443,162.98000000000002],"xaxis":"x","y":[2.6828939598873496,3.2623198215659133,0.7182271825225507,1.850225211517063,1.104513241206277,1.8708175574687405,2.2088650858122283,4.588289441611102,1.100179415937576,2.0938512124790565,2.29405886162628,1.5767321163300592,1.5273650513220365,4.3048190226979175,2.2609247265328505,3.08751150163481,null,2.5942629010954197,2.261213885348782,1.2018547333184684,5.016402263242712,1.5556349186104266,2.3785061838613357,0.6235346377262885,null,1.8696834669715199,3.671095809760943,1.2095453691366904,1.9091883092036803,5.348015467857635,3.9628708028397788,2.7013676606665866,1.2547054292883684,3.810259429891465,1.018908134089771,0.717147125769893,null,3.0385165011527944,2.171329823544653,2.35480360115233],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eregion=Europe\u003cbr\u003emean=%{x}\u003cbr\u003estdev=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Austria","Belarus","Belgium","Bulgaria","Croatia","Czech Republic","Denmark","Estonia","Finland","France","Germany","Greece","Hungary","Ireland","Italy","Latvia","Lithuania","Macedonia","Moldova","Netherlands","Norway","Poland","Portugal","Romania","Russia","Serbia","Slovakia","Slovenia","Spain","Sweden","Switzerland","Ukraine","United Kingdom"],"legendgroup":"Europe","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[169.25,167.85555555555555,168.93333333333334,167.434,170.875,168.509,167.8818695652174,172.653125,172.5,173.01153846153846,166.80092592592592,168.98000000000002,170.71599999999998,167.03621052631578,169.64852631578947,166.64153846153846,169.85183333333333,167.90833333333333,168.61725,171.536,170.895,173.16555555555556,169.44057142857145,165.40174074074073,167.1232222222222,166.2064516129032,170.20000000000002,168.04285714285714,174.25,165.74761904761903,171.61249999999998,168.89644444444446,164.6142857142857,169.69381481481483],"xaxis":"x","y":[0.9746794344808891,5.160052692642749,6.595705673643528,4.612640121328439,2.2867371223353854,5.598839912306499,5.327578883033153 ...

# %% [markdown]
# This plot has some drawbacks because it treats countries with longer time series the same as countries with shorter time series, which is probably not sensible, but it shows that
# 1. Men in Asian countries are generally shorter than men outside Asia
# 2. Men in Africa and Europe are similar heights over time, but European men have heights that vary more.

# %%
df['year'].value_counts().head(n=5)
# Out:
# year
# 1980    90
# 1950    90
# 1960    89
# 1970    88
# 1930    86
# Name: count, dtype: int64

# %% [markdown]
# Let's look at the data for 1980 since that is the one where we have the most complete dataset.

# %%
from plotly.express import choropleth
choropleth(data_frame=df[df['year'] == 1980], locations='alpha-3', color='value')
# Out:
# <div>                            <div id="30945151-f606-4174-bc89-9760c84d48d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30945151-f606-4174-bc89-9760c84d48d5")) {                    Plotly.newPlot(                        "30945151-f606-4174-bc89-9760c84d48d5",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"alpha-3=%{location}\u003cbr\u003evalue=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locations":["DEU","POL","FRA","RUS","IRL","GBR","USA","PRT","ITA","SWE","MEX","ESP","AUT","PER","NLD","IDN","BEN","MDG","MOZ","SLE","NGA","EST","BRA","BFA","CMR","CAN","CHN","COG","FIN","GAB","GHA","NOR","SEN","DNK","VNM","BLR","KHM","IND","LAO","MYS","MDA","ARM","AZE","BGD","EGY","IRN","MLI","MMR","YEM","ETH","PHL","THA","TGO","TCD","COL","GRC","GIN","MWI","NER","PRK","LKA","TZA","UGA","GUY","JPN","KEN","MAR","NPL","PNG","BOL","GTM","JAM","ZAF","ZWE","LSO","NAM","BWA","LBR","RWA","HTI","CRI","JOR","ZMB","CHL","HND","NIC","DJI","PAN","TTO","ARE"],"name":"","z":[180.5,177.4,176.5,177.0,176.6,176.83,179.0,172.13,174.48,180.4,167.806,175.6,178.8,164.236,182.7,164.01,169.163,162.874,165.15,165.8,169.503,179.1,171.7,172.829,170.967,179.6,171.5,168.369,178.2,169.7,170.005,179.7,174.254,183.2,160.1,176.4,162.5,164.437,163.6,175.1,174.225,171.653,172.153,162.377,171.283,172.37,172.238,160.1,167.6,167.253,165.6,169.7,167.7,173.3,170.6,177.3,169.49,166.244,170.651,173.8,165.8,166.861,169.274,170.5,171.66,171.221,170.29,162.953,160.9,164.191,160.8,173.6,168.1,171.004,167.386,171.343,167.1,167.264,167.162,171.494,173.6,170.29,168.194,173.1,164.663,166.4,168.893,170.0,174.4,169.05],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"o ...

# %% [markdown]
# When we use a colorbar that puts the extreme values of the data at the far ends we probably get a view that exaggerates the absolute differences between countries.

# %%
from plotly.express import histogram
histogram(data_frame=df[df['year'] == 1980].sort_values(by='region'), y='name', x='value', height=1500, color='sub-region')
# Out:
# <div>                            <div id="63517edc-8292-4644-8682-81bdf4f80da8" class="plotly-graph-div" style="height:1500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63517edc-8292-4644-8682-81bdf4f80da8")) {                    Plotly.newPlot(                        "63517edc-8292-4644-8682-81bdf4f80da8",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"sub-region=Northern Africa\u003cbr\u003esum of value=%{x}\u003cbr\u003ename=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Northern Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Northern Africa","offsetgroup":"Northern Africa","orientation":"h","showlegend":true,"x":[171.283,170.29],"xaxis":"x","y":["Egypt","Morocco"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"sub-region=Sub-Saharan Africa\u003cbr\u003esum of value=%{x}\u003cbr\u003ename=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Sub-Saharan Africa","offsetgroup":"Sub-Saharan Africa","orientation":"h","showlegend":true,"x":[170.967,167.7,168.369,171.004,169.7,170.005,168.1,174.254,171.221,169.274,166.861,172.238,170.651,166.244,167.253,169.49,172.829,171.343,167.386,165.8,168.893,168.194,169.503,167.162,167.264,173.3,169.163,162.874,165.15,167.1],"xaxis":"x","y":["Cameroon","Togo","Congo","Zimbabwe","Gabon","Ghana","South Africa","Senegal","Kenya","Uganda","Tanzania","Mali","Niger","Malawi","Ethiopia","Guinea","Burkina Faso","Namibia","Lesotho","Sierra Leone","Djibouti","Zambia","Nigeria","Rwanda","Liberia","Chad","Benin","Madagascar","Mozambique","Botswana"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"sub-region=Latin America and the Caribbean\u003cbr\u003esum of value=%{x}\u003cbr\u003ename=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America and the Caribbean","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America and the Caribbean","offsetgroup":"Latin America and the Caribbean","orientation":"h","showlegend":true,"x":[170.6,170.0,171.7,166.4,164.663,173.1,174.4,170.5,164.191,160.8,173.6,167.806,171.494,164.236,173.6],"xaxis":"x","y":["Colombia","Panama","Brazil","Nicaragua","Honduras","Chile","Trinidad and Tobago","Guyana","Bolivia","Guatemala","Jamaica","Mexico","Haiti","Peru","Costa Rica"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"sub-region=Northern America\u003cbr\u003esum of value=%{x}\u003cbr\u003ename=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Northern America","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Northern America","offsetgroup":"Northern America","orientation":"h","showlegend":true,"x":[179.0,179.6],"xaxis":"x","y":["United States","Canada"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"sub-region=Western Asia\u003cbr\u003esum of value=%{x}\u003cbr\u003ename=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Western Asia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Western Asia","offsetgroup":"Western Asia","orientation":"h","showlegend":true,"x":[170.29,169.05,171.653,167.6,172.153],"xaxis":"x","y":["Jordan","United Arab Emirates","Armenia","Yemen","Azerbaijan"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"sub-region=Southern Asia\u003cbr\u003esum of value=%{x}\u003cbr\u003ename=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Southern Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Southern Asia", ...

# %% [markdown]
# A histogram shows all the data for 1980 in context of the region/subregion and does not overstate the difference from country to country.
