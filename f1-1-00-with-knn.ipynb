# %% [markdown]
# We want to do dimension reduction so let's install UMAP.

# %%
# !pip install --quiet umap-learn

# %% [markdown]
# Now let's load up our data and do a little feature engineering to make all of our data numeric or Boolean.

# %%
import pandas as pd

DATA = '/kaggle/input/mobile-device-usage-and-user-behavior-dataset/user_behavior_dataset.csv'
TARGET = 'User Behavior Class'

df = pd.read_csv(filepath_or_buffer=DATA, index_col=['User ID'])
df = pd.get_dummies(data=df, columns=['Device Model', 'Operating System', 'Gender'])
df.head()
# Out:
#          App Usage Time (min/day)  Screen On Time (hours/day)  \
# User ID
# 1                             393                         6.4
# 2                             268                         4.7
# 3                             154                         4.0
# 4                             239                         4.8
# 5                             187                         4.3
#
#          Battery Drain (mAh/day)  Number of Apps Installed  \
# User ID
# 1                           1872                        67
# 2                           1331                        42
# 3                            761                        32
# 4                           1676                        56
# 5                           1367                        58
#
#          Data Usage (MB/day)  Age  User Behavior Class  \
# User ID
# 1                       1122   40                    4
# 2                        944   47                    3
# 3                        322   42                    2
# 4                        871   20                    3
# 5                        988   31                    3
#
#          Device Model_Google Pixel 5  Device Model_OnePlus 9  \
# User ID
# 1                               True                   False
# 2                              False                    True
# 3                              False                   False
# 4                               True                   False
# 5                              False                   False
#
#          Device Model_Samsung Galaxy S21  Device Model_Xiaomi Mi 11  \
# User ID
# 1                                  False                      False
# 2                                  False                      False
# 3                                  False                       True
# 4                                  False                      False
# 5                                  False                      False
#
#          Device Model_iPhone 12  Operating System_Android  \
# User ID
# 1                         False                      True
# 2                         False                      True
# 3                         False                      True
# 4                         False                      True
# 5                          True                     False
#
#          Operating System_iOS  Gender_Female  Gender_Male
# User ID
# 1                       False          False         True
# 2                       False           True        False
# 3                       False          False         True
# 4                       False          False         True
# 5                        True           True        False

# %% [markdown]
# Are our target classes balanced?

# %%
df['User Behavior Class'].value_counts().to_dict()
# Out:
# {2: 146, 3: 143, 4: 139, 5: 136, 1: 136}

# %% [markdown]
# Our target class is essentially balanced.

# %%
COLUMNS = ['App Usage Time (min/day)', 'Screen On Time (hours/day)',
       'Battery Drain (mAh/day)', 'Number of Apps Installed',
       'Data Usage (MB/day)', 'Age', 
       'Device Model_Google Pixel 5', 'Device Model_OnePlus 9',
       'Device Model_Samsung Galaxy S21', 'Device Model_Xiaomi Mi 11',
       'Device Model_iPhone 12', 'Operating System_Android',
       'Operating System_iOS', 'Gender_Female', 'Gender_Male']

# %% [markdown]
# Let's do some dimension reduction and visualize our data using a scatter plot.

# %%
import arrow
from umap import UMAP

time_start = arrow.now()
umap = UMAP(random_state=2024, verbose=False, n_jobs=1, low_memory=False, n_epochs=201)
df[['x', 'y']] = umap.fit_transform(X=df[COLUMNS])
print('done with UMAP in {}'.format(arrow.now() - time_start))
# Out:
# done with UMAP in 0:00:09.910675

# %%
from plotly import express

express.scatter(data_frame=df, x='x', y='y', color=TARGET, )
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a8ca2ca9-9eb0-4716-98bf-ded623affea9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8ca2ca9-9eb0-4716-98bf-ded623affea9")) {                    Plotly.newPlot(                        "a8ca2ca9-9eb0-4716-98bf-ded623affea9",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eUser Behavior Class=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[4,3,2,3,3,2,4,5,4,4,1,3,4,3,3,5,2,3,1,5,2,5,4,3,3,2,4,5,4,4,3,3,3,1,5,1,2,5,4,4,3,5,2,2,2,5,5,2,5,5,4,3,2,2,5,1,1,5,4,4,5,4,1,5,4,3,3,2,5,1,4,5,4,1,1,3,1,2,1,3,5,2,4,1,3,4,2,1,2,4,2,3,1,2,4,4,5,5,1,3,1,3,2,3,2,1,2,1,3,3,2,5,3,2,4,2,1,3,1,2,4,5,5,5,3,5,4,3,2,2,5,4,2,1,1,5,1,3,5,5,3,4,2,1,5,3,4,1,3,2,5,1,2,4,1,2,1,4,4,2,1,1,4,1,3,5,5,1,3,5,2,1,2,4,1,3,3,3,3,5,2,4,5,1,5,5,4,1,2,1,2,1,4,3,4,3,3,2,1,2,5,2,1,1,2,4,1,2,5,3,4,5,2,1,2,5,4,5,5,2,4,2,4,5,2,5,4,3,2,4,2,5,5,2,2,1,5,4,1,5,1,5,2,4,1,3,1,4,2,1,1,4,5,2,1,4,4,3,3,5,1,4,5,1,4,5,3,5,3,4,4,3,2,2,2,5,3,3,1,4,1,1,4,1,4,5,4,3,2,1,4,1,1,3,5,1,4,2,3,2,4,3,4,5,2,2,3,4,3,4,3,4,2,2,3,1,3,2,4,5,3,3,4,1,4,3,3,1,1,5,3,2,3,4,1,5,4,1,4,1,1,5,5,3,3,4,2,1,2,4,4,1,3,4,1,1,3,5,1,3,5,5,1,4,5,4,5,5,2,2,5,5,5,5,1,1,1,4,5,2,3,5,1,2,2,4,2,1,5,2,4,4,2,4,5,4,1,5,1,1,5,2,4,5,5,4,2,4,4,4,5,5,3,3,2,2,3,5,3,1,1,2,4,1,3,2,2,2,2,5,3,2,5,1,5,2,3,1,2,2,3,3,1,3,5,4,5,3,2,1,2,5,2,1,2,1,1,3,1,2,5,2,3,3,1,3,4,3,4,1,3,5,2,3,3,4,4,3,3,3,2,5,5,1,4,1,2,3,4,5,4,2,1,4,2,5,3,2,3,2,1,4,5,3,5,4,3,1,3,5,3,5,1,2,4,2,2,1,5,2,4,1,4,5,3,3,2,1,2,3,5,4,4,3,4,2,3,5,5,5,5,2,3,3,5,1,3,2,4,2,4,2,2,4,4,3,2,3,4,5,4,2,1,1,3,1,2,1,3,4,4,4,3,5,5,2,5,4,3,1,5,2,3,1,1,2,3,4,4,2,2,5,4,3,4,5,5,2,2,3,4,1,2,2,3,4,5,3,3,5,5,1,5,1,2,2,3,3,4,3,3,1,4,1,1,1,3,3,1,4,2,3,5,2,4,2,5,1,4,5,1,1,5,2,3,2,1,1,4,3,2,1,3,1,5,2,3,3,4,5,1,2,2,4,5,3,5,3,2,2,1,4,5,1,5,1,2,2,3,1,4,4,3,1,3,4,4,4,3,5,3,2,4,5,5,2,4,2,1,3],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1.2689453,6.8632507,12.123258,3.6511805,6.1900797,12.0785675,1.4876416,-3.5245402,-0.47760034,1.2528657,8.745114,3.913768,-1.1131332,3.8204958,3.4339857,-2.3483176,11.8952265,5.889364,10.447451,-3.5006304,11.903009,-2.9308584,0.6407277,6.124829,3.4569662,13.009511,-1.1848334,-1.6609433,-0.30403635,1.5677124,6.5393767,3.95895,5.4627094,8.292023,-1.7361027,8.949966,13.372715,-3.2784417,-0.3334236,1.2639676,5.1115932,-2.374763,12.43675,12.890293,12.004955,-2.1388173,-1.7061981,12.394934,-2.762155,-3.2785745,0.50122,7.1512685,12.356037,13.771921,-3.740299,8.340203,9.054366,-3.3334556,-0.95522475,-0.9507499,-3.058114,-0.6265498,8.31953,-3.4860134,0.27510977,6.045922,3.4989285,12.60382,-3.2269516,10.390647,1.3695104,-3.4138904,-1.2195256,9.569298,8.24729,7.188441,8.760383,11.934443,8.759972,7.236775,-1.5843699,12.403311,-1.0812485,8.617431,6.53053,0.6099992,13.100483,10.103144,12.322987,0.5024635,12.424853,5.157568,10.373213,13.849748,-0.63046145,0.2040775,-3.5589812,-2.1009142,10.160774,5.1202583,8.691257,6.774176,11.97554,3.3976808,13.8399725,10.226882,13.204456,10.240339,3.4029531,4.008422,12.798426,-2.3846846,5.046643,12.452091,0.44472665,13.241221,10.310993,4.0643425,8.852288,13.005751,0.01803794,-2.4749568,-2.3717077,-2.8376563,3.5351124,-3.3284497,0.19778924,5.163187,12.746349,12.54766,-3.444012,0.29561102,13.233748,8.716295,9.952622,-2.081652,9.469947,6.566155,-3.7953491,-1.7679276,4.989298,0.8780979,12.506219,9.575293,-2.2024987,7.21107,-1.1475376,9.770298,3.6363206,12.293149,-1.881075,9.503325,12.488725,-0.80942994,8.599682,12.161249,8.565434,-0.2183067,-0.21153373,12.289287,10.200271,8.5735855,0.8408954,8.296312,7.062826,-3.35074,-3.3924932,8.330972,6.707355,-1.9827222,12.77596,9.70384,11.981765,1.5836929,8.409051,4.00233,3.4164739,5.6479,4.271914,-3 ...

# %% [markdown]
# Our target variable aligns very well with our clusters, so we expect that just about any model can do well. Let's build a model.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[COLUMNS], df[TARGET], test_size=0.2, random_state=2024, stratify=df[TARGET])

logreg = LogisticRegression(max_iter=100000, tol=1e-3).fit(X_train, y_train)
print('model fit in {} iterations'.format(logreg.n_iter_[0]))
print('accuracy: {:5.4f}'.format(accuracy_score(y_true=y_test, y_pred=logreg.predict(X=X_test))))
print('f1: {:5.4f}'.format(f1_score(average='weighted', y_true=y_test, y_pred=logreg.predict(X=X_test))))
print(classification_report(zero_division=0.0, y_true=y_test, y_pred=logreg.predict(X=X_test)))
# Out:
# model fit in 13578 iterations
# accuracy: 0.9000
# f1: 0.8996
#               precision    recall  f1-score   support
#
#            1       1.00      0.96      0.98        27
#            2       0.97      0.97      0.97        29
#            3       0.84      0.93      0.89        29
#            4       0.81      0.75      0.78        28
#            5       0.89      0.89      0.89        27
#
#     accuracy                           0.90       140
#    macro avg       0.90      0.90      0.90       140
# weighted avg       0.90      0.90      0.90       140
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %% [markdown]
# That's odd. We may do better with KNN. Let's try that.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3,).fit(X_train, y_train)

print('accuracy: {:5.4f}'.format(accuracy_score(y_true=y_test, y_pred=knn.predict(X=X_test))))
print('f1: {:5.4f}'.format(f1_score(average='weighted', y_true=y_test, y_pred=knn.predict(X=X_test))))
print(classification_report(zero_division=0.0, y_true=y_test, y_pred=knn.predict(X=X_test)))
# Out:
# accuracy: 1.0000
# f1: 1.0000
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        27
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        29
#            4       1.00      1.00      1.00        28
#            5       1.00      1.00      1.00        27
#
#     accuracy                           1.00       140
#    macro avg       1.00      1.00      1.00       140
# weighted avg       1.00      1.00      1.00       140

# %% [markdown]
# Let's have a look at the model probabilities for logistic regression.

# %%
probability_df = pd.DataFrame(data=logreg.predict_proba(X=X_test).max(axis=1), columns=['probability'])
probability_df['true'] = y_test.tolist()
probability_df['pred'] = logreg.predict(X=X_test)
probability_df['correct'] = probability_df['true'] == probability_df['pred']
probability_df[['x', 'y']] = umap.transform(X=X_test)

probability_df.head()
# Out:
#    probability  true  pred  correct          x         y
# 0     0.999856     5     5     True  -2.291656 -5.380343
# 1     0.987673     1     1     True   9.696007 -2.103451
# 2     0.976413     2     2     True  12.582695  9.255136
# 3     0.996342     5     5     True  -2.172602 -3.936835
# 4     0.979685     1     1     True   8.440191 -2.951017

# %%
express.scatter(data_frame=probability_df, x='x', y='y', facet_col='correct', color='probability')
# Out:
# <div>                            <div id="f976ee8d-4074-400e-ad4d-8dd8c5c9d1fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f976ee8d-4074-400e-ad4d-8dd8c5c9d1fe")) {                    Plotly.newPlot(                        "f976ee8d-4074-400e-ad4d-8dd8c5c9d1fe",                        [{"hovertemplate":"correct=True\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eprobability=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0.9998558323126356,0.9876729458465034,0.9764126766896788,0.9963419768515911,0.9796848139676425,0.9768543437633785,0.9346756749297958,0.9498498206822975,0.8167805108394126,0.9815963784941758,0.9102559795213404,0.8433135619774962,0.9884501837564725,0.6485851500655353,0.9651906267714989,0.5777126509287799,0.7597678769146722,0.8470880019982082,0.895273380903003,0.9842928078082431,0.7589177448612697,0.9965314646375991,0.771179500097098,0.6576978753765605,0.9833960891703688,0.9951170836598803,0.9796040628968103,0.9831416121234456,0.9493894189512556,0.8584176604768103,0.7705598586181027,0.9778577732581749,0.5316213276157087,0.9855889675253708,0.9323267916551734,0.5665552480749855,0.9624170278738655,0.968520400908058,0.5986152839628865,0.909651053559847,0.9879106748406333,0.9583760437728,0.9968321728207693,0.8575312214214641,0.9844060827115708,0.9107127059521548,0.937860774289267,0.5758288239312119,0.9213082627544745,0.9107177507739374,0.9995812016374102,0.9999458268101966,0.9144033466442771,0.6105726699298468,0.8931114271101857,0.9229564786662864,0.9274984430812783,0.9468587916743402,0.9877907000707835,0.9365612483598792,0.9862946487415083,0.91256787192303,0.8884214103031385,0.9995593647458351,0.9734026276972733,0.7441558766350415,0.5197190750443422,0.7866166130704682,0.628040719111362,0.5462469091896773,0.9671405941923487,0.7422299810185525,0.9835697181540185,0.7000301065458604,0.6153162424854471,0.8419212108706515,0.6171046849011586,0.9052163830538538,0.9724355742390115,0.9121161558319907,0.9923413510209731,0.7991948916878656,0.8777632377274099,0.9934517280585043,0.9498991179150442,0.9666838207509446,0.9987214410811469,0.9806300901078658,0.9993931180374797,0.8774855944482303,0.8738518959687216,0.999962397503529,0.9218693195457873,0.9972483397151868,0.9564791808994969,0.6645231452153753,0.8079768899490378,0.6567194320782656,0.9817971106948166,0.906086282798658,0.668361312474082,0.9994615427997522,0.7947824112322829,0.8470684838389828,0.7567563544389859,0.9681762099607871,0.9887328014673837,0.8732955432832423,0.9999547766140766,0.8083310375298435,0.5625442639075646,0.980808537202024,0.8782725658086469,0.8901131694924014,0.9826241684778112,0.656563272140807,0.7023455284570223,0.5183072883046796,0.5361760680884996,0.5272123521895438,0.9839150557047345,0.7986052790542564,0.7271889414501019,0.9563711919875916,0.9683237722547475,0.9470008437535209],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-2.291656,9.696007,12.582695,-2.1726024,8.440191,9.73147,13.145626,10.24929,11.94653,12.59015,10.454323,10.047082,10.058941,0.47041366,12.13424,-1.0910691,5.000689,-3.686913,12.720455,9.957633,12.564291,9.131891,3.7999272,4.097585,-3.013654,9.920271,13.01276,13.794967,9.111277,1.5472943,-1.0851492,8.549116,12.416411,9.093468,-0.19041643,-0.8748222,1.3754127,12.430763,-3.5399454,8.668725,8.793805,6.569005,-3.087676,3.7607567,-2.0053241,6.445255,12.384055,-1.6018608,0.4238583,-0.58798546,-2.3587472,-2.3479223,1.2372652,4.1405196,8.4356165,3.5473444,12.337544,3.8314576,10.20269,-1.3930811,-2.5583014,0.073687114,12.903624,-2.8639205,12.860875,4.1557236,4.1086135,0.9336899,-1.8990823,6.716919,-2.6038532,11.833652,10.00689,6.3867526,3.4298308,0.7236308,1.2970824,12.957395,-1.6423907,1 ...

# %% [markdown]
# Surprisingly, our logistic regression model makes mistakes in all five classes, and occasionally produces high model probablities for incorrect predictions.
