# %% [markdown]
# <a href="https://www.kaggle.com/code/mikedelong/global-data-needs-maps?scriptVersionId=149335709" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/material-footprint-per-capita-by-country/material_footprint.csv')
# if we don't have data in the most complete year we may as well drop the country altogether
df = df.dropna(subset=df.columns[-1])
df['mean'] = df[df.columns[7:]].mean(axis=1)
df['std'] = df[df.columns[7:]].std(axis=1)
df.head()
# Out:
#   ISO3               Country Continent           Hemisphere  \
# 0  AFG           Afghanistan      Asia  Northern Hemisphere
# 1  AGO                Angola    Africa  Southern Hemisphere
# 2  ALB               Albania    Europe  Northern Hemisphere
# 4  ARE  United Arab Emirates      Asia  Northern Hemisphere
# 5  ARG             Argentina   America  Southern Hemisphere
#
#   Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                      Low                      SA            180.0
# 1                   Medium                     SSA            148.0
# 2                     High                     ECA             67.0
# 4                Very High                      AS             26.0
# 5                Very High                     LAC             47.0
#
#    Material footprint per capita (tonnes) (1990)  \
# 0                                           2.33
# 1                                           2.44
# ...

# %%
from plotly.express import choropleth
for color in ['Continent', 'Hemisphere', 'Human Development Groups', 'UNDP Developing Regions', 'HDI Rank (2021)', 'mean', 'std']:
    choropleth(data_frame=df, locations='ISO3', color=color).show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
from plotly.express import scatter
scatter(data_frame=df, x='mean', y='std', color='Human Development Groups', log_y=True, hover_name='Country')
# Out:
# <div>                            <div id="f84b413c-b846-4f4f-9bf1-c0498a48db4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f84b413c-b846-4f4f-9bf1-c0498a48db4c")) {                    Plotly.newPlot(                        "f84b413c-b846-4f4f-9bf1-c0498a48db4c",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eHuman Development Groups=Low\u003cbr\u003emean=%{x}\u003cbr\u003estd=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Burundi","Benin","Burkina Faso","Central African Republic","The Democratic Republic of the Congo","Djibouti","Eritrea","Ethiopia","Guinea","Gambia","Haiti","Liberia","Madagascar","Mali","Mozambique","Malawi","Niger","Nigeria","Pakista
# ...

# %% [markdown]
# The mean footprint tells us the level and the standard deviation tells us the volatility; mean consumption does a pretty good job of tracking development.

# %%
scatter(data_frame=df, y='mean', x='HDI Rank (2021)', color='Human Development Groups', log_y=False, hover_name='Country')
# Out:
# <div>                            <div id="a97a3d6e-5275-46ae-8344-fcb962773b02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a97a3d6e-5275-46ae-8344-fcb962773b02")) {                    Plotly.newPlot(                        "a97a3d6e-5275-46ae-8344-fcb962773b02",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eHuman Development Groups=Low\u003cbr\u003eHDI Rank (2021)=%{x}\u003cbr\u003emean=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Burundi","Benin","Burkina Faso","Central African Republic","The Democratic Republic of the Congo","Djibouti","Eritrea","Ethiopia","Guinea","Gambia","Haiti","Liberia","Madagascar","Mali","Mozambique","Malawi","Niger","Niger
# ...

# %%
scatter(data_frame=df, x='mean', color='HDI Rank (2021)', y='std', log_y=True, hover_name='Country')
# Out:
# <div>                            <div id="dfe14c72-9db1-4918-a95c-3146662e96df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfe14c72-9db1-4918-a95c-3146662e96df")) {                    Plotly.newPlot(                        "dfe14c72-9db1-4918-a95c-3146662e96df",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003emean=%{x}\u003cbr\u003estd=%{y}\u003cbr\u003eHDI Rank (2021)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Angola","Albania","United Arab Emirates","Argentina","Armenia","Australia","Austria","Azerbaijan","Burundi","Belgium","Benin","Burkina Faso","Bangladesh","Bulgaria","Bahrain","Bahamas","Bosnia and Herzegovina","Belarus","Belize","B
# ...
