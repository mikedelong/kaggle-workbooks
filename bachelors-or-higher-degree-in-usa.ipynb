# %% [markdown]
# <a href="https://www.kaggle.com/code/mikedelong/bachelors-or-higher-degree-in-usa?scriptVersionId=135609758" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/bachelors-or-higher-degree-data-of-usa/Bachelors or Higher Degree for USA States.csv").rename(columns={'Unnamed: 0': 'Year'})
df.columns = [item.strip() for item in df.columns]
df['Year'] = df['Year'].apply(func=lambda x: int(str(x)[:4]))
df.head()
# Out:
#    Year  Alabama  California  Arizona  Michigan  North Carolina  Minnesota  \
# 0  2006     21.1        29.0     25.5      24.5            24.8       30.4
# 1  2007     21.4        29.5     25.3      24.7            25.6       31.0
# 2  2008     22.0        29.6     25.1      24.7            26.1       31.5
# 3  2009     22.0        29.9     25.6      24.6            26.5       31.5
# 4  2010     21.9        30.1     25.9      25.2            26.5       31.8
#
#    Arkansas  Montana  Georgia  ...  Hawaii  Nebraska  Utah  Ohio  Washington  \
# 0      18.2     27.4     26.6  ...    29.7      26.9  28.6  23.0        30.5
# 1      19.3     27.0     27.1  ...    29.2      27.5  28.7  24.1        30.3
# 2      18.8     27.1     27.5  ...    29.1      27.1  29.1  24.1        30.7
# 3      18.9     27.4     27.5  ...    29.6      27.4  28.5  24.1        31.0
# 4      19.5     28.8     27.3  ...    29.5      28.6  29.3  24.6        31.1
#
# ...

# %%
# %matplotlib inline
from matplotlib.pyplot import xticks
from seaborn import lineplot
lineplot(data=df.melt(id_vars='Year', value_vars=df.columns[1:], var_name='State'), x='Year', y='value', hue='State', legend=None, )
_ = xticks(rotation=90)
