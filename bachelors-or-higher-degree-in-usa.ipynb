# %% [markdown]
# <a href="https://www.kaggle.com/code/mikedelong/bachelors-or-higher-degree-in-usa?scriptVersionId=135611341" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
df = pd.read_csv('../input/bachelors-or-higher-degree-data-of-usa/Bachelors or Higher Degree for USA States.csv').rename(columns={'Unnamed: 0': 'Year'})
df.rename(columns=lambda x: x.strip())
df['Year'] = pd.to_datetime(df['Year']).apply(lambda x: x.year)
df.head()
# Out:
#    Year   Alabama   California   Arizona   Michigan   North Carolina  \
# 0  2006      21.1         29.0      25.5       24.5             24.8
# 1  2007      21.4         29.5      25.3       24.7             25.6
# 2  2008      22.0         29.6      25.1       24.7             26.1
# 3  2009      22.0         29.9      25.6       24.6             26.5
# 4  2010      21.9         30.1      25.9       25.2             26.5
#
#     Minnesota   Arkansas   Montana   Georgia  ...   Hawaii   Nebraska   Utah  \
# 0        30.4       18.2      27.4      26.6  ...     29.7       26.9   28.6
# 1        31.0       19.3      27.0      27.1  ...     29.2       27.5   28.7
# 2        31.5       18.8      27.1      27.5  ...     29.1       27.1   29.1
# 3        31.5       18.9      27.4      27.5  ...     29.6       27.4   28.5
# 4        31.8       19.5      28.8      27.3  ...     29.5       28.6   29.3
#
#     Ohio   Washington   South Dakota   Rhode Island   Oregon   Virginia  \
# ...

# %%
from plotly.express import line 
figure = line(df, x='Year', y=df.columns[1:])
figure.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
