# %%
import pandas as pd
df = pd.read_csv(filepath_or_buffer='/kaggle/input/student-anxiety-dataset/anxiety.csv', encoding = 'ISO-8859-1', index_col=['S. No.'],
                ).drop(columns=['highestleague'])
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='D', origin='1899-12-30')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13464 entries, 1 to 14250
# Data columns (total 53 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Timestamp        13464 non-null  datetime64[ns]
#  1   GAD1             13464 non-null  int64
#  2   GAD2             13464 non-null  int64
#  3   GAD3             13464 non-null  int64
#  4   GAD4             13464 non-null  int64
#  5   GAD5             13464 non-null  int64
#  6   GAD6             13464 non-null  int64
#  7   GAD7             13464 non-null  int64
#  8   GADE             12815 non-null  object
#  9   SWL1             13464 non-null  int64
#  10  SWL2             13464 non-null  int64
#  11  SWL3             13464 non-null  int64
#  12  SWL4             13464 non-null  int64
#  13  SWL5             13464 non-null  int64
#  14  Game             13464 non-null  object
#  15  Platform         13464 non-null  object
# ...

# %%
df.head()
# Out:
#                            Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  \
# S. No.
# 1      2015-02-17 00:06:17.568000256     0     0     0     0     1     0
# 2      2015-02-17 00:09:47.520000256     1     2     2     2     0     1
# 3      2015-02-17 00:55:35.040000000     0     2     2     0     0     3
# 4      2015-02-17 01:37:58.655999744     0     0     0     0     0     0
# 5      2015-02-17 02:08:51.072000256     2     1     2     2     2     3
#
#         GAD7                  GADE  SWL1  ...  Birthplace    Residence  \
# S. No.                                    ...
# 1          0  Not difficult at all     3  ...         USA          USA
# 2          0    Somewhat difficult     3  ...         USA          USA
# 3          1  Not difficult at all     2  ...     Germany      Germany
# 4          0  Not difficult at all     2  ...         USA          USA
# 5          2        Very difficult     2  ...         USA  South Korea
#
# ...

# %%
df.nunique()
# Out:
# Timestamp          11734
# GAD1                   4
# GAD2                   4
# GAD3                   4
# GAD4                   4
# GAD5                   4
# GAD6                   4
# GAD7                   4
# GADE                   4
# SWL1                   7
# SWL2                   7
# SWL3                   7
# SWL4                   7
# SWL5                   7
# Game                  11
# Platform               3
# Hours                 84
# earnings             314
# whyplay              407
# League              1455
# streams               65
# SPIN1                  5
# SPIN2                  5
# SPIN3                  5
# SPIN4                  5
# SPIN5                  5
# SPIN6                  5
# SPIN7                  5
# SPIN8                  5
# SPIN9                  5
# SPIN10                 5
# SPIN11                 5
# SPIN12                 5
# SPIN13                 5
# SPIN14                 5
# SPIN15                 5
# SPIN16                 5
# ...
