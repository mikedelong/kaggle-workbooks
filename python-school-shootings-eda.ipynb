# %% [markdown]
# <a href="https://www.kaggle.com/code/mikedelong/python-school-shootings-eda?scriptVersionId=142767334" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/school-shootings/school-shootings-data.csv', index_col=['uid'])
df.head()

# %%
df.info()

# %%
df.nunique()

# %%
from plotly.express import histogram
histogram(data_frame=df[df['killed'] > 0], x='year', color='casualties')

# %%
from plotly.express import scatter_geo
scatter_geo(data_frame=df, lat='lat', lon='long',  projection='albers usa', size='casualties', color='day_of_week', hover_name='school_name')
