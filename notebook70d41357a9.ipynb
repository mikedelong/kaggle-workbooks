# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/real-estate-data-sourced-from-99acres-com/houses.csv
# /kaggle/input/real-estate-data-sourced-from-99acres-com/flats.csv

# %%
import pandas as pd
house_df = pd.read_csv(filepath_or_buffer='/kaggle/input/real-estate-data-sourced-from-99acres-com/houses.csv', index_col=['property_id']).drop(columns=['link'])
house_df.head()
# Out:
#                                                 property_name  \
# property_id
# K70037724      5 Bedroom House for sale in Sector 70A Gurgaon
# E69288322    5 Bedroom House for sale in Sector 21A Faridabad
# F69536898    10 Bedroom House for sale in Sushant Lok Phase 1
# R69483164      21 Bedroom House for sale in Sector 54 Gurgaon
# M69381272    12 Bedroom House for sale in Sushant Lok Phase 1
#
#                       society       price              rate  \
# property_id
# K70037724    Bptp Visionnaire  5.25 Crore   ₹ 20,115/sq.ft.
# E69288322                 NaN   5.7 Crore  ₹ 105,751/sq.ft.
# F69536898                 NaN   2.1 Crore   ₹ 38,251/sq.ft.
# R69483164                 NaN     5 Crore   ₹ 43,066/sq.ft.
# M69381272                 NaN     3 Crore   ₹ 53,763/sq.ft.
#
#                               area                 areaWithType      bedRoom  \
# property_id
# K70037724    (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)   5 Bedrooms
# ...

# %%
flat_df = pd.read_csv(filepath_or_buffer='/kaggle/input/real-estate-data-sourced-from-99acres-com/flats.csv',
                     index_col=['property_id']).drop(columns=['link'])
flat_df.head()
# Out:
#                                property_name                 society  \
# property_id
# C68850746       2 BHK Flat in Krishna Colony  maa bhagwati residency
# H68850564          2 BHK Flat in Ashok Vihar            Apna Enclave
# J68850120                2 BHK Flat in Sohna  Tulsiani Easy in Homes
# S68849476    2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard
# L47956793    2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend
#
#                   price             rate  \
# property_id
# C68850746        45 Lac   ₹ 5,000/sq.ft.
# H68850564        50 Lac   ₹ 7,692/sq.ft.
# J68850120        40 Lac   ₹ 6,722/sq.ft.
# S68849476    1.47 Crore  ₹ 12,250/sq.ft.
# L47956793        70 Lac   ₹ 5,204/sq.ft.
#
#                                        areaWithType     bedRoom     bathroom  \
# property_id
# C68850746            Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# H68850564            Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
# ...
