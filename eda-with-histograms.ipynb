# %%
import warnings
import pandas as pd

BUS = '/kaggle/input/london-bus-safety-performance/tfl_bus_safety.csv'

warnings.filterwarnings(action='ignore', category=FutureWarning)
df = pd.read_csv(filepath_or_buffer=BUS, parse_dates=['date_of_incident'])

df.head()
# Out:
#    year date_of_incident route        operator  group_name  \
# 0  2015       2015-01-01     1  London General    Go-Ahead
# 1  2015       2015-01-01     4       Metroline   Metroline
# 2  2015       2015-01-01     5     East London  Stagecoach
# 3  2015       2015-01-01     5     East London  Stagecoach
# 4  2015       2015-01-01     6       Metroline   Metroline
#
#              bus_garage              borough  \
# 0  Garage Not Available            Southwark
# 1  Garage Not Available            Islington
# 2  Garage Not Available             Havering
# 3  Garage Not Available  None London Borough
# 4  Garage Not Available          Westminster
#
#                            injury_result_description incident_event_type  \
# 0                          Injuries treated on scene    Onboard Injuries
# 1                          Injuries treated on scene    Onboard Injuries
# 2  Taken to Hospital – Reported Serious Injury or...    Onboard Injuries
# ...

# %% [markdown]
# There is no causal relationship apparent in our data, so we're just going to make some investigative plots.

# %%
from plotly import express

express.histogram(data_frame=df, x='operator', color='year')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
express.histogram(data_frame=df, x='year')
# Out:
# <div>                            <div id="b7c57534-cc81-423f-9587-f82ccf3bcbac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7c57534-cc81-423f-9587-f82ccf3bcbac")) {                    Plotly.newPlot(                        "b7c57534-cc81-423f-9587-f82ccf3bcbac",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"year=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,20
# ...

# %%
express.histogram(data_frame=df, x='group_name')
# Out:
# <div>                            <div id="be7690ca-9311-4839-965b-fff8b8ddb091" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be7690ca-9311-4839-965b-fff8b8ddb091")) {                    Plotly.newPlot(                        "be7690ca-9311-4839-965b-fff8b8ddb091",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"group_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Go-Ahead","Metroline","Stagecoach","Stagecoach","Metroline","Metroline","Stagecoach","London United","London United","Go-Ahead","Go-Ahead","Go-Ahead","Go-Ahead","Go-Ahead","Go-Ahead","Go-Ahe
# ...

# %%
express.histogram(data_frame=df, x='borough')
# Out:
# <div>                            <div id="4054ebdd-d8c6-42ca-8ef5-7a69dbcc005e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4054ebdd-d8c6-42ca-8ef5-7a69dbcc005e")) {                    Plotly.newPlot(                        "4054ebdd-d8c6-42ca-8ef5-7a69dbcc005e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"borough=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Southwark","Islington","Havering","None London Borough","Westminster","Westminster","City of London","Hammersmith & Fulham","Westminster","City of London","Westminster","Westminster","Southwark
# ...

# %%
express.histogram(data_frame=df, x='injury_result_description')
# Out:
# <div>                            <div id="77df6a7c-6eed-4015-9daf-8beabccaf45c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77df6a7c-6eed-4015-9daf-8beabccaf45c")) {                    Plotly.newPlot(                        "77df6a7c-6eed-4015-9daf-8beabccaf45c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"injury_result_description=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Injuries treated on scene","Injuries treated on scene","Taken to Hospital – Reported Serious Injury or Severity Unknown","Taken to Hospital – Reported Serious Injury or Severi
# ...

# %%
express.histogram(data_frame=df, x='incident_event_type')
# Out:
# <div>                            <div id="54d1b721-5c4f-43dd-9d52-e11b1e25eff5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54d1b721-5c4f-43dd-9d52-e11b1e25eff5")) {                    Plotly.newPlot(                        "54d1b721-5c4f-43dd-9d52-e11b1e25eff5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"incident_event_type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Onboard Injuries","Onboard Injuries","Onboard Injuries","Onboard Injuries","Onboard Injuries","Onboard Injuries","Onboard Injuries","Onboard Injuries","Onboard Injuries","Onboard In
# ...

# %%
express.histogram(data_frame=df, x='victim_category')
# Out:
# <div>                            <div id="a5d36c2e-6fbc-4289-9314-be9a817a6b53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5d36c2e-6fbc-4289-9314-be9a817a6b53")) {                    Plotly.newPlot(                        "a5d36c2e-6fbc-4289-9314-be9a817a6b53",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"victim_category=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Passenger","Passenger","Passenger","Passenger","Pedestrian","Passenger","Passenger","Conductor","Passenger","Passenger","Passenger","Passenger","Passenger","Passenger","Passenger","Pass
# ...

# %%
express.histogram(data_frame=df, x='victims_sex')
# Out:
# <div>                            <div id="42c16cdf-cfaf-4c30-8090-b145b0fcc917" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42c16cdf-cfaf-4c30-8090-b145b0fcc917")) {                    Plotly.newPlot(                        "42c16cdf-cfaf-4c30-8090-b145b0fcc917",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"victims_sex=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Male","Male","Male","Male","Female","Female","Male","Unknown","Female","Female","Female","Female","Female","Male","Male","Female","Unknown","Unknown","Unknown","Male","Unknown","Unknown","U
# ...

# %%
express.histogram(data_frame=df, x='victims_age')
# Out:
# <div>                            <div id="dae5b1af-a24d-4937-a926-940885536f7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dae5b1af-a24d-4937-a926-940885536f7d")) {                    Plotly.newPlot(                        "dae5b1af-a24d-4937-a926-940885536f7d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"victims_age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Child","Unknown","Elderly","Elderly","Elderly","Elderly","Adult","Unknown","Elderly","Adult","Adult","Adult","Adult","Child","Elderly","Unknown","Unknown","Unknown","Adult","Unknown","Unkno
# ...

# %%
express.scatter(data_frame=df[['borough', 'incident_event_type']].groupby(by=['borough', 'incident_event_type']).size().to_frame().reset_index(), x='borough', y='incident_event_type', color=0)
# Out:
# <div>                            <div id="5ae29ff5-168a-4976-a562-f61aaf79105a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ae29ff5-168a-4976-a562-f61aaf79105a")) {                    Plotly.newPlot(                        "5ae29ff5-168a-4976-a562-f61aaf79105a",                        [{"hovertemplate":"borough=%{x}\u003cbr\u003eincident_event_type=%{y}\u003cbr\u003e0=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3,8,64,88,69,1,3,136,2,6,30,174,3,288,171,3,245,2,1,10,67,101,70,160,5,13,48,137,260,188,5,234,2,3,10,116,198,145,2,198,1,1,33,157,1,265,234,8,199,2,4,51,55,64,1,68,3,24,182,315,142,3,363,9,30,151,1,270,176,2,224,2,10,92,182,92,1,202,3,27,158,181,200,3,259,4,1,8,139,261,149,5,232,1,4,19,91
# ...

# %%
df.nunique()
# Out:
# year                           4
# date_of_incident              45
# route                        612
# operator                      25
# group_name                    14
# bus_garage                    84
# borough                       35
# injury_result_description      4
# incident_event_type           10
# victim_category               17
# victims_sex                    3
# victims_age                    5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23158 entries, 0 to 23157
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       23158 non-null  int64
#  1   date_of_incident           23158 non-null  datetime64[ns]
#  2   route                      23158 non-null  object
#  3   operator                   23158 non-null  object
#  4   group_name                 23158 non-null  object
#  5   bus_garage                 23158 non-null  object
#  6   borough                    23158 non-null  object
#  7   injury_result_description  23158 non-null  object
#  8   incident_event_type        23158 non-null  object
#  9   victim_category            23158 non-null  object
#  10  victims_sex                23158 non-null  object
#  11  victims_age                23158 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 2.1+ MB
